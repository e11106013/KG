# %%
# 先產生一個CSV檔案，給後面的程式讀取
import json
import pandas as pd
import os
import re

# 設定資料夾路徑
directory_path = "./docs/output/1_clean_json/llama"
# 儲存為 CSV 檔案
csv_path = "./docs/output/2_metadata/processed_data.csv"

# 讀取 JSON 檔案
def read_json(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return data
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON in file {file_path}: {e}")
        return None
    except Exception as e:
        print(f"Error reading file {file_path}: {e}")
        return None

# 目標關鍵字正則表達式（優先處理 "檔案來源機關"）
target_patterns = {
    "案名": r"(案名：)",
    "檔案內容": r"(檔案內容：)",
    "檔號": r"(檔號：)",
    "管有機關": r"(管有機關：)",
    "檔案來源機關": r"(檔案來源機關：)",  # **優先處理**
    "來源機關": r"(來源機關：)"  # **如果沒有 "檔案來源機關" 才處理**
}

# 處理 `reference` 欄位
def process_reference(reference):
    if isinstance(reference, list):
        modified_ref_list = []
        contains_file_source = any("檔案來源機關" in ref for ref in reference)  # 是否有 "檔案來源機關"

        for ref in reference:
            if any(key in ref for key in target_patterns):  # 只處理包含關鍵字的行
                for key, pattern in target_patterns.items():
                    # **如果"檔案來源機關"已經存在，就不再處理 "來源機關"**
                    if key == "來源機關" and contains_file_source:
                        continue
                    ref = re.sub(pattern, r" | \1", ref)  # 在關鍵字前加 " | "
            modified_ref_list.append(ref.strip())  # 去除前後空白

        return modified_ref_list
    return reference  # 非列表的情況，直接返回

# 處理 JSON 數據
def process_data(data, file_id):
    file_ids = []  # 每個 reference 對應的 file_id
    references = []  # 處理後的 reference

    if isinstance(data, dict):
        data = [data]
    
    if isinstance(data, list):
        for item in data:
            title = item.get('titles', '')
            if isinstance(title, list):
                title = title[0] if title else ''
            
            reference = item.get('reference', [])
            modified_reference = process_reference(reference)

            for ref in modified_reference:
                file_ids.append(file_id)
                references.append(ref)  # 每個 reference 獨立存入

    # 創建 DataFrame
    df = pd.DataFrame({
        'file_id': file_ids,
        'reference': references
    })
    
    return df

# 讀取所有 JSON 檔案
def read_all_json_files(directory_path):
    all_data = []
    
    for filename in os.listdir(directory_path):
        if filename.endswith('.json'):
            file_path = os.path.join(directory_path, filename)
            print(f"Reading file: {file_path}")
            data = read_json(file_path)
            if data:
                all_data.append((data, filename))
    
    return all_data

# 讀取所有 JSON 檔案
all_data = read_all_json_files(directory_path)

# 整理資料
all_file_ids = []
all_references = []

# 處理所有檔案的資料
for data, file_id in all_data:
    df = process_data(data, file_id)
    all_file_ids.extend(df['file_id'])
    all_references.extend(df['reference'])

# 創建最終 DataFrame
final_df = pd.DataFrame({
    'file_id': all_file_ids,
    'reference': all_references
})

final_df.to_csv(csv_path, index=False, encoding='utf-8-sig')

print(f"CSV file has been saved to {csv_path}")
# Out:
# Reading file: ./docs/output/1_clean_json/llama\228事件(20).json
# Reading file: ./docs/output/1_clean_json/llama\「友仔」是什麼？光復初期臺北地區非法組織調查報告告訴您(37).json
# Reading file: ./docs/output/1_clean_json/llama\「回首向來蕭瑟處，歸去，也無風雨也無晴」—民國38年國軍遷臺紀事(30).json
# Reading file: ./docs/output/1_clean_json/llama\「威海衛」租借地的收回(42).json
# Reading file: ./docs/output/1_clean_json/llama\「快速」發展的年代：麥克阿瑟公路通車一甲子(203).json
# Reading file: ./docs/output/1_clean_json/llama\「日暮鄉關何處是」─「留越國軍」的返台路(31).json
# Reading file: ./docs/output/1_clean_json/llama\「賽德克．巴萊」重現的霧社事件(17).json
# Reading file: ./docs/output/1_clean_json/llama\「醫者仁也‧仁者人也」─光復初期臺灣醫學教育(29).json
# Reading file: ./docs/output/1_clean_json/llama\ㄋㄟㄋㄟ補給站：美援牛奶的供應(127).json
# Reading file: ./docs/output/1_clean_json/llama\一紙命令，臺灣命運大不同─中國台灣省行政長官公署警備總司令部第一號令(1).json
# Reading file: ./docs/output/1_clean_json/llama\不用手機也可哈拉一整天─45年度公用電話擴充計畫(2).json
# Reading file: ./docs/output/1_clean_json/llama\不能少了你—臺灣光復後首次戶口清查(35).json
# Reading file: ./docs/output/1_clean_json/llama\世界人權日(18).json
# Reading file: ./docs/output/1_clean_json/llama\世紀糖鐵穿鄉越鎮的五分車(148).json
# Reading file: ./docs/output/1_clean_json/llama\中元普渡與法國軍墓在基隆(170).json
# Reading file: ./docs/output/1_clean_json/llama\中華商場：見證大臺北繁華歲月(166).json
# Reading file: ./docs/output/1_clean_json/llama\中華航空：從軍事化管理到以客為尊經營(152).json
# Reading file: ./docs/output/1_clean_json/llama\九年國教：春風化雨五十載(134).json
# Reading file: ./docs/output/1_clean_json/llama\亞東關係協會：臺日友好關係的樞紐(185).json
# Reading file: ./docs/output/1_clean_json/llama\人民頭家—公民直選總統(23).json
# Reading file: ./docs/output/1_clean_json/llama\任重道遠─民國36年台灣省鐵路圖(11).json
# Reading file: ./docs/output/1_clean_json/llama\低鈉鹽的由來─從臺鹽公司檔案見端倪(60).json
# Reading file: ./docs/output/1_clean_json/llama\保存學術的火種—中央研究院播遷來臺(76).json
# Reading file: ./docs/output/1_clean_json/llama\保育與觀光—從國立公園到國家公園(141).json
# Reading file: ./docs/output/1_clean_json/llama\傳播知識的種子—臺灣總督府圖書館的故事(62).json
# Reading file: ./docs/output/1_clean_json/llama\元氣補給：美軍大兵在臺灣(163).json
# Reading file: ./docs/output/1_clean_json/llama\光復初期的山區管制與遷村(41).json
# Reading file: ./docs/output/1_clean_json/llama\光復初期臺灣鐵路的復原(86).json
# Reading file: ./docs/output/1_clean_json/llama\光輝十月．榮耀臺灣(28).json
# Reading file: ./docs/output/1_clean_json/llama\全民瘋棒球：回味臺灣棒球精彩史頁(83).json
# Reading file: ./docs/output/1_clean_json/llama\八七水災與家園重建(146).json
# Reading file: ./docs/output/1_clean_json/llama\公路趴趴走！GO~GO！(58).json
# Reading file: ./docs/output/1_clean_json/llama\共榮併進—農復會與臺灣農業的發展(116).json
# Reading file: ./docs/output/1_clean_json/llama\兵役節淺談兵役(21).json
# Reading file: ./docs/output/1_clean_json/llama\再續絃歌：交通大學在臺灣的耕耘路(135).json
# Reading file: ./docs/output/1_clean_json/llama\力挽狂瀾：民國51年副霍亂疫情撲滅與對日貿易(156).json
# Reading file: ./docs/output/1_clean_json/llama\市容煥新：淘汰三輪換四輪(143).json
# Reading file: ./docs/output/1_clean_json/llama\幽禁歲月：張學良在臺灣的後半生(114).json
# Reading file: ./docs/output/1_clean_json/llama\廢鐵變黃金：從沉船打撈到拆船王國(167).json
# Reading file: ./docs/output/1_clean_json/llama\彰化地標：八卦山大佛與風景區(174).json
# Reading file: ./docs/output/1_clean_json/llama\從想食到饗時—尋味臺灣八十年(172).json
# Reading file: ./docs/output/1_clean_json/llama\從開發到保育：走過臺灣的建設時代(196).json
# Reading file: ./docs/output/1_clean_json/llama\快樂時光：承載記憶的兒童樂園(130).json
# Reading file: ./docs/output/1_clean_json/llama\您今天搭幾路？光復初期的基隆市公車(50).json
# Reading file: ./docs/output/1_clean_json/llama\情報戰：金門戰役的決勝要件(149).json
# Reading file: ./docs/output/1_clean_json/llama\愛仁輪事件爭議始末(117).json
# Reading file: ./docs/output/1_clean_json/llama\戒嚴時期金門漁會與漁業的發展(186).json
# Reading file: ./docs/output/1_clean_json/llama\戰時相戀、和平分離─海角七號的故事背景(25).json
# Reading file: ./docs/output/1_clean_json/llama\打撈沉貼：光復初期臺灣的軍事接收要務(106).json
# Reading file: ./docs/output/1_clean_json/llama\打造超級油輪「柏瑪奮進號」(125).json
# Reading file: ./docs/output/1_clean_json/llama\扭轉「錢」坤—國幣演變的故事(84).json
# Reading file: ./docs/output/1_clean_json/llama\投降到受降—撼動歷史的26天(38).json
# Reading file: ./docs/output/1_clean_json/llama\抗戰「船」奇：決戰千里外的廣源輪案(121).json
# Reading file: ./docs/output/1_clean_json/llama\抗戰時期的傷兵救護與管理(99).json
# Reading file: ./docs/output/1_clean_json/llama\抗戰期間的新四軍事件(85).json
# Reading file: ./docs/output/1_clean_json/llama\拓墾最前線臺三線上的明珠—北埔(122).json
# Reading file: ./docs/output/1_clean_json/llama\探索臺灣鹽業發展四百年(199).json
# Reading file: ./docs/output/1_clean_json/llama\揭密．國家檔案(173).json
# Reading file: ./docs/output/1_clean_json/llama\撲瘧我最棒─得來不易的「台灣地區瘧疾根除證書」(3).json
# Reading file: ./docs/output/1_clean_json/llama\文化活化了產業—從檔案看國營事業的轉型(65).json
# Reading file: ./docs/output/1_clean_json/llama\旅行的記憶：歷史景點的美好故事(63).json
# Reading file: ./docs/output/1_clean_json/llama\旋轉舞台：消失的電視國劇(49).json
# Reading file: ./docs/output/1_clean_json/llama\晴空決戰中的外籍空軍志願隊(26).json
# Reading file: ./docs/output/1_clean_json/llama\更迭變化的人口課題，永遠的挑戰─推行臺灣地區家庭計畫(4).json
# Reading file: ./docs/output/1_clean_json/llama\本週中心德目：服從師長(45).json
# Reading file: ./docs/output/1_clean_json/llama\杜絕烏腳病：臺灣公衛史上的大挑戰(202).json
# Reading file: ./docs/output/1_clean_json/llama\東沙島主權維護：從海人草開發談起(87).json
# Reading file: ./docs/output/1_clean_json/llama\桃園國際機場與周邊交通的發展(140).json
# Reading file: ./docs/output/1_clean_json/llama\歡慶光復臺灣省博覽會(100).json
# Reading file: ./docs/output/1_clean_json/llama\民國38年的太平輪事件(96).json
# Reading file: ./docs/output/1_clean_json/llama\氣候戰爭：古寧頭戰役致勝關鍵之一(110).json
# Reading file: ./docs/output/1_clean_json/llama\水庫紀元：曾文水庫的竣工與開放(192).json
# Reading file: ./docs/output/1_clean_json/llama\水源永續：多功能石門水庫的興建(204).json
# Reading file: ./docs/output/1_clean_json/llama\永誌邦誼：臺灣糖業技術的對外援助(157).json
# Reading file: ./docs/output/1_clean_json/llama\沙漠奇蹟、綠洲農業—海外農耕隊(77).json
# Reading file: ./docs/output/1_clean_json/llama\海洋臺灣：走尋港口的歷史(59).json
# Reading file: ./docs/output/1_clean_json/llama\湖光山色：從工業走向觀光的澄清湖(155).json
# Reading file: ./docs/output/1_clean_json/llama\溫泉之旅：北投產業發展速讀(115).json
# Reading file: ./docs/output/1_clean_json/llama\灣生尋根-在臺日僑遣送(101).json
# Reading file: ./docs/output/1_clean_json/llama\火車快飛—臺灣鐵路建設向前行(82).json
# Reading file: ./docs/output/1_clean_json/llama\為國爭光：臺北市少棒隊勇奪世界冠軍(182).json
# Reading file: ./docs/output/1_clean_json/llama\烽火歲月中的「臺灣革命同盟會」(103).json
# Reading file: ./docs/output/1_clean_json/llama\烽火歲月與和平鐘聲：決戰於千里之外的宣傳單(52).json
# Reading file: ./docs/output/1_clean_json/llama\獎券在手、希望無窮：期待中獎的喜悅(68).json
# Reading file: ./docs/output/1_clean_json/llama\球來就打，永不放棄的臺南巨人少棒隊(169).json
# Reading file: ./docs/output/1_clean_json/llama\甜蜜再進化—從產糖到製菓(161).json
# Reading file: ./docs/output/1_clean_json/llama\由直轉橫：新臺幣鈔券的發行與演變(180).json
# Reading file: ./docs/output/1_clean_json/llama\白金鹽憶：戰後臺灣鹽業的多元發展(184).json
# Reading file: ./docs/output/1_clean_json/llama\百事可樂加冰塊：敲開市場大門的一封信(177).json
# Reading file: ./docs/output/1_clean_json/llama\百年記憶：憲法制訂歷程(43).json
# Reading file: ./docs/output/1_clean_json/llama\百年記憶：承載記憶的鐵路(44).json
# Reading file: ./docs/output/1_clean_json/llama\直衝雲霄：花蓮機場走過一甲子歲月(179).json
# Reading file: ./docs/output/1_clean_json/llama\看不見的推手—美援與臺灣經濟發展(93).json
# Reading file: ./docs/output/1_clean_json/llama\礦山記憶：探索金瓜石百年歷史風華(191).json
# Reading file: ./docs/output/1_clean_json/llama\科技時代：清華大學電動車的研發(195).json
# Reading file: ./docs/output/1_clean_json/llama\空飄氣球諜對諜(15).json
# Reading file: ./docs/output/1_clean_json/llama\空飄汽球：對中共的心戰攻勢(131).json
# Reading file: ./docs/output/1_clean_json/llama\穿梭南北：自強號啟動臺灣運輸新紀元(126).json
# Reading file: ./docs/output/1_clean_json/llama\穿越時空的阿里山森林鐵路！(88).json
# Reading file: ./docs/output/1_clean_json/llama\筵席稅(14).json
# Reading file: ./docs/output/1_clean_json/llama\紀念至聖先師的傳統禮俗—祭孔大典(75).json
# Reading file: ./docs/output/1_clean_json/llama\細菌戰疫：國際合作與鼠疫防治(153).json
# Reading file: ./docs/output/1_clean_json/llama\經營與蛻變：從輪船招商局到陽明海運(181).json
# Reading file: ./docs/output/1_clean_json/llama\縮地千里始足下(56).json
# Reading file: ./docs/output/1_clean_json/llama\繁榮經濟的高雄加工出口區(112).json
# Reading file: ./docs/output/1_clean_json/llama\繪葉傳意、郵戳紀事：歷史的窗與鏡(67).json
# Reading file: ./docs/output/1_clean_json/llama\美哉海洋國家公園：東沙島歷史寫真簿(64).json
# Reading file: ./docs/output/1_clean_json/llama\考察臺灣：光復初期大專院校的校外實習(91).json
# Reading file: ./docs/output/1_clean_json/llama\肥料換穀：臺灣農業生產的根基(108).json
# Reading file: ./docs/output/1_clean_json/llama\臺北市升格與蛻變(120).json
# Reading file: ./docs/output/1_clean_json/llama\臺北機廠：火車改造的大本營(123).json
# Reading file: ./docs/output/1_clean_json/llama\臺灣人的財產？還是日本人的財產？—政府接收臺灣日產的插曲(40).json
# Reading file: ./docs/output/1_clean_json/llama\臺灣來電：電力事業的早期發展(90).json
# Reading file: ./docs/output/1_clean_json/llama\臺灣唯一的海底隧道：高雄過港隧道的建設與通車(200).json
# Reading file: ./docs/output/1_clean_json/llama\臺灣啟航：南北雙港百年進展(160).json
# Reading file: ./docs/output/1_clean_json/llama\臺灣日產的接收(95).json
# Reading file: ./docs/output/1_clean_json/llama\臺灣瘧疾根除半世紀(102).json
# Reading file: ./docs/output/1_clean_json/llama\臺灣菸酒事業：從專賣到自由化經營 (193).json
# Reading file: ./docs/output/1_clean_json/llama\臺灣西部走廊大動脈—中山高速公路(72).json
# Reading file: ./docs/output/1_clean_json/llama\臺灣貨櫃運輸新發展(1960-1980年代)(150).json
# Reading file: ./docs/output/1_clean_json/llama\臺灣鐵道線路圖—見證鐵路萬能的1930年代(137).json
# Reading file: ./docs/output/1_clean_json/llama\臺韓外交的轉折：反共六義士劫機事件(189).json
# Reading file: ./docs/output/1_clean_json/llama\與農共生—走過百年的農會(113).json
# Reading file: ./docs/output/1_clean_json/llama\航向國際：高雄國際機場的蛻變(138).json
# Reading file: ./docs/output/1_clean_json/llama\英雄之島：揭開大膽島的神祕面紗(158).json
# Reading file: ./docs/output/1_clean_json/llama\華興中學與臺灣棒球傳奇 (194).json
# Reading file: ./docs/output/1_clean_json/llama\萬噸巨輪MIT(66).json
# Reading file: ./docs/output/1_clean_json/llama\萬變甘味—多元的糖業產品(151).json
# Reading file: ./docs/output/1_clean_json/llama\落地生根－大陳人遷臺歷程(97).json
# Reading file: ./docs/output/1_clean_json/llama\虎翔天際：鏖戰藍天的FlyingTiger(69).json
# Reading file: ./docs/output/1_clean_json/llama\行憲後「第一任總統、副總統就職大典」實況轉播(47).json
# Reading file: ./docs/output/1_clean_json/llama\被遺忘的戰爭—韓戰(70).json
# Reading file: ./docs/output/1_clean_json/llama\西螺大橋：遠東第一大橋在臺灣(187).json
# Reading file: ./docs/output/1_clean_json/llama\見證歷史的幸運之艦－丹陽艦(107).json
# Reading file: ./docs/output/1_clean_json/llama\解讀無字天書—地質調查所與臺灣地質圖(142).json
# Reading file: ./docs/output/1_clean_json/llama\誓師北伐：我國空軍的貢獻(109).json
# Reading file: ./docs/output/1_clean_json/llama\警報響起…防空洞成追憶(78).json
# Reading file: ./docs/output/1_clean_json/llama\走過一甲子的清境農場(164).json
# Reading file: ./docs/output/1_clean_json/llama\走過五十載的澎湖跨海大橋(165).json
# Reading file: ./docs/output/1_clean_json/llama\走過半世紀的陽明山中山樓(111).json
# Reading file: ./docs/output/1_clean_json/llama\跟著檔案趴趴走：西南邊境探秘行腳(46).json
# Reading file: ./docs/output/1_clean_json/llama\身、心、手、腦—伴隨臺灣農青成長的四健會(118).json
# Reading file: ./docs/output/1_clean_json/llama\遊民行不行─組織義勇糾察隊(12).json
# Reading file: ./docs/output/1_clean_json/llama\那些年檔案裏的禁書與禁歌(57).json
# Reading file: ./docs/output/1_clean_json/llama\醫療無國界─推行「中沙醫療合作計畫」(5).json
# Reading file: ./docs/output/1_clean_json/llama\金圓券的發行與流通(136).json
# Reading file: ./docs/output/1_clean_json/llama\金門之熊—古寧頭戰役的國軍裝甲兵(92).json
# Reading file: ./docs/output/1_clean_json/llama\金馬獎：一甲子的臺灣電影事業(183).json
# Reading file: ./docs/output/1_clean_json/llama\鈔票演變大不同─四萬臺幣換一元(55).json
# Reading file: ./docs/output/1_clean_json/llama\鐵路觀光：鐵路局觀光號列車的啟動(168).json
# Reading file: ./docs/output/1_clean_json/llama\鐵道安全的守護者─鐵路警察(24).json
# Reading file: ./docs/output/1_clean_json/llama\長河淌淌流金爍爍：臺金公司的金銅歲月(61).json
# Reading file: ./docs/output/1_clean_json/llama\開學樂：校園生活樂無窮(51).json
# Reading file: ./docs/output/1_clean_json/llama\關渡大橋：亞洲第一座鋼繫拱橋(197).json
# Reading file: ./docs/output/1_clean_json/llama\關閉政策：日洲丸扣留事件(129).json
# Reading file: ./docs/output/1_clean_json/llama\防疫新挑戰－從抗「煞」檔案說起(71).json
# Reading file: ./docs/output/1_clean_json/llama\阿根納造船廠的歷史風華(147).json
# Reading file: ./docs/output/1_clean_json/llama\電報為您鮮花宅配浪漫傳情─電信開辦電報送花業務(8).json
# Reading file: ./docs/output/1_clean_json/llama\電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json
# Reading file: ./docs/output/1_clean_json/llama\震驚全球的蘇聯陶普斯輪事件(178).json
# Reading file: ./docs/output/1_clean_json/llama\霍亂止步—臺灣的公共衛生成果(94).json
# Reading file: ./docs/output/1_clean_json/llama\香港調景嶺：政府救濟與難民援助(162).json
# Reading file: ./docs/output/1_clean_json/llama\香蕉輸日與臺灣經濟(119).json
# Reading file: ./docs/output/1_clean_json/llama\高雄市升格：行政區劃與人事組織的調整(145).json
# Reading file: ./docs/output/1_clean_json/llama\鬼斧神工的中橫公路(105).json
# Reading file: ./docs/output/1_clean_json/llama\黃金歲月：臺灣鳳梨罐頭行銷全球(175).json
# Reading file: ./docs/output/1_clean_json/llama\黑與白的精彩對弈—圍棋(74).json
# CSV file has been saved to ./docs/output/2_metadata/processed_data.csv

# %%
import csv
import json
import os
import re

# 設定路徑

#directory_path = "./docs/output/1_clean_json/llama"
#csv_file_path  = csv_path
output_dir = "./docs/output/2_metadata/v3"

# 確認輸出目錄是否存在，若不存在則創建
os.makedirs(output_dir, exist_ok=True)

def detect_delimiter(csv_path):
    with open(csv_path, "r", encoding="utf-8-sig") as file:
        sample = file.readline()
        if "\t" in sample:
            return "\t"
        elif ";" in sample:
            return ";"
        else:
            return ","

delimiter = detect_delimiter(csv_path)

def parse_csv_to_json(csv_path, delimiter):
    data_dict = {}

    with open(csv_path, "r", encoding="utf-8-sig") as file:
        reader = csv.reader(file, delimiter=delimiter)
        for row in reader:
            if len(row) < 2:
                continue

            file_name = row[0].strip()
            details = row[1].strip()

            # 檢查 "檔號" 是否存在於該行，若無則跳過
            if "檔號" not in details:
                continue

            #print(f"處理檔案：{file_name}，詳情：{details}")

            # 初始化 JSON 結構
            if file_name not in data_dict:
                data_dict[file_name] = {"metadata": []}

            # 解析 "檔案內容"（從「」中提取內容）
            content_match = re.search(r"檔案內容：([^ ]+)", details)

            # 解析 "檔案管有機關" 和 "檔案來源機關"
            source_match = re.search(r"檔案管有機關：([^ ]+) 檔案來源機關：([^ ]+)", details)

            # 解析其他欄位（檔號、來源機關、管有機關、案名）
            entry = {"案名": None}  # 預設 "案名": null
            for key in ["檔號", "來源機關", "管有機關", "案名"]:
                match = re.search(fr"{key}：([^|]+)", details)
                if match:
                    entry[key] = match.group(1).strip()

            # 如果有找到檔案管有機關和檔案來源機關
            if source_match:
                entry["檔案管有機關"] = source_match.group(1).strip()
                entry["檔案來源機關"] = source_match.group(2).strip()

            # 加入 "檔案內容"
            if content_match:
                entry["檔案內容"] = content_match.group(1).strip()

            # 檢查 entry 是否為空，若非空則加入
            if any(value is not None for value in entry.values()):  # 確保至少有一個有效值
                data_dict[file_name]["metadata"].append(entry)

    return data_dict

count = 0  # 初始化處理檔案數量計數器

# 讀取 CSV 資料並解析
parsed_data = parse_csv_to_json(csv_path, delimiter)

# 讀取 JSON 檔案並與 CSV 資料合併
for json_file_name in os.listdir(directory_path):
    if json_file_name.endswith(".json"):
        json_file_path = os.path.join(directory_path, json_file_name)

        # 嘗試讀取 JSON 檔案
        try:
            with open(json_file_path, "r", encoding="utf-8") as json_file:
                json_data = json.load(json_file)

            # 確認是否有對應的資料
            if json_file_name in parsed_data:
                # 合併資料（僅保留 reference 和 metadata 欄位）
                json_data = {
                    "reference": json_data.get("reference", []),
                    "metadata": parsed_data[json_file_name].get("metadata", [])
                }

                # 輸出到新的 JSON 檔案
                output_json_path = os.path.join(output_dir, json_file_name)
                with open(output_json_path, "w", encoding="utf-8") as json_output_file:
                    json.dump(json_data, json_output_file, ensure_ascii=False, indent=4)
                print(f"✅ 檔案已儲存到 {output_json_path}")
            else:
                # 沒有找到對應的 CSV 資料，將原始 JSON 寫入新目錄
                print(f"⚠️ 原始JSON檔案 {json_file_name} 不存在檔號資訊。")
                output_json_path = os.path.join(output_dir, json_file_name)
                with open(output_json_path, "w", encoding="utf-8") as json_output_file:
                    json.dump(json_data, json_output_file, ensure_ascii=False, indent=4)

                print(f"✅ 原始 JSON 檔案已儲存到 {output_json_path}")
            count += 1  # 成功處理一個檔案後，計數 +1

        except Exception as e:
            print(f"❌ 讀取檔案 {json_file_name} 時發生錯誤: {e}")
            
print(f"\n📂 共處理完成 {count} 個檔案")
# Out:
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\228事件(20).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\「友仔」是什麼？光復初期臺北地區非法組織調查報告告訴您(37).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\「回首向來蕭瑟處，歸去，也無風雨也無晴」—民國38年國軍遷臺紀事(30).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\「威海衛」租借地的收回(42).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\「快速」發展的年代：麥克阿瑟公路通車一甲子(203).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\「日暮鄉關何處是」─「留越國軍」的返台路(31).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\「賽德克．巴萊」重現的霧社事件(17).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\「醫者仁也‧仁者人也」─光復初期臺灣醫學教育(29).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\ㄋㄟㄋㄟ補給站：美援牛奶的供應(127).json
# ⚠️ 原始JSON檔案 一紙命令，臺灣命運大不同─中國台灣省行政長官公署警備總司令部第一號令(1).json 不存在檔號資訊。
# ✅ 原始 JSON 檔案已儲存到 ./docs/output/2_metadata/v3\一紙命令，臺灣命運大不同─中國台灣省行政長官公署警備總司令部第一號令(1).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\不用手機也可哈拉一整天─45年度公用電話擴充計畫(2).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\不能少了你—臺灣光復後首次戶口清查(35).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\世界人權日(18).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\世紀糖鐵穿鄉越鎮的五分車(148).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\中元普渡與法國軍墓在基隆(170).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\中華商場：見證大臺北繁華歲月(166).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\中華航空：從軍事化管理到以客為尊經營(152).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\九年國教：春風化雨五十載(134).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\亞東關係協會：臺日友好關係的樞紐(185).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\人民頭家—公民直選總統(23).json
# ⚠️ 原始JSON檔案 任重道遠─民國36年台灣省鐵路圖(11).json 不存在檔號資訊。
# ✅ 原始 JSON 檔案已儲存到 ./docs/output/2_metadata/v3\任重道遠─民國36年台灣省鐵路圖(11).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\低鈉鹽的由來─從臺鹽公司檔案見端倪(60).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\保存學術的火種—中央研究院播遷來臺(76).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\保育與觀光—從國立公園到國家公園(141).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\傳播知識的種子—臺灣總督府圖書館的故事(62).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\元氣補給：美軍大兵在臺灣(163).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\光復初期的山區管制與遷村(41).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\光復初期臺灣鐵路的復原(86).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\光輝十月．榮耀臺灣(28).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\全民瘋棒球：回味臺灣棒球精彩史頁(83).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\八七水災與家園重建(146).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\公路趴趴走！GO~GO！(58).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\共榮併進—農復會與臺灣農業的發展(116).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\兵役節淺談兵役(21).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\再續絃歌：交通大學在臺灣的耕耘路(135).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\力挽狂瀾：民國51年副霍亂疫情撲滅與對日貿易(156).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\勇者無懼的「自由中國號」(98).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\北迴鐵路串聯臺灣東部交通的動脈(198).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\升旗典禮開始：唱國歌！(48).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\原形「幣」露—新舊台幣的變裝故事(10).json
# ⚠️ 原始JSON檔案 台灣邁向民主化的里程碑─告別戒嚴時期(13).json 不存在檔號資訊。
# ✅ 原始 JSON 檔案已儲存到 ./docs/output/2_metadata/v3\台灣邁向民主化的里程碑─告別戒嚴時期(13).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\吃麵強身：國人飲食習慣的轉變(128).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\唐榮鐵工廠：見證國營企業民營化歷程(176).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\四萬換一元：新臺幣的發行與流通(144).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\國之根本—我國憲政發展速讀(89).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\國宴迎賓：外交進行曲(190).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\國家文化藝術殿堂—兩廳院的落成(80).json
# ⚠️ 原始JSON檔案 國寶大遷徙(81).json 不存在檔號資訊。
# ✅ 原始 JSON 檔案已儲存到 ./docs/output/2_metadata/v3\國寶大遷徙(81).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\國寶遷臺：故宮文物分批運抵臺灣(139).json
# ⚠️ 原始JSON檔案 國幣風華迎新歲(32).json 不存在檔號資訊。
# ✅ 原始 JSON 檔案已儲存到 ./docs/output/2_metadata/v3\國幣風華迎新歲(32).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\國慶紀念(16).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\國民住宅　營造公共居住空間(124).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\國籍疑義(19).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\在月夜飄盪的特種監獄(36).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\報案專線110？160？169？─實施簡化投案電話為110(7).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\大家來運動：回味臺灣省運動會(104).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\大專集訓-成功嶺的甘苦回憶(133).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\太平山林業開發與交通運輸(132).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\奉獻大愛．再造家園(27).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\奔馳七十載：內灣線的興築與產業脈動(171).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\妙不可「鹽」：鹽的千變萬用(188).json
# ⚠️ 原始JSON檔案 姊姊妹妹站起來─我國第一位女性大法官張金蘭女士(9).json 不存在檔號資訊。
# ✅ 原始 JSON 檔案已儲存到 ./docs/output/2_metadata/v3\姊姊妹妹站起來─我國第一位女性大法官張金蘭女士(9).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\婆娑之洋、椰林風情：南海諸島探索之旅(54).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\婦幼專線(22).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\孤臣／孤城無力可回天─大陸最後根據地西昌戰役檢討(39).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\孫理蓮與基督教芥菜種會(201).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\寂靜山城風滿樓─九份、金瓜石與二二八(33).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\寶島觀光：臺灣旅遊業的進展(159).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\山河血淚、寸土必爭：扭轉局勢的長沙會戰(73).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\屹立百年的鐵道部廳舍(154).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\市容煥新：淘汰三輪換四輪(143).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\幽禁歲月：張學良在臺灣的後半生(114).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\廢鐵變黃金：從沉船打撈到拆船王國(167).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\彰化地標：八卦山大佛與風景區(174).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\從想食到饗時—尋味臺灣八十年(172).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\從開發到保育：走過臺灣的建設時代(196).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\快樂時光：承載記憶的兒童樂園(130).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\您今天搭幾路？光復初期的基隆市公車(50).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\情報戰：金門戰役的決勝要件(149).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\愛仁輪事件爭議始末(117).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\戒嚴時期金門漁會與漁業的發展(186).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\戰時相戀、和平分離─海角七號的故事背景(25).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\打撈沉貼：光復初期臺灣的軍事接收要務(106).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\打造超級油輪「柏瑪奮進號」(125).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\扭轉「錢」坤—國幣演變的故事(84).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\投降到受降—撼動歷史的26天(38).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\抗戰「船」奇：決戰千里外的廣源輪案(121).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\抗戰時期的傷兵救護與管理(99).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\抗戰期間的新四軍事件(85).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\拓墾最前線臺三線上的明珠—北埔(122).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\探索臺灣鹽業發展四百年(199).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\揭密．國家檔案(173).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\撲瘧我最棒─得來不易的「台灣地區瘧疾根除證書」(3).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\文化活化了產業—從檔案看國營事業的轉型(65).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\旅行的記憶：歷史景點的美好故事(63).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\旋轉舞台：消失的電視國劇(49).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\晴空決戰中的外籍空軍志願隊(26).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\更迭變化的人口課題，永遠的挑戰─推行臺灣地區家庭計畫(4).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\本週中心德目：服從師長(45).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\杜絕烏腳病：臺灣公衛史上的大挑戰(202).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\東沙島主權維護：從海人草開發談起(87).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\桃園國際機場與周邊交通的發展(140).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\歡慶光復臺灣省博覽會(100).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3
json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\行憲後「第一任總統、副總統就職大典」實況轉播(47).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\被遺忘的戰爭—韓戰(70).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\西螺大橋：遠東第一大橋在臺灣(187).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\見證歷史的幸運之艦－丹陽艦(107).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\解讀無字天書—地質調查所與臺灣地質圖(142).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\誓師北伐：我國空軍的貢獻(109).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\警報響起…防空洞成追憶(78).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\走過一甲子的清境農場(164).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\走過五十載的澎湖跨海大橋(165).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\走過半世紀的陽明山中山樓(111).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\跟著檔案趴趴走：西南邊境探秘行腳(46).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\身、心、手、腦—伴隨臺灣農青成長的四健會(118).json
# ⚠️ 原始JSON檔案 遊民行不行─組織義勇糾察隊(12).json 不存在檔號資訊。
# ✅ 原始 JSON 檔案已儲存到 ./docs/output/2_metadata/v3\遊民行不行─組織義勇糾察隊(12).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\那些年檔案裏的禁書與禁歌(57).json
# ⚠️ 原始JSON檔案 醫療無國界─推行「中沙醫療合作計畫」(5).json 不存在檔號資訊。
# ✅ 原始 JSON 檔案已儲存到 ./docs/output/2_metadata/v3\醫療無國界─推行「中沙醫療合作計畫」(5).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\金圓券的發行與流通(136).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\金門之熊—古寧頭戰役的國軍裝甲兵(92).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\金馬獎：一甲子的臺灣電影事業(183).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\鈔票演變大不同─四萬臺幣換一元(55).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\鐵路觀光：鐵路局觀光號列車的啟動(168).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\鐵道安全的守護者─鐵路警察(24).json
# ⚠️ 原始JSON檔案 長河淌淌流金爍爍：臺金公司的金銅歲月(61).json 不存在檔號資訊。
# ✅ 原始 JSON 檔案已儲存到 ./docs/output/2_metadata/v3\長河淌淌流金爍爍：臺金公司的金銅歲月(61).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\開學樂：校園生活樂無窮(51).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\關渡大橋：亞洲第一座鋼繫拱橋(197).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\關閉政策：日洲丸扣留事件(129).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\防疫新挑戰－從抗「煞」檔案說起(71).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\阿根納造船廠的歷史風華(147).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\電報為您鮮花宅配浪漫傳情─電信開辦電報送花業務(8).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\震驚全球的蘇聯陶普斯輪事件(178).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\霍亂止步—臺灣的公共衛生成果(94).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\香港調景嶺：政府救濟與難民援助(162).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\香蕉輸日與臺灣經濟(119).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\高雄市升格：行政區劃與人事組織的調整(145).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\鬼斧神工的中橫公路(105).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\黃金歲月：臺灣鳳梨罐頭行銷全球(175).json
# ✅ 檔案已儲存到 ./docs/output/2_metadata/v3\黑與白的精彩對弈—圍棋(74).json
#
# 📂 共處理完成 201 個檔案

# %%
import os
import json

json_dir = output_dir  # JSON檔案所在資料夾

# 取得所有 JSON 檔案
files = [f for f in os.listdir(json_dir) if f.endswith(".json")]

for file in files:
    full_path = os.path.join(json_dir, file)
    
    with open(full_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        
        print(f"\n===== 檔案名稱: {file} =====")
        print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# ===== 檔案名稱: 228事件(20).json =====
# {
#   "reference": [
#     "檔案管有機關：檔案管理局 檔案來源機關：臺灣省菸酒公賣局 檔案內容：查緝天馬茶房一事私煙處理情形 檔號：0036/523.3/9/1/002",
#     "參考資料：檔案管理局虛擬檔案館。〈228事件主題區〉，http://va.archives.gov.tw/main.asp(民98年1月22日檢索)。",
#     "檔案管有機關：檔案管理局 檔案來源機關：臺灣省菸酒公賣局 檔案內容：查緝天馬茶房一事私煙處理情形 檔號：0036/523.3/9/1/002",
#     "參考資料：檔案管理局虛擬檔案館。〈228事件主題區〉，http://va.archives.gov.tw/main.asp(民98年1月22日檢索)。",
#     "政府網站資料開放宣告|隱私權、著作權及資訊安全政策宣告 | 本局電子信箱"
#   ],
#   "metadata": [
#     {
#       "案名": null,
#       "檔號": "0036/523.3/9/1/002",
#       "來源機關": "臺灣省菸酒公賣局",
#       "管有機關": "檔案管理局",
#       "檔案內容": "查緝天馬茶房一事私煙處理情形"
#     },
#     {
#       "案名": null,
#       "檔號": "0036/523.3/9/1/002",
#       "來源機關": "臺灣省菸酒公賣局",
#       "管有機關": "檔案管理局",
#       "檔案內容": "查緝天馬茶房一事私煙處理情形"
#     }
#   ]
# }
#
# ===== 檔案名稱: 「友仔」是什麼？光復初期臺北地區非法組織調查報告告訴您(37).json =====
# {
#   "reference": [
#     "參考資料：",
#     "1.臺灣省行政長官公署編。《臺灣省行政長官公署三月來工作概要（三十四年十月二十五日—三十五年一月二十四日）》。臺北市：編者，民35。",
#     "2.黃玉齋主編，《臺灣年鑑》。臺北市：海峽學術出版社，民90。",
#     "3.黃靜嘉。《春帆樓下晚濤急：日本對臺灣殖民統治及其影響》。臺北市：臺灣商務，民91。",
#     "檔案影像1-1 檔案內容：「擬請組織臺北市義勇糾察隊以協助治安」  檔號：0034/474/1758/001/001 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像1-2 檔案內容：「擬請組織臺北市義勇糾察隊以協助治安」  檔號：0034/474/1758/001/001 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像2-1 檔案內容：「為組織義勇糾察隊地方治安得永久保全據此理合簽請察核示遵由」  檔號：0034/474/1758/001/009 來源機關：國史館 管有機關：檔案管理局(複製品)",
#     "檔案影像2-2 檔案內容：「為組織義勇糾察隊地方治安得永久保全據此理合簽請察核示遵由」  檔號：0034/474/1758/001/009 來源機關：國史館 管有機關：檔案管理局(複製品)",
#     "檔案影像2-3 檔案內容：「為組織義勇糾察隊地方治安得永久保全據此理合簽請察核示遵由」  檔號：0034/474/1758/001/009 來源機關：國史館 管有機關：檔案管理局(複製品)",
#     "檔案影像2-4 檔案內容：「為組織義勇糾察隊地方治安得永久保全據此理合簽請察核示遵由」  檔號：0034/474/1758/001/009 來源機關：國史館 管有機關：檔案管理局(複製品)",
#     "檔案影像3-1 檔案內容：「擬具臺灣省各縣市壯丁守望隊組織辦法草案」  檔號：0035/474/1825/001/001 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像3-2 檔案內容：「各縣市守望隊之指揮監督擬由就近警察機關負責」  檔號：0035/474/1825/001/002 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像4-1 檔案內容：「製發各縣市非法組織調查表飭屬翔實填造十日內報處」  檔號：0035/474/1719/001/001 來源機關：國史館管有機關：檔案管理局(複製品)",
#     "檔案影像4-2 檔案內容：「製發各縣市非法組織調查表飭屬翔實填造十日內報處」  檔號：0035/474/1719/001/001 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像4-3 檔案內容：「調查流氓及皇民奉公會職員非法活動情形」  檔號：0035/474/1719/001/002 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像4-4 檔案內容：「調查流氓及皇民奉公會職員非法活動情形」  檔號：0035/474/1719/001/002 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像4-5 檔案內容：「調查流氓及皇民奉公會職員非法活動情形」  檔號：0035/474/1719/001/002 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像5 檔案內容：「查辦萬華流氓新興組織具報」  檔號：0037/474/1957/001/0017 來源機關：國史館管有機關：檔案管理局(複製品)",
#     "檔案影像6-1 檔案內容：「注意偵防臺北市新興流氓組織活動情形」  檔號：0037/474/1957/001/002 來源機關：國史館管有機關：檔案管理局(複製品)",
#     "檔案影像6-2 檔案內容：「注意偵防臺北市新興流氓組織活動情形」  檔號：0037/474/1957/001/002 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像6-3 檔案內容：「具報查辦萬華流氓新興組織情形」  檔號：0037/474/1957/001/008 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像7-1 檔案內容：「萬華流氓化名『烏秋』等充任刑警等情調查報告」  檔號：0037/474/1957/001/007 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像7-2 檔案內容：「萬華流氓化名『烏秋』等充任刑警等情調查報告」  檔號：0037/474/1957/001/007 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像8-1 檔案內容：「據報流氓組織『堀江部隊』等不法等情希迅併飭查辦復報」  檔號：0037/474/1957/001/009 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像8-2 檔案內容：「流氓非法組織『堀江部隊』希迅飭屬詳查嚴辦復報」  檔號：0037/474/1957/001/004 來源機關：國史館  管有機關：檔案管理局(複製品)",
#     "檔案影像8-3 檔案內容：「流氓非法組織『堀江部隊』希迅飭屬詳查嚴辦復報」  檔號：0037/474/1957/001/004 來源機關：國史館  管有機關：檔案管理局(複製品)"
#   ],
#   "metadata": [
#     {
#       "案名": null,
#       "檔號": "0034/474/1758/001/001",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「擬請組織臺北市義勇糾察隊以協助治安」"
#     },
#     {
#       "案名": null,
#       "檔號": "0034/474/1758/001/001",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「擬請組織臺北市義勇糾察隊以協助治安」"
#     },
#     {
#       "案名": null,
#       "檔號": "0034/474/1758/001/009",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「為組織義勇糾察隊地方治安得永久保全據此理合簽請察核示遵由」"
#     },
#     {
#       "案名": null,
#       "檔號": "0034/474/1758/001/009",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「為組織義勇糾察隊地方治安得永久保全據此理合簽請察核示遵由」"
#     },
#     {
#       "案名": null,
#       "檔號": "0034/474/1758/001/009",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「為組織義勇糾察隊地方治安得永久保全據此理合簽請察核示遵由」"
#     },
#     {
#       "案名": null,
#       "檔號": "0034/474/1758/001/009",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「為組織義勇糾察隊地方治安得永久保全據此理合簽請察核示遵由」"
#     },
#     {
#       "案名": null,
#       "檔號": "0035/474/1825/001/001",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「擬具臺灣省各縣市壯丁守望隊組織辦法草案」"
#     },
#     {
#       "案名": null,
#       "檔號": "0035/474/1825/001/002",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「各縣市守望隊之指揮監督擬由就近警察機關負責」"
#     },
#     {
#       "案名": null,
#       "檔號": "0035/474/1719/001/001",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「製發各縣市非法組織調查表飭屬翔實填造十日內報處」"
#     },
#     {
#       "案名": null,
#       "檔號": "0035/474/1719/001/001",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「製發各縣市非法組織調查表飭屬翔實填造十日內報處」"
#     },
#     {
#       "案名": null,
#       "檔號": "0035/474/1719/001/002",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「調查流氓及皇民奉公會職員非法活動情形」"
#     },
#     {
#       "案名": null,
#       "檔號": "0035/474/1719/001/002",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「調查流氓及皇民奉公會職員非法活動情形」"
#     },
#     {
#       "案名": null,
#       "檔號": "0035/474/1719/001/002",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「調查流氓及皇民奉公會職員非法活動情形」"
#     },
#     {
#       "案名": null,
#       "檔號": "0037/474/1957/001/0017",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「查辦萬華流氓新興組織具報」"
#     },
#     {
#       "案名": null,
#       "檔號": "0037/474/1957/001/002",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「注意偵防臺北市新興流氓組織活動情形」"
#     },
#     {
#       "案名": null,
#       "檔號": "0037/474/1957/001/002",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「注意偵防臺北市新興流氓組織活動情形」"
#     },
#     {
#       "案名": null,
#       "檔號": "0037/474/1957/001/008",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「具報查辦萬華流氓新興組織情形」"
#     },
#     {
#       "案名": null,
#       "檔號": "0037/474/1957/001/007",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「萬華流氓化名『烏秋』等充任刑警等情調查報告」"
#     },
#     {
#       "案名": null,
#       "檔號": "0037/474/1957/001/007",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「萬華流氓化名『烏秋』等充任刑警等情調查報告」"
#     },
#     {
#       "案名": null,
#       "檔號": "0037/474/1957/001/009",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「據報流氓組織『堀江部隊』等不法等情希迅併飭查辦復報」"
#     },
#     {
#       "案名": null,
#       "檔號": "0037/474/1957/001/004",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「流氓非法組織『堀江部隊』希迅飭屬詳查嚴辦復報」"
#     },
#     {
#       "案名": null,
#       "檔號": "0037/474/1957/001/004",
#       "來源機關": "國史館",
#       "管有機關": "檔案管理局(複製品)",
#       "檔案內容": "「流氓非法組織『堀江部隊』希迅飭屬詳查嚴辦復報」"
#     }
#   ]
# }
#
# ===== 檔案名稱: 「回首向來蕭瑟處，歸去，也無風雨也無晴」—民國38年國軍遷臺紀事(30).json =====
# {
#   "reference": [
#     "資料來源： 檔號：38/543.4/7421 檔案內容：陸軍各單位轉進臺灣經過報告書 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "資料來源： 檔號：38/541.6/7022 檔案內容：防衛臺灣空軍作戰計畫 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "資料來源： 檔號：38/541.4/6015 檔案內容：國軍作戰計畫 檔案來源機關：國防部史政編譯局檔 案管有機關：檔案管理局",
#     "檔案影像6-1、6-2 資料來源： 檔號：38/541.1/4010 檔案內容：臺灣澎湖保衛方案 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "參考資料：1.費正清主編、章建剛等譯。《劍橋中華民國史第二部》。上海市：上海人民出版社，民國81年。2.張玉法。《中國現代史》。臺北市：臺灣東華，民國77年。3.林桶法。《戰後中國的變局：以國民黨為中心的探討（1945-1949年）》。臺北市：臺灣商務，民國92年。",
#     "政府網站資料開放宣告|隱私權、著作權及資訊安全政策宣告 | 本局電子信箱"
#   ],
#   "metadata": [
#     {
#       "案名": null,
#       "檔號": "38/543.4/7421",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "陸軍各單位轉進臺灣經過報告書"
#     },
#     {
#       "案名": null,
#       "檔號": "38/541.6/7022",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "防衛臺灣空軍作戰計畫"
#     },
#     {
#       "案名": null,
#       "檔號": "38/541.4/6015",
#       "來源機關": "國防部史政編譯局檔 案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "國軍作戰計畫"
#     },
#     {
#       "案名": null,
#       "檔號": "38/541.1/4010",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "臺灣澎湖保衛方案"
#     }
#   ]
# }
#
# ===== 檔案名稱: 「威海衛」租借地的收回(42).json =====
# {
#   "reference": [
#     "參考資料：1.郭廷以，《近代中國史綱》，臺北市：曉園，民83。2.張玉法，《中國現代史》，臺北市：東華書局，民90。",
#     "檔案影像1 說明：「清光緒24年簽訂的〈中英議租威海衛專條〉抄本」 檔號：0011/002.6/5320。 案名：「威海衛收復案」 來源機關：國防部 管有機關：檔案管理局",
#     "檔案影像2 說明：「民國11年梁如皓咨文」 檔號：0011/002.6/5320。 案名：「威海衛收復案」 來源機關：國防部 管有機關：檔案管理局",
#     "檔案影像3 說明：「民國19年〈中英交收威海衛協定專約〉抄本」 檔號：0011/002.6/5320。案名：「威海衛收復案」 來源機關：國防部 管有機關：檔案管理局",
#     "檔案影像4 說明：「劉公島藍晒圖」 檔號：0012/570.39/3111 案名：「江陰要塞暨劉公葫蘆兩島圖」 來源機關：國防部 管有機關：檔案管理局",
#     "檔案影像5 說明：「葫蘆島藍晒圖」 檔號：0012/570.39/3111 案名：「江陰要塞暨劉公葫蘆兩島圖」 來源機關：國防部 管有機關：檔案管理局"
#   ],
#   "metadata": [
#     {
#       "案名": "「威海衛收復案」",
#       "檔號": "0011/002.6/5320。",
#       "來源機關": "國防部",
#       "管有機關": "檔案管理局"
#     },
#     {
#       "案名": "「威海衛收復案」",
#       "檔號": "0011/002.6/5320。",
#       "來源機關": "國防部",
#       "管有機關": "檔案管理局"
#     },
#     {
#       "案名": "「威海衛收復案」",
#       "檔號": "0011/002.6/5320。",
#       "來源機關": "國防部",
#       "管有機關": "檔案管理局"
#     },
#     {
#       "案名": "「江陰要塞暨劉公葫蘆兩島圖」",
#       "檔號": "0012/570.39/3111",
#       "來源機關": "國防部",
#       "管有機關": "檔案管理局"
#     },
#     {
#       "案名": "「江陰要塞暨劉公葫蘆兩島圖」",
#       "檔號": "0012/570.39/3111",
#       "來源機關": "國防部",
#       "管有機關": "檔案管理局"
#     }
#   ]
# }
#
# ===== 檔案名稱: 「快速」發展的年代：麥克阿瑟公路通車一甲子(203).json =====
# {
#   "reference": [
#     "圖1 麥克阿瑟公路建設計畫緣起 案名：修築台北市麥克阿塞公路 檔號：0053/3600401/0405 來源機關：總統府 管有機關：國家發展委員會檔案管理局",
#     "圖2 麥克阿瑟公路路線圖 案名：修築台北市麥克阿塞公路 檔號：0053/3600401/0405 來源機關：總統府 管有機關：國家發展委員會檔案管理局",
#     "圖3 麥克阿瑟公路通車典禮剪綵 案名：1964農復會照片 檔號：0053/0011/1來源機關：行政院新聞局 管有機關：國家發展委員會檔案管理局",
#     "圖4 公路局金馬號行駛於麥克阿瑟公路 案名：1964農復會照片 檔號：0053/0011/1來源機關：行政院新聞局 管有機關：國家發展委員會檔案管理局",
#     "圖5 麥克阿瑟公路通車暨第31號碼頭開放聯合簡報會 案名：1964農復會照片 檔號：0053/0011/1 來源機關：行政院新聞局 管有機關：國家發展委員會檔案管理局",
#     "圖6 麥克阿瑟公路車輛通行費票根 來源：林怡甄提供",
#     "圖7 麥克阿瑟公路管理站收費情形 案名：交通處及所屬單位組織 檔號：0054/T012.42/0040 來源機關：臺灣省政府 管有機關：國家發展委員會檔案管理局",
#     "圖8 麥克阿瑟公路管理站編制討論案 案名：交通處及所屬單位組織 檔號：0054/T012.42/0040 來源機關：臺灣省政府 管有機關：國家發展委員會檔案管理局",
#     "圖9 麥克阿瑟公路管理站編制表 案名：交通處及所屬單位組織 檔號：0054/T012.42/0040 來源機關：臺灣省政府 管有機關：國家發展委員會檔案管理局",
#     "圖10 「台灣省麥克阿瑟直達公路管理辦法」草案 案名：台灣省麥克阿瑟直達公路管理辦法 檔號：0056/1-1-13-3-1/15 來源機關：行政院 管有機關：國家發展委員會檔案管理局",
#     "圖11 「台灣省麥克阿瑟直達公路管理辦法」草案審議意見表 案名：台灣省麥克阿瑟直達公路管理辦法 檔號：0056/1-1-13-3-1/15 來源機關：行政院 管有機關：國家發展委員會檔案管理局",
#     "圖12 「台灣省麥克阿瑟直達公路管理辦法」擬予廢止 案名：台灣省麥克阿瑟直達公路管理辦法 檔號：0056/1-1-13-3-1/15 來源機關：行政院 管有機關：國家發展委員會檔案管理局",
#     "圖13 麥克阿瑟公路施工情形 案名：1964農復會照片 檔號：0053/0011/1 來源機關：行政院新聞局 管有機關：國家發展委員會檔案管理局",
#     "圖14 麥克阿瑟公路施工情形 案名：1964農復會照片 檔號：0053/0011/1 來源機關：行政院新聞局 管有機關：國家發展委員會檔案管理局",
#     "來源：林怡甄提供",
#     "歡迎透過國家檔案資訊網找尋更多屬於麥帥公路的歷史軌跡，也歡迎蒞臨本局參觀「奇蹟之島—1970-1980從開發到保育臺灣建設檔案特展」，尋訪更多有關我國建設的國家檔案。",
#     "國家檔案",
#     "機關服務",
#     "便民服務",
#     "國家檔案館",
#     "認識我們",
#     "政府網站資料開放宣告|隱私權、著作權及資訊安全政策宣告 | 本局電子信箱"
#   ],
#   "metadata": [
#     {
#       "案名": "修築台北市麥克阿塞公路",
#       "檔號": "0053/3600401/0405",
#       "來源機關": "總統府",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "修築台北市麥克阿塞公路",
#       "檔號": "0053/3600401/0405",
#       "來源機關": "總統府",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1964農復會照片",
#       "檔號": "0053/0011/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1964農復會照片",
#       "檔號": "0053/0011/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1964農復會照片",
#       "檔號": "0053/0011/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "交通處及所屬單位組織",
#       "檔號": "0054/T012.42/0040",
#       "來源機關": "臺灣省政府",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "交通處及所屬單位組織",
#       "檔號": "0054/T012.42/0040",
#       "來源機關": "臺灣省政府",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "交通處及所屬單位組織",
#       "檔號": "0054/T012.42/0040",
#       "來源機關": "臺灣省政府",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "台灣省麥克阿瑟直達公路管理辦法",
#       "檔號": "0056/1-1-13-3-1/15",
#       "來源機關": "行政院",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "台灣省麥克阿瑟直達公路管理辦法",
#       "檔號": "0056/1-1-13-3-1/15",
#       "來源機關": "行政院",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "台灣省麥克阿瑟直達公路管理辦法",
#       "檔號": "0056/1-1-13-3-1/15",
#       "來源機關": "行政院",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1964農復會照片",
#       "檔號": "0053/0011/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1964農復會照片",
#       "檔號": "0053/0011/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     }
#   ]
# }
#
# ===== 檔案名稱: 「日暮鄉關何處是」─「留越國軍」的返台路(31).json =====
# {
#   "reference": [
#     "檔案影像1-1、1-2 資料來源： 檔號：0038/0640/7760 檔案內容：「留越國軍處理案」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "檔案影像2-1、2-2 資料來源： 檔號：0038/0640/7760 檔案內容：「留越國軍處理案」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "檔案影像3-1、3-2 資料來源： 檔號：0038/0640/7760 檔案內容：「留越國軍處理案」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "檔案影像 資料來源： 檔號：0038/0420/3410 檔案內容：「對入越國軍宣慰支援及與法方交涉接運回國經過」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "檔案影像5-1、5-2 資料來源： 檔號：0038/0420/3410 檔案內容：「對入越國軍宣慰支援及與法方交涉接運回國經過」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "檔案影像6 資料來源： 檔號：0038/0420/3410 檔案內容：「對入越國軍宣慰支援及與法方交涉接運回國經過」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "檔案影像7-1、7-2 資料來源： 檔號：0038/0640/7760 檔案內容：「留越國軍處理案」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "檔案影像7-3、7-4 資料來源： 檔號：0038/0640/7760 檔案內容：「留越國軍處理案」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "檔案影像8 資料來源： 檔號：0038/0640/7760 檔案內容：「留越國軍處理案」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "檔案影像9 資料來源： 檔號：0038/0640/7760 檔案內容：「留越國軍處理案」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "檔案影像10-1、10-2 資料來源： 檔號：0038/0640/7760 檔案內容：「留越國軍處理案」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "檔案影像11-1、11-2 資料來源： 檔號：0038/0420/3410 檔案內容：「對入越國軍宣慰支援及與法方交涉接運回國經過」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "參考資料",
#     "1.張世瑛、葉健?主訪。《不再流浪的孤軍:忠貞新村訪談錄》。新店市：國史館，民國91年。2.黃翔瑜訪談。《留越軍民訪談錄（一）、（二）》。新店市：國史館，民國：96年。",
#     "桂越邊區匪我態勢要圖（民國38年12月上旬）",
#     "資料來源： 檔號：0038/0640/7760 檔案內容：「留越國軍處理案」 檔案來源機關：國防部史政編譯局 檔案管有機關：檔案管理局",
#     "政府網站資料開放宣告|隱私權、著作權及資訊安全政策宣告 | 本局電子信箱"
#   ],
#   "metadata": [
#     {
#       "案名": null,
#       "檔號": "0038/0640/7760",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「留越國軍處理案」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0640/7760",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「留越國軍處理案」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0640/7760",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「留越國軍處理案」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0420/3410",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「對入越國軍宣慰支援及與法方交涉接運回國經過」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0420/3410",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「對入越國軍宣慰支援及與法方交涉接運回國經過」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0420/3410",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「對入越國軍宣慰支援及與法方交涉接運回國經過」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0640/7760",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「留越國軍處理案」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0640/7760",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「留越國軍處理案」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0640/7760",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「留越國軍處理案」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0640/7760",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「留越國軍處理案」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0640/7760",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「留越國軍處理案」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0420/3410",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「對入越國軍宣慰支援及與法方交涉接運回國經過」"
#     },
#     {
#       "案名": null,
#       "檔號": "0038/0640/7760",
#       "來源機關": "國防部史政編譯局 檔案",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「留越國軍處理案」"
#     }
#   ]
# }
#
# ===== 檔案名稱: 「賽德克．巴萊」重現的霧社事件(17).json =====
# {
#   "reference": [
#     "檔案管有機關：檔案管理局檔案 來源機關：內政部警政署 檔案內容：查復霧社事件及日人治台暴行由 檔號：0035/068.2/3/1/003",
#     "參考資料：1.中央社霧社事件，“行政院文化建設委員會國家文化資料庫知識管理系統” (民97年11月3日)。2.劉映蘭，”PChome新聞網”民97年9月22中廣新聞 ”(民97年11月3日)。3.郭弘斌，”台灣海外網-台灣人的台灣史”(民97年11月3日)。",
#     "政府網站資料開放宣告|隱私權、著作權及資訊安全政策宣告 | 本局電子信箱"
#   ],
#   "metadata": [
#     {
#       "案名": null,
#       "檔號": "0035/068.2/3/1/003",
#       "來源機關": "內政部警政署",
#       "管有機關": "檔案管理局檔案",
#       "檔案內容": "查復霧社事件及日人治台暴行由"
#     }
#   ]
# }
#
# ===== 檔案名稱: 「醫者仁也‧仁者人也」─光復初期臺灣醫學教育(29).json =====
# {
#   "reference": [
#     "參考資料：1.小田俊郎著、洪有錫譯。《臺灣醫學五十年》。臺北市：前衛，民國84年。2.陳永興。《臺灣醫療發展史》。臺北市：月旦，民國86年。3.莊永明。《臺灣醫療史：以臺大醫院為主軸》。臺北市：遠流，民國87年。",
#     "資料來源：檔案管有機關：檔案管理局 檔案來源機關：教育部 檔案內容：各省市醫學衛生教育-臺灣省。 檔號：36/醫拾壹41/1。",
#     "資料來源：檔案管有機關：檔案管理局 檔案來源機關：教育部 檔案內容：各省市醫學衛生教育-臺灣省。 檔號：36/醫拾壹41/1。",
#     "資料來源：檔案管有機關：檔案管理局 檔案來源機關：教育部 檔案內容：各省市醫學衛生教育-臺灣省。 檔號：36/醫拾壹41/1。",
#     "資料來源：檔案管有機關：檔案管理局 檔案來源機關：教育部 檔案內容：各省市醫學衛生教育-臺灣省。 檔號：36/醫拾壹41/1。",
#     "資料來源：檔案管有機關：檔案管理局 檔案來源機關：教育部 檔案內容：「醫學教育總卷視導」。 檔號：38/醫壹12/1。",
#     "資料來源：檔案管有機關：檔案管理局 檔案來源機關：教育部 檔案內容：「醫學教育總卷視導」。 檔號：38/醫壹12/1。",
#     "資料來源：檔案管有機關：檔案管理局 檔案來源機關：教育部 檔案內容：「醫學教育總卷視導」。 檔號：38/醫壹12/1。",
#     "資料來源：檔案管有機關：檔案管理局 檔案來源機關：教育部 檔案內容：留日及返台學生處理辦法案。 檔號：37/075.34/1。",
#     "資料來源：檔案管有機關：檔案管理局 檔案來源機關：教育部 檔案內容：留日及返台學生處理辦法案。 檔號：37/075.34/1。",
#     "參考資料：1.小田俊郎著、洪有錫譯。《臺灣醫學五十年》。臺北市：前衛，民國84年。2.陳永興。《臺灣醫療發展史》。臺北市：月旦，民國86年。3.莊永明。《臺灣醫療史：以臺大醫院為主軸》。臺北市：遠流，民國87年。",
#     "政府網站資料開放宣告|隱私權、著作權及資訊安全政策宣告 | 本局電子信箱"
#   ],
#   "metadata": [
#     {
#       "案名": null,
#       "檔號": "36/醫拾壹41/1。",
#       "來源機關": "教育部",
#       "管有機關": "檔案管理局",
#       "檔案內容": "各省市醫學衛生教育-臺灣省。"
#     },
#     {
#       "案名": null,
#       "檔號": "36/醫拾壹41/1。",
#       "來源機關": "教育部",
#       "管有機關": "檔案管理局",
#       "檔案內容": "各省市醫學衛生教育-臺灣省。"
#     },
#     {
#       "案名": null,
#       "檔號": "36/醫拾壹41/1。",
#       "來源機關": "教育部",
#       "管有機關": "檔案管理局",
#       "檔案內容": "各省市醫學衛生教育-臺灣省。"
#     },
#     {
#       "案名": null,
#       "檔號": "36/醫拾壹41/1。",
#       "來源機關": "教育部",
#       "管有機關": "檔案管理局",
#       "檔案內容": "各省市醫學衛生教育-臺灣省。"
#     },
#     {
#       "案名": null,
#       "檔號": "38/醫壹12/1。",
#       "來源機關": "教育部",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「醫學教育總卷視導」。"
#     },
#     {
#       "案名": null,
#       "檔號": "38/醫壹12/1。",
#       "來源機關": "教育部",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「醫學教育總卷視導」。"
#     },
#     {
#       "案名": null,
#       "檔號": "38/醫壹12/1。",
#       "來源機關": "教育部",
#       "管有機關": "檔案管理局",

#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "美援雜卷",
#       "檔號": "0037/471/0058",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "美援雜卷",
#       "檔號": "0037/471/0058",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "按美四八〇公法項下商訂剩餘農產品協定",
#       "檔號": "0045/473.1/18",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "按美四八〇公法項下商訂剩餘農產品協定",
#       "檔號": "0045/473.1/19",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "美援問題剪報",
#       "檔號": "0052/470/41",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1964農復會照片",
#       "檔號": "0053/0011/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "福利其他",
#       "檔號": "0040/A總185A",
#       "來源機關": "臺灣菸酒股份有限公司臺北菸廠",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "福利其他",
#       "檔號": "0040/A總185A",
#       "來源機關": "臺灣菸酒股份有限公司臺北菸廠",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1966農復會照片",
#       "檔號": "0055/0013/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "乳品工業",
#       "檔號": "0067/P-8.3.4/01",
#       "來源機關": "行政院經濟建設委員會",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1957農復會照片；",
#       "檔號": "0046/0004/1；",
#       "來源機關": "行政院新聞局；",
#       "管有機關": "國家發展委員會檔案管理局。"
#     }
#   ]
# }
#
# ===== 檔案名稱: 一紙命令，臺灣命運大不同─中國台灣省行政長官公署警備總司令部第一號令(1).json =====
# {
#   "file_id": [
#     "1"
#   ],
#   "filename": [
#     "一紙命令，臺灣命運大不同─中國台灣省行政長官公署警備總司令部第一號令(1).html"
#   ],
#   "titles": [
#     "一紙命令，臺灣命運大不同─中國台灣省行政長官公署警備總司令部第一號令"
#   ],
#   "intro": [
#     "民國34年10月25日陳儀以行政長官兼警備總司令的身分對日將安藤利吉下署部字第一號令，是日起，台灣、澎湖脫離了日本帝國殖民管轄。"
#   ],
#   "author": [
#     "◎資料蒐集：應用服務組"
#   ],
#   "articles": [
#     "依據民國32年所發表的開羅宣言，日本應無條件投降並將台灣、澎湖群島歸還中國。因此，國民政府乃於民國33年5月在中央設計局之下設立台灣調查委員會，做為戰後接收台灣之準備。民國34年8月29日，國民政府特任陳儀為台灣省行政長官，負台灣接收及軍政全責；9月7日，政府又任命陳儀兼任台灣省警備總司令。",
#     "民國34年10月24日台灣省行政長官陳儀抵台，翌日在台北公會堂(今中山堂)主持接受日軍受降典禮。同日陳儀以行政長官兼警備總司令的身分對日將安藤利吉下署部字第一號令，指出9月9日日本已無條件投降，陳儀與其所指定的部隊及行政人員將要接受台灣、澎湖列島地區日本陸海空軍及其輔助部隊之投降，併接收台灣、澎湖列島之領土、人民治權、軍政設施及資產。"
#   ],
#   "reference": [
#     "政府網站資料開放宣告|隱私權、著作權及資訊安全政策宣告 | 本局電子信箱"
#   ],
#   "published_date": "2007/7/16",
#   "URL": "https://www.archives.gov.tw/wSite/public/Attachment/0/f1718088731347.pdf"
# }
#
# ===== 檔案名稱: 不用手機也可哈拉一整天─45年度公用電話擴充計畫(2).json =====
# {
#   "reference": [
#     "檔案來源機關：中華電信股份有限公司 案名：擴充公用電話計畫案 檔號：0044/C14/000002/0001/002",
#     "檔案來源機關：中華電信股份有限公司 案名：我國投幣式公用電話概略 檔號：0048/C14/000004/0001/001",
#     "※註部分資料來自中華電信網站(http://www.cht.com.tw)，檔案管理局目前管有之中華電信檔案，最早之檔案產生年代為民國38年。",
#     "政府網站資料開放宣告|隱私權、著作權及資訊安全政策宣告 | 本局電子信箱"
#   ],
#   "metadata": [
#     {
#       "案名": "擴充公用電話計畫案",
#       "檔號": "0044/C14/000002/0001/002",
#       "來源機關": "中華電信股份有限公司"
#     },
#     {
#       "案名": "我國投幣式公用電話概略",
#       "檔號": "0048/C14/000004/0001/001",
#       "來源機關": "中華電信股份有限公司"
#     }
#   ]
# }
#
# ===== 檔案名稱: 不能少了你—臺灣光復後首次戶口清查(35).json =====
# {
#   "reference": [
#     "參考資料：1.〈民政處增設戶籍科〉。《民報》(民35年3月31日，第二版)。",
#     "2.《臺灣行政長官公署三月來工作概要》（民34年10月25日至35年1月24日）。台北市：行政長官公署，民35。",
#     "檔案影像1  檔號：0035/065.2/13/1/005 檔案內容：「原有我國國籍之臺灣人民自三十四年十月二十五日起一律恢復國籍由」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像2-1  檔號：35/065.2/11/1/002 檔案內容：「台灣省人民回復原有姓名辦法案」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像2-2  檔號：35/065.2/11/1/002 檔案內容：「臺灣省人民回復原有姓名辦法案」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像2-3  檔號：35/065.2/11/1/002 檔案內容：「臺灣省人民回復原有姓名辦法案」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像3-1  檔號：36/073.7/3/1/030 檔案內容：「為轉發現行戶政法規三種希知照由」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像3-2  檔號：36/073.7/3/1/030 檔案內容：「為轉發現行戶政法規三種希知照由」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像3-3  檔號：36/073.7/3/1/030 檔案內容：「為轉發現行戶政法規三種希知照由」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像4-1  檔號：36/073.7/3/1/001 檔案內容：「為檢送本省縣市各級辦理戶籍登記辦請核備由」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像4-2  檔號：36/073.7/3/1/001 檔案內容：「為檢送本省縣市各級辦理戶籍登記辦請核備由」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像5-1  檔號：36/073.7/3/2/002 檔案內容：「函送戶籍法施行細則及附表由」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像5-2  檔號：36/073.7/3/2/002 檔案內容：「函送戶籍法施行細則及附表由」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像：6-1  檔號：36/073.7/3/2/018 檔案內容：「為送本縣解答戶政法令條文(第一期)請核示由」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局",
#     "檔案影像：6-2  檔號：36/073.7/3/2/018 檔案內容：「為送本縣解答戶政法令條文(第一期)請核示由」 來源機關：臺灣省文獻委員會  管有機關：檔案管理局"
#   ],
#   "metadata": [
#     {
#       "案名": null,
#       "檔號": "0035/065.2/13/1/005",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「原有我國國籍之臺灣人民自三十四年十月二十五日起一律恢復國籍由」"
#     },
#     {
#       "案名": null,
#       "檔號": "35/065.2/11/1/002",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「台灣省人民回復原有姓名辦法案」"
#     },
#     {
#       "案名": null,
#       "檔號": "35/065.2/11/1/002",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「臺灣省人民回復原有姓名辦法案」"
#     },
#     {
#       "案名": null,
#       "檔號": "35/065.2/11/1/002",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「臺灣省人民回復原有姓名辦法案」"
#     },
#     {
#       "案名": null,
#       "檔號": "36/073.7/3/1/030",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「為轉發現行戶政法規三種希知照由」"
#     },
#     {
#       "案名": null,
#       "檔號": "36/073.7/3/1/030",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「為轉發現行戶政法規三種希知照由」"
#     },
#     {
#       "案名": null,
#       "檔號": "36/073.7/3/1/030",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「為轉發現行戶政法規三種希知照由」"
#     },
#     {
#       "案名": null,
#       "檔號": "36/073.7/3/1/001",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「為檢送本省縣市各級辦理戶籍登記辦請核備由」"
#     },
#     {
#       "案名": null,
#       "檔號": "36/073.7/3/1/001",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「為檢送本省縣市各級辦理戶籍登記辦請核備由」"
#     },
#     {
#       "案名": null,
#       "檔號": "36/073.7/3/2/002",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「函送戶籍法施行細則及附表由」"
#     },
#     {
#       "案名": null,
#       "檔號": "36/073.7/3/2/002",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「函送戶籍法施行細則及附表由」"
#     },
#     {
#       "案名": null,
#       "檔號": "36/073.7/3/2/018",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「為送本縣解答戶政法令條文(第一期)請核示由」"
#     },
#     {
#       "案名": null,
#       "檔號": "36/073.7/3/2/018",
#       "來源機關": "臺灣省文獻委員會",
#       "管有機關": "檔案管理局",
#       "檔案內容": "「為送本縣解答戶政法令條文(第一期)請核示由」"
#     }
#   ]
# }
#
# ===== 檔案名稱: 世界人權日(18).json =====
# {
#   "reference": [
#     "檔案管有機關：檔案管理局檔案來源機關：總統府檔案內容：紐約國際人權聯盟對政府考慮逮捕美麗島事件3位領導者來函表達關切檔號：0067/3150901/1-005/1/003",
1 來源機關：行政院新聞局 管有機關：國家發展委員會檔案管理局",
#     "圖16 臺灣新生報社長參加華航環球線首航案名：出國參加各種活動 檔號：0057/A028-1(3)/01 來源機關：台灣新生報 管有機關：國家發展委員會檔案管理局",
#     "王洸。《開國六十年交通史論》。臺北市：作者自印，民60。林玉萍。《臺灣航空工業史：戰爭羽翼下的1935年～1979年》。臺北市：新銳文創，民100。交通部等。《世紀交通─運輸重要檔案專題選輯》。臺北市：檔案管理局，民102。衣復恩。《我的回憶》。臺北市：財團法人立青文教基金會，民100。曾建華。《風雨華航：華航從間諜公司崛起祕辛》。臺北市：臺灣壹傳媒，民91。林佩莉。〈再現東方之龍：中華航空〉。未出版之碩士論文，國立清華大學科技管理學院科技管理研究所，民106年張源傑。〈開放天空政策對我國航空事業之影響〉。未出版之碩士論文，東吳法律研究所，民89年。中華航空。〈公司沿革〉，https://www.china-airlines.com/tw/zh/about-us/history(民109年2月3日檢索)。交通部民用航空局。〈航空運輸專論〉，https://www.caa.gov.tw/article.aspx?a=863&lang=1(民109年2月3日檢索)。維基百科。〈中華航空〉，https://zh.wikipedia.org/wiki/%E4%B8%AD%E8%8F%AF%E8%88%AA%E7%A9%BA(民109年2月3日檢索)。",
#     "國家發展委員會檔案管理局典藏豐富國家檔案，歡迎透過國家檔案資訊網，探尋華航發展的歷程。"
#   ],
#   "metadata": [
#     {
#       "案名": "國建六年計畫、捷運、北二高、石化工業、機場",
#       "檔號": "0065/2026/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "駐港中國中央兩航空公司叛變案",
#       "檔號": "0065/2026/1",
#       "來源機關": "國防部史政編譯局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "其他-兩航公司叛變善後處理",
#       "檔號": "0038/050105/014/0001/001",
#       "來源機關": "交通部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "中寮（寮國）空運臨時協定",
#       "檔號": "0045/606.32/12",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "中寮（寮國）空運臨時協定",
#       "檔號": "0045/606.32/12",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "華航開闢國際航線",
#       "檔號": "0054/31709/0004/001/040",
#       "來源機關": "總統府",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "華航開闢國際航線",
#       "檔號": "0054/31709/0004/001/050",
#       "來源機關": "總統府",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "公路、機場、港口",
#       "檔號": "0058/0042/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "出國參加各種活動",
#       "檔號": "0067/2011/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "體育活動(運動會、區運、棒球賽)",
#       "檔號": "0060/0069/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "戲劇(國劇、平劇)、布袋戲、皮影戲",
#       "檔號": "0060/0091/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "東亞、中東、中美洲外交專輯",
#       "檔號": "0055/0036/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "陸、海、空軍",
#       "檔號": "0052/0049/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "公路、機場、港口",
#       "檔號": "0058/0042/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "公路、機場、港口",
#       "檔號": "0058/0042/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "親子活動、立法院議場外觀、區運、選舉活動",
#       "檔號": "0084/0058/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "出國參加各種活動",
#       "檔號": "0057/A028-1(3)/01",
#       "來源機關": "台灣新生報",
#       "管有機關": "國家發展委員會檔案管理局"
#     }
#   ]
# }
#
# ===== 檔案名稱: 九年國教：春風化雨五十載(134).json =====
# {
#   "reference": [
#     "臺中縣立豐原國民中學 案名：1969農復會照片 檔號：0058/0016/1 來源機關：行政院新聞局 管有機關：國家發展委員會檔案管理局",
#     "圖1 民國28年教育部擬具國民教育實施綱要 案名：國民小學章則規程檔號：0028/301.00/0001 來源機關：教育部 典藏機關：國家發展委員會檔案管理局",
#     "圖2 新竹縣關西鎮石光國民學校 案名：SP農復會照片檔號：0041/0021/1來源機關：行政院新聞局 典藏機關：國家發展委員會檔案管理局",
#     "圖3 九年國民教育實施綱要 案名：九年國民教育實施綱要檔號：0056/11992-151017/00001 來源機關：經濟部 典藏機關：國家發展委員會檔案管理局",
家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1970農復會照片",
#       "檔號": "0059/0017/1",
#       "來源機關": "行政院新聞局 典藏機關：國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "國民教育法",
#       "檔號": "0057/2081502/0003",
#       "來源機關": "總統府 典藏機關：國家發展委員會檔案管理局"
#     }
#   ]
# }
#
# ===== 檔案名稱: 亞東關係協會：臺日友好關係的樞紐(185).json =====
# {
#   "reference": [
#     "圖1 舊金山和約 案名：對日和約（台日貿易協定）（日韓臨時航空協定）  檔號：0039/412.6/69 來源機關：外交部 管有機關：國家發展委員會檔案管理局",
#     "圖2 中日和平條約 案名：對日和約 檔號：0040/713.1/52 來源機關：外交部 管有機關：國家發展委員會檔案管理局",
#     "圖3 岸信介(前排左三)訪臺 案名：金鐘獎、外交、劇照翻拍 檔號：0067/0035/1 來源機關：行政院新聞局 管有機關：國家發展委員會檔案管理局",
#     "圖4 亞東關係協會協助臺日學術合作 案名：中日學校締盟暨交流 檔號：0072/050.4/90001 來源機關：外交部 管有機關：國家發展委員會檔案管理局",
#     "圖5 亞東關係協會與財團法人交流協會互設駐外辦事處協議書 案名：司法行政法令 檔號：0076/609/89001 來源機關：外交部 管有機關：國家發展委員會檔案管理局",
#     "圖6 亞東關係協會東京辦事處來函 案名：中日空運協定檔號：0054/606.3/89005 來源機關：外交部 管有機關：國家發展委員會檔案管理局",
#     "圖7 中華航空公司 案名：公路、機場、港口 檔號：0058/0042/1 來源機關：行政院新聞局 管有機關：國家發展委員會檔案管理局",
#     "圖8 我政府處理中日航線問題之基本立場 案名：中日空運協定 檔號：0054/606.3/89005 來源機關：外交部 管有機關：國家發展委員會檔案管理局",
#     "國家發展委員會檔案管理局典藏臺灣與日本往來的歷史紀錄，其中不乏亞東關係協會維繫雙邊關係的努力，歡迎從國家檔案資訊網檢索、查詢，一同探尋臺日交流的軌跡。",
#     "國家檔案",
#     "機關服務",
#     "便民服務",
#     "國家檔案館",
#     "認識我們",
#     "政府網站資料開放宣告|隱私權、著作權及資訊安全政策宣告 | 本局電子信箱"
#   ],
#   "metadata": [
#     {
#       "案名": "對日和約（台日貿易協定）（日韓臨時航空協定）",
#       "檔號": "0039/412.6/69",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "對日和約",
#       "檔號": "0040/713.1/52",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "金鐘獎、外交、劇照翻拍",
#       "檔號": "0067/0035/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "中日學校締盟暨交流",
#       "檔號": "0072/050.4/90001",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "司法行政法令",
#       "檔號": "0076/609/89001",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "中日空運協定",
#       "檔號": "0054/606.3/89005",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "公路、機場、港口",
#       "檔號": "0058/0042/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "中日空運協定",
#       "檔號": "0054/606.3/89005",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     }
#   ]
# }
#
# ===== 檔案名稱: 人民頭家—公民直選總統(23).json =====
# {
#   "reference": [
#     "檔案影像1 資料來源：檔案管有機關：國家發展委員會檔案管理局 檔案來源機關：國民大會檔案內容：馮定國函陳對總統選舉方式建議。 檔號：0081/525/1/1-11/134",
#     "檔案影像2 資料來源：檔案管有機關：國家發展委員會檔案管理局 檔案來源機關：國民大會檔案內容：公布憲法增修條文第十一條至十八條全文。 檔號：0081/513/1/1-1/007",
#     "檔案影像3 資料來源：檔案管有機關：國家發展委員會檔案管理局 檔案來源機關：國民大會檔案內容：溫錫金有關總統選舉、公民投票入憲國是建言(第34次大會)。 檔號：0086/525/1/1-19/202",
#     "參考資料1.《國民大會憲政國家檔案目錄選編》。台北市：檔案管理局，民94。2.《時代輪廓嶄新與蛻變的歷程-國民大會修憲檔案專題選輯》。台北市：檔案管理局，民97。",
#     "資料來源：檔案管有機關：國家發展委員會檔案管理局 檔案來源機關：國民大會 檔案內容：馮定國函陳對總統選舉方式建議。 檔號：0081/525/1/1-11/134",
#     "政府網站資料開放宣告|隱私權、著作權及資訊安全政策宣告 | 本局電子信箱",
#     "總統直選乃重大憲政改革工作之一環，可從國民大會修憲檔案一探究竟，為促進國民大會檔案之開放應用，本局陸續編輯出版「國民大會憲政國家檔案目錄選編」、「國民大會憲政國家檔案導引」及「時代輪廓嶄新與蛻變的歷程-國民大會修憲檔案專題選輯」等，並舉辦「中華民國憲政檔案展」，同時於虛擬檔案館(網址http://theme.archives.gov.tw/)設置「國民大會」主題檔案區，歡迎各界查考應用。"
#   ],
#   "metadata": [
#     {
#       "案名": null,
#       "檔號": "0081/525/1/1-11/134",
#       "來源機關": "國民大會",
#       "管有機關": "國家發展委員會檔案管理局",
#       "檔案內容": "馮定國函陳對總統選舉方式建議。"
#     },
#     {
#       "案名": null,
#       "檔號": "0081/513/1/1-1/007",
#       "來源機關": "國民大會",
#       "管有機關": "國家發展委員會檔案管理局",
#       "檔案內容": "公布憲法增修條文第十一條至十八條全文。"
#     },
#     {
#       "案名": null,
#       "檔號": "0086/525/1/1-19/202",
#       "來源機關": "國民大會",
#       "管有機關": "國家發展委員會檔案管理局",
#       "檔案內容": "溫錫金有關總統選舉、公民投票入憲國是建言(第34次大會)。"
#     },
#     {
#       "案名": null,
#       "檔號": "0081/525/1/1-11/134",
#       "來源機關": "國民大會",
#       "管有機關": "國家發展委員會檔案管理局",
#       "檔案內容": "馮定國函陳對總統選舉方式建議。"
#     }
#   ]
# }
#
# ===== 檔案名稱: 任重道遠─民國36年台灣省鐵路圖(11).json =====
# {
#   "file_id": [
#     "11"
#   ],
#   "filename": [
#     "任重道遠─民國36年台灣省鐵路圖(11).html"
#   ],
#   "titles": [
#     "任重道遠─民國36年台灣省鐵路圖"
#   ],
#   "intro": [
# ...
#     "維基百科，調景嶺(2019年10月28日)。檢自https://zh.wikipedia.org/wiki/%E8%AA%BF%E6%99%AF%E5%B6%BA(2019年12月12日)多維新聞，調景嶺：湮沒於香港的「小台灣」(2016)。檢自https://duoweicn.dwnews.com/CN-2016%E5%B9%B407%E6%9C%9F/10003413.html(2019年12月13日)楊孟軒(民100)。調景嶺：香港「小臺灣」的起源與變遷，1950-1970年代。臺灣史研究，18(1)，133-183。薛月順(民90)。臺灣入境管制初探—以民國38年陳誠擔任省主席時期為例。國史館學術集刊，1，225-256。林芝諺(民98)。冷戰下中華民國的難民政策—以香港調景嶺營難民為中心的討論（1950-1961）(電子檔)。國立臺灣師範大學歷史學系，臺北市。http://rportal.lib.ntnu.edu.tw/bitstream/20.500.12235/95454/1/n069422019701.pdf。",
#     "若您想瞭解更多調景嶺的故事，歡迎至國家檔案資訊網檢索、查詢。"
#   ],
#   "metadata": [
#     {
#       "案名": "調景嶺難民",
#       "檔號": "0046/599/5",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名":
1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "原住民、民俗節目",
#       "檔號": "0052/0077/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "採購物品",
#       "檔號": "0039/A總184A/1",
#       "來源機關": "臺灣菸酒股份有限公司臺北菸廠",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "SP農復會照片",
#       "檔號": "0041/0021/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "SP農復會照片",
#       "檔號": "0041/0021/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "應送美方年度物資需要量表",
#       "檔號": "0040/432.2/314",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "養殖、林 業",
#       "檔號": "0066/0054/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1952-1954農復會照片",
#       "檔號": "0041/0001/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "農業發展、畜牧業、林業、造紙、石化、塑膠、造船、航空、汽車工業",
#       "檔號": "0065/0057/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1960農復會照片",
#       "檔號": "0049/0007/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1959農復會照片",
#       "檔號": "0048/0006/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1959農復會照片",
#       "檔號": "0048/0006/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1959農復會照片",
#       "檔號": "0048/0006/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1959農復會照片",
#       "檔號": "0048/0006/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1959農復會照片",
#       "檔號": "0048/0006/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1960農復會照片",
#       "檔號": "0049/0007/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1959農復會照片",
#       "檔號": "0048/0006/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1959農復會照片",
#       "檔號": "0048/0006/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1959農復會照片",
#       "檔號": "0048/0006/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "1959農復會照片",
#       "檔號": "0048/0006/1",
#       "來源機關": "行政院新聞局",
#       "管有機關": "國家發展委員會檔案管理局"
#     },
#     {
#       "案名": "鳳梨銷美供應僑商",
#       "檔號": "0061/432.32/0008",
#       "來源機關": "外交部",
#       "管有機關": "國家發展委員會檔案管理局"
#     }
#   ]
# }
#
# ===== 檔案名稱: 黑與白的精彩對弈—圍棋(74).json =====
# {
#   "reference": [
#     "圖1 棋盤來源:魏寶菊提供",
#     "圖2 圍棋來源:魏寶菊提供",
#     "圖3  檔號：0068/0409/001 案名：圍棋研究與推行 來源機關：國家文化總會  管有機關：檔案管理局",
#     "圖4  檔號:0068/0409/001 案名:圍棋研究與推行 來源機關:國家文化總會  管有機關:檔案管理局",
#     "圖5  檔號:0068/0409/001 案名:圍棋研究與推行 來源機關:國家文化總會  管有機關:檔案管理局",
#     "圖6 舉辦公務人員圍棋等棋藝比賽通知  檔號:0091/07/07-02 案名:人事一般業務 來源機關:行政院九二一震災災後重建推動委員會  管有機關:檔案管理局",
#     "圖7  檔號:0068/0409/001 案名:圍棋研究與推行 來源機關:國家文化總會  管有機關:檔案管理局",
#     "圖8 圍棋比賽情形  檔號:0061/001/027 案名:廠房設施、產品及外賓來訪、休閒娛樂等其它活動 來源機關:行政院國軍退除役官兵輔導委員會塑膠工廠  管有機關:檔案管理局",
#     "現今最強的電腦程式和頂尖的棋手對弈，仍互有勝負，可見圍棋令人著迷之處，歡迎您到國家檔案資訊網瞭解臺灣圍棋發展的歷程吧!"
#   ],
#   "metadata": [
#     {
#       "案名": "圍棋研究與推行",
#       "檔號": "0068/0409/001",
#       "來源機關": "國家文化總會",
#       "管有機關": "檔案管理局"
#     }
#   ]
# }

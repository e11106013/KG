# %% [markdown]
# ##### v3：tool function 可行版本

# %%
# 設定基本的 LLM 模型

from langchain_openai import ChatOpenAI
import os

# 設置 LLM 模型
os.environ["GROQ_API_KEY"] = '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'

llm = ChatOpenAI(
    openai_api_base="https://api.groq.com/openai/v1",
    openai_api_key=os.environ['GROQ_API_KEY'],
    model_name="llama-3.3-70b-versatile",
    #model_name="llama-3.2-3b-preview",        
    #model_name="llama-3.2-3b-preview",
    #model_name="mixtral-8x7b-32768",
    #model_name="llama-3.2-11b-vision-preview",
    #model_name="deepseek-r1-distill-qwen-32b",
    #model_name="deepseek-r1-distill-llama-70b",
    temperature=0.0,
  #  max_tokens=1000,
)

# %%
import re
from langchain_core.tools import tool
from langchain.agents import initialize_agent, AgentType
from langchain.agents import Tool
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import SystemMessage
import requests
from bs4 import BeautifulSoup  # 用於解析 HTML 格式

last_sparql_result = None

# === SPARQL Query Tool Function ===
def preprocess_sparql(query: str) -> str:
    # Remove unsupported SERVICE clause
    query = re.sub(r'SERVICE\s+wikibase:label\s*\{[^}]*\}', '', query, flags=re.IGNORECASE)
    # Add rdfs:label filter if not present
    if 'rdfs:label' not in query:
        query += '\nOPTIONAL { ?s rdfs:label ?label . FILTER(lang(?label) = "zh") }'
    # 基本格式檢查
    if 'SELECT' not in query.upper():
        query = f"SELECT * WHERE {{ {query} }}"
    return query.strip()

@tool("query_kg_tool", return_direct=True)
def query_kg_tool(sparql_query: str) -> str:
    """
    查詢本地 Virtuoso SPARQL endpoint，並回傳 JSON 格式的查詢結果摘要。
    輸入為 SPARQL 語句，會自動處理不支援語法與中文標籤補強。
    """
    global last_sparql_query
    print("大型語言產生的 SPARQL 查詢語句：\n", sparql_query)
    #cleaned_query = preprocess_sparql(sparql_query)
    #print("✅ 預處理後的 SPARQL 查詢語句：\n", cleaned_query)
    last_sparql_query = sparql_query
    
    endpoint = "http://192.168.133.39:8890/sparql"
    headers = {"Accept": "application/sparql-results+json"}
    params = {"query": sparql_query}
    try:
        response = requests.get(endpoint, headers=headers, params=params, timeout=10)
        response.raise_for_status()

        # 如果返回的是 HTML 格式，使用 BeautifulSoup 解析
        if "html" in response.headers["Content-Type"]:
            soup = BeautifulSoup(response.text, 'html.parser')
            rows = soup.find_all('tr')[1:]  # 排除表頭
            output = []
            for row in rows:
                cols = row.find_all('td')
                subject = cols[0].get_text()  # 主體
                predicate = cols[1].get_text()  # 關係
                object_ = cols[2].get_text()  # 客體
                output.append(f"Subject: {subject}, Predicate: {predicate}, Object: {object_}")
            return "\n".join(output)

        # 如果返回的是 JSON 格式
        results = response.json()
        bindings = results.get("results", {}).get("bindings", [])
        if not bindings:
            return "查無資料，請確認查詢條件或資料庫內容。"

        output = []
        for row in bindings:
            row_data = {k: v.get("value") for k, v in row.items()}
            output.append(str(row_data))

        #return "\n".join([f" {row}" for i, row in enumerate(output)])
        return "\n".join(output)
    except Exception as e:
        return f"查詢失敗，請確認 SPARQL 是否正確。錯誤：{str(e)}"

# === Tools List ===
tools = [
    query_kg_tool
]

# === Prompt Setup ===
system_prompt = """
你是一個智慧型知識查詢助理，所有問題都必須透過 query_kg_tool 工具查詢 RDF 知識圖譜，不能自己回答。
請將自然語言問題轉換成正確的 SPARQL 查詢後，使用 query_kg_tool 工具查詢。
請注意：
- 使用的 SPARQL endpoint 是本地 Virtuoso，不支援 Wikidata 特有語法如 SERVICE wikibase:label。
- 請使用標準 SPARQL 1.1 語法。
- 若要取得中文名稱，請使用 rdfs:label 並加入 FILTER(lang(?label) = \"zh\")。
"""

# === Initialize Agent ===
agent = initialize_agent(
    tools,
    llm,
    agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
    verbose=True,
    handle_parsing_errors=True,
    agent_kwargs={
        "system_message": SystemMessage(content=system_prompt)
    }
)
# Out:
# C:\Users\jwu048\AppData\Local\Temp\ipykernel_27064\3572526944.py:88: LangChainDeprecationWarning: LangChain agents will continue to be supported, but it is recommended for new use cases to be built with LangGraph. LangGraph offers a more flexible and full-featured framework for building agents, including support for tool-calling, persistence of state, and human-in-the-loop workflows. For details, refer to the `LangGraph documentation <https://langchain-ai.github.io/langgraph/>`_ as well as guides for `Migrating from AgentExecutor <https://python.langchain.com/docs/how_to/migrate_agent/>`_ and LangGraph's `Pre-built ReAct agent <https://langchain-ai.github.io/langgraph/how-tos/create-react-agent/>`_.
#   agent = initialize_agent(

# %%
# === Agent 使用示範 ===
question = "查詢與電影有關的文件"
#question = "查詢與228 事件相關的文件"
response = agent.run(question)
if not response:
    print("⚠️ 無查詢結果，請檢查 SPARQL 或語句。")
else:
    print("🔎 查詢回覆：", response)

#print("SPARQL 查詢語句：", last_sparql_query)
# Out:
# C:\Users\jwu048\AppData\Local\Temp\ipykernel_27064\2270069493.py:4: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = agent.run(question)
# > Entering new AgentExecutor chain...
# Thought: 我需要查詢與電影有關的文件，所以我應該使用SPARQL語句來查詢相關的資料。
#
# Action: query_kg_tool
# Action Input: SELECT ?s ?p ?o WHERE { ?s ?p ?o . FILTER CONTAINS(str(?s), "電影") }大型語言產生的 SPARQL 查詢語句：
#  SELECT ?s ?p ?o WHERE { ?s ?p ?o . FILTER CONTAINS(str(?s), "電影") }
#
# Observation: {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://xmlns.com/foaf/0.1/Document'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://xmlns.com/foaf/0.1/Document'}
# {'s': 'http://example.org/doc/「賽德克．巴萊」重現的霧社事件(17)#event_電影製作', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/大專集訓-成功嶺的甘苦回憶(133)#event_獲得電影金馬獎', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/礦山記憶：探索金瓜石百年歷史風華(191)#event_成為電影取材', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_重新設計金馬獎座', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_八七水災', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_成立電影事業輔導委員會', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_扶植電影事業', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_接受外界申請', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_第59屆頒獎典禮', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_興辦金馬獎', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_訂定獎勵國語影片辦法', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_電影事業輔導', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_頒令發展國語電影事業', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_頒發最佳演員特別獎', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_首屆金馬獎頒獎典禮', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍收復林厝', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍南下漸次占領福建沿海', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍強行登陸金門', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍渡海占領金門意圖明顯', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍規劃從大金門登陸', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍規劃登陸金門', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍設計臺語會話範本', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_加強臺灣本島防禦措施', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_古寧頭戰史館', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_古寧頭戰役', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_古寧頭戰役結束', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_固守舟山群島及金門島', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國共內戰', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍兵力分布', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍反擊', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍收復古寧頭', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_徵兵防守', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_政府派遣第22兵團負責大、小金門防務', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_政府重視金門防務', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_李光前陣亡', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_第19軍從汕頭抵達金門', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_設防佈雷', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_金門發展出特有的戰地文化', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_金門陷入三面包圍', 'p': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'o': 'http://example.org/schema#Event'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://creativecommons.org/ns#attributionURL', 'o': 'https://www.archives.gov.tw'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://creativecommons.org/ns#attributionURL', 'o': 'https://www.archives.gov.tw'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://purl.org/dc/elements/1.1/creator', 'o': '國家發展委員會檔案管理局企劃組視察朱育萱'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://purl.org/dc/elements/1.1/creator', 'o': '檔案管理局應用服務組研究員馬有成'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://purl.org/dc/elements/1.1/date', 'o': '2022-09-16'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://purl.org/dc/elements/1.1/date', 'o': '2010-04-16'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://purl.org/dc/elements/1.1/identifier', 'o': 'https://www.archives.gov.tw/wSite/public/Attachment/0/f1717473054705.pdf'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://purl.org/dc/elements/1.1/identifier', 'o': 'https://www.archives.gov.tw/wSite/public/Attachment/0/f1718084189735.pdf'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://purl.org/dc/elements/1.1/title', 'o': '金馬獎：一甲子的臺灣電影事業'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://purl.org/dc/elements/1.1/title', 'o': '電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://purl.org/dc/terms/rights', 'o': '本資料依據創用 CC 姓名標示-非商業性 3.0 授權條款釋出'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://purl.org/dc/terms/rights', 'o': '本資料依據創用 CC 姓名標示-非商業性 3.0 授權條款釋出'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://creativecommons.org/ns#attributionName', 'o': '檔案管理局'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://creativecommons.org/ns#attributionName', 'o': '檔案管理局'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://creativecommons.org/ns#license', 'o': 'http://creativecommons.org/licenses/by-nc/3.0/'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://creativecommons.org/ns#license', 'o': 'http://creativecommons.org/licenses/by-nc/3.0/'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://example.org/relatedFile', 'o': '_:b-1023628210763537075'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://example.org/relatedFile', 'o': '_:b-1240860313163385962'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://example.org/relatedFile', 'o': '_:b-6634531970373587085'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://example.org/relatedFile', 'o': '_:b4408123814379868784'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://example.org/relatedFile', 'o': '_:b4838097991098076112'}
# {'s': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json', 'p': 'http://example.org/relatedFile', 'o': '_:b6942451437138544592'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://example.org/relatedFile', 'o': '_:b-3701037564213273946'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://example.org/relatedFile', 'o': '_:b-8559794070639337164'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://example.org/relatedFile', 'o': '_:b1993252809891308114'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://example.org/relatedFile', 'o': '_:b5295509559759788347'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://example.org/relatedFile', 'o': '_:b5838819992436036773'}
# {'s': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json', 'p': 'http://example.org/relatedFile', 'o': '_:b628713585856492369'}
# {'s': 'http://example.org/doc/「賽德克．巴萊」重現的霧社事件(17)#event_電影製作', 'p': 'http://www.w3.org/2000/01/rdf-schema#comment', 'o': '事件
 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import networkx as nx
import plotly.graph_objects as go
import plotly.io as pio

pio.renderers.default = 'browser'

# 提取 URI 中的標籤
def extract_label(uri):
    if uri.startswith("http"):
        return uri.rsplit("/", 1)[-1]
    return uri
# 顯示簡短URI
def simplify_uri(uri):
    if '#' in uri:
        return uri.split('#')[-1]
    else:
        return uri.rstrip('/').split('/')[-1]

sparql = SPARQLWrapper("http://192.168.133.39:8890/sparql")
#sparql.setQuery("""
#PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> SELECT ?s ?p ?o WHERE { ?s ?p ?o . FILTER (regex(str(?s), "228事件")) }
#""")

sparql.setQuery(last_sparql_query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/Document'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/Document'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/「賽德克．巴萊」重現的霧社事件(17)#event_電影製作'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/大專集訓-成功嶺的甘苦回憶(133)#event_獲得電影金馬獎'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/礦山記憶：探索金瓜石百年歷史風華(191)#event_成為電影取材'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_重新設計金馬獎座'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_八七水災'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_成立電影事業輔導委員會'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_扶植電影事業'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_接受外界申請'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_第59屆頒獎典禮'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_興辦金馬獎'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_訂定獎勵國語影片辦法'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_電影事業輔導'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_頒令發展國語電影事業'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_頒發最佳演員特別獎'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_首屆金馬獎頒獎典禮'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍收復林厝'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍南下漸次占領福建沿海'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍強行登陸金門'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍渡海占領金門意圖明顯'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍規劃從大金門登陸'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍規劃登陸金門'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍設計臺語會話範本'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_加強臺灣本島防禦措施'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_古寧頭戰史館'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_古寧頭戰役'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_古寧頭戰役結束'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_固守舟山群島及金門島'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國共內戰'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍兵力分布'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍反擊'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍收復古寧頭'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_徵兵防守'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_政府派遣第22兵團負責大、小金門防務'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_政府重視金門防務'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_李光前陣亡'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_第19軍從汕頭抵達金門'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_設防佈雷'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_金門發展出特有的戰地文化'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_金門陷入三面包圍'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://example.org/schema#Event'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri',
#      'value': 'http://creativecommons.org/ns#attributionURL'},
#     'o': {'type': 'uri', 'value': 'https://www.archives.gov.tw'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri',
#      'value': 'http://creativecommons.org/ns#attributionURL'},
#     'o': {'type': 'uri', 'value': 'https://www.archives.gov.tw'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/creator'},
#     'o': {'type': 'literal', 'value': '國家發展委員會檔案管理局企劃組視察朱育萱'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/creator'},
#     'o': {'type': 'literal', 'value': '檔案管理局應用服務組研究員馬有成'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/date'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2022-09-16'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/date'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2010-04-16'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri',
#      'value': 'http://purl.org/dc/elements/1.1/identifier'},
#     'o': {'type': 'uri',
#      'value': 'https://www.archives.gov.tw/wSite/public/Attachment/0/f1717473054705.pdf'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri',
#      'value': 'http://purl.org/dc/elements/1.1/identifier'},
#     'o': {'type': 'uri',
#      'value': 'https://www.archives.gov.tw/wSite/public/Attachment/0/f1718084189735.pdf'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/title'},
#     'o': {'type': 'literal', 'value': '金馬獎：一甲子的臺灣電影事業'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/title'},
#     'o': {'type': 'literal', 'value': '電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/rights'},
#     'o': {'type': 'literal', 'value': '本資料依據創用 CC 姓名標示-非商業性 3.0 授權條款釋出'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/rights'},
#     'o': {'type': 'literal', 'value': '本資料依據創用 CC 姓名標示-非商業性 3.0 授權條款釋出'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri',
#      'value': 'http://creativecommons.org/ns#attributionName'},
#     'o': {'type': 'literal', 'value': '檔案管理局'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri',
#      'value': 'http://creativecommons.org/ns#attributionName'},
#     'o': {'type': 'literal', 'value': '檔案管理局'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri', 'value': 'http://creativecommons.org/ns#license'},
#     'o': {'type': 'uri',
#      'value': 'http://creativecommons.org/licenses/by-nc/3.0/'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri', 'value': 'http://creativecommons.org/ns#license'},
#     'o': {'type': 'uri',
#      'value': 'http://creativecommons.org/licenses/by-nc/3.0/'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b-1023628210763537075'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b-1240860313163385962'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b-6634531970373587085'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b4408123814379868784'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b4838097991098076112'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b6942451437138544592'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b-3701037564213273946'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b-8559794070639337164'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b1993252809891308114'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b5295509559759788347'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b5838819992436036773'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'},
#     'p': {'type': 'uri', 'value': 'http://example.org/relatedFile'},
#     'o': {'type': 'uri', 'value': '_:b628713585856492369'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/「賽德克．巴萊」重現的霧社事件(17)#event_電影製作'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'literal', 'xml:lang': 'zh-tw', 'value': '事件：電影製作'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/大專集訓-成功嶺的甘苦回憶(133)#event_獲得電影金馬獎'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'literal', 'xml:lang': 'zh-tw', 'value': '事件：獲得電影金馬獎'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/礦山記憶：探索金瓜石百年歷史風華(191)#event_成為電影取材'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'literal', 'xml:lang': 'zh-tw', 'value': '事件：成為電影取材'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_重新設計金馬獎座'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'literal', 'xml:lang': 'zh-tw', 'value': '事件：重新設計金馬獎座'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_八七水災'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'literal', 'xml:lang': 'zh-tw', 'value': '事件：八七水災'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_成立電影事業輔導委員會'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'literal', 'xml:lang': 'zh-tw', 'value': '事件：成立電影事業輔導委員會'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_扶植電影事業'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'literal', 'xml:lang': 'zh-tw', 'value': '事件：扶植電影事業'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_接受外界申請'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'literal', 'xml:lang': 'zh-tw', 'value': '事件：接受外界申請'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_第59屆頒獎典禮'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'literal', 'xml:lang': 'zh-tw', 'value': '事件：第59屆頒獎典禮'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_興辦金馬獎'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'literal', 'xml:lang': 'zh-tw', 'value': '事件
}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_李光前陣亡'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#hasTriple'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b22669'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_第19軍從汕頭抵達金門'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#hasTriple'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b22670'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_第19軍從汕頭抵達金門'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#hasTriple'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b22671'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_設防佈雷'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#hasTriple'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b22672'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_設防佈雷'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#hasTriple'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b22673'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_金門發展出特有的戰地文化'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#hasTriple'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b22674'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_金門陷入三面包圍'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#hasTriple'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b22675'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/「賽德克．巴萊」重現的霧社事件(17)#event_電影製作'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/「賽德克．巴萊」重現的霧社事件(17).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/大專集訓-成功嶺的甘苦回憶(133)#event_獲得電影金馬獎'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/大專集訓-成功嶺的甘苦回憶(133).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/礦山記憶：探索金瓜石百年歷史風華(191)#event_成為電影取材'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/礦山記憶：探索金瓜石百年歷史風華(191).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_重新設計金馬獎座'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_八七水災'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_成立電影事業輔導委員會'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_扶植電影事業'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_接受外界申請'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_第59屆頒獎典禮'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_興辦金馬獎'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_訂定獎勵國語影片辦法'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_電影事業輔導'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_頒令發展國語電影事業'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_頒發最佳演員特別獎'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183)#event_首屆金馬獎頒獎典禮'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/金馬獎：一甲子的臺灣電影事業(183).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍收復林厝'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍南下漸次占領福建沿海'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍強行登陸金門'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍渡海占領金門意圖明顯'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍規劃從大金門登陸'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍規劃登陸金門'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_共軍設計臺語會話範本'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_加強臺灣本島防禦措施'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_古寧頭戰史館'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_古寧頭戰役'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_古寧頭戰役結束'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_固守舟山群島及金門島'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國共內戰'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍兵力分布'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍反擊'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_國軍收復古寧頭'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_徵兵防守'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_政府派遣第22兵團負責大、小金門防務'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_政府重視金門防務'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_李光前陣亡'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_第19軍從汕頭抵達金門'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_設防佈雷'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_金門發展出特有的戰地文化'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}},
#    {'s': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34)#event_金門陷入三面包圍'},
#     'p': {'type': 'uri', 'value': 'http://example.org/schema#describedIn'},
#     'o': {'type': 'uri',
#      'value': 'http://example.org/doc/電影歎詠戰地、檔案銘刻戰役—金門古寧頭戰役(34).json'}}]}}

# %%
# # 建立 NetworkX 圖形
# G = nx.DiGraph()

# for result in results["results"]["bindings"]:
#     s = extract_label(result["s"]["value"])
#     p = extract_label(result["p"]["value"])
#     if result["o"]["type"] == "uri":
#         o = extract_label(result["o"]["value"])
#     else:
#         o = result["o"]["value"]
#     G.add_edge(simplify_uri(s), simplify_uri(o), label=p)

# pos = nx.spring_layout(G, seed=42)
# edge_x, edge_y = [], []
# for edge in G.edges(data=True):
#     x0, y0 = pos[edge[0]]
#     x1, y1 = pos[edge[1]]
#     edge_x.extend([x0, x1, None])
#     edge_y.extend([y0, y1, None])

# edge_trace = go.Scatter(x=edge_x, y=edge_y, line=dict(width=1, color='#888'),
#                         hoverinfo='none', mode='lines')

# node_x, node_y, node_text = [], [], []
# for node in G.nodes():
#     x, y = pos[node]
#     node_x.append(x)
#     node_y.append(y)
#     node_text.append(node)

# node_trace = go.Scatter(x=node_x, y=node_y, mode='markers+text', hoverinfo='text',
#                         marker=dict(size=10, color='blue'), text=node_text)

# fig = go.Figure(data=[edge_trace, node_trace],
#                 layout=go.Layout(title='SPARQL Knowledge Graph', showlegend=False))

# fig.show()

# %%
import dash
from dash import dcc, html, Input, Output, State
import dash_cytoscape as cyto
import requests
import threading
import webbrowser
#import re

app = dash.Dash(__name__)

# 顯示簡短URI
def simplify_uri(uri):
    if '#' in uri:
        return uri.split('#')[-1]
    else:
        return uri.rstrip('/').split('/')[-1]

# SPARQL 端點 URL
SPARQL_ENDPOINT = "http://192.168.133.39:8890/sparql"

app.layout = html.Div([
    html.H2("SPARQL 知識圖譜查詢與視覺化"),

    dcc.Input(
        id='sparql-input',
        type='text',
        placeholder='輸入 SPARQL 查詢，例如：SELECT * WHERE { ?s ?p ?o } LIMIT 10',
        style={'width': '100%', 'margin-bottom': '12px'}
    ),
    html.Button('查詢', id='query-button', n_clicks=0, style={'margin-bottom': '20px'}),

    cyto.Cytoscape(
        id='cytoscape-graph',
        layout={'name': 'cose'},  # 或 'breadthfirst'
        style={'width': '100%', 'height': '600px'},
        elements=[],
        stylesheet=[
            {
                'selector': 'node',
                'style': {
                    'label': 'data(label)',
                    'background-color': '#0074D9',
                    'color': 'white',
                    'text-valign': 'center',
                    'text-halign': 'center',
                    'font-size': 10,
                    'width': 'label',
                    'padding': '8px',
                    'shape': 'ellipse',    # ellipse 橢圓形，roundrectangle
                    'border-width': 1,            # 邊框調整，預設是 0
                    'border-color': '#333333'   # 邊框顏色
                }
            },
            {
                'selector': 'edge',
                'style': {
                    'curve-style': 'bezier',
                    'target-arrow-shape': 'triangle-backcurve',
                    'source-arrow-shape': 'none',
                    'target-arrow-color': '#000',
                    'line-color': '#000',
                    'arrow-scale': 1.5,
                    'width': 2,
                    'label': 'data(label)',        
                    # 加框設定 
                    'text-background-color': '#EEE',           # 背景顏色
                    'text-background-opacity': 1,              # 背景不透明度（0～1）
                    'text-background-shape': 'roundrectangle', # 形狀： rectangle / roundrectangle
                    'text-border-color': '#333',               # 框線顏色
                    'text-border-width': 1,                    # 框線寬度
                    'text-border-opacity': 1,                  # 框線不透明度（0～1）
                    # 其他文字樣式
                    'font-size':  9,
                    'text-rotation': 'autorotate',
                    'color': '#000'
                }
            }
        ]
    )
])

@app.callback(
    Output('cytoscape-graph', 'elements'),
    Input('query-button', 'n_clicks'),
    State('sparql-input', 'value')
)
def update_graph(n_clicks, sparql_query):
    if not sparql_query:
        return []

    headers = {"Accept": "application/sparql-results+json"}
    try:
        response = requests.get(SPARQL_ENDPOINT, params={'query': sparql_query}, headers=headers, timeout=10)
        data = response.json()
        bindings = data.get("results", {}).get("bindings", [])
    except Exception as e:
        print(f"查詢失敗: {e}")
        return []

    nodes = {}
    edges = []
    for result in bindings:
        s = result.get("s", {}).get("value", "")
        p = result.get("p", {}).get("value", "")
        o = result.get("o", {}).get("value", "")

        if s and s not in nodes:
            nodes[s] = {'data': {'id': s, 'label': simplify_uri(s)}}
        if o and o not in nodes:
            nodes[o] = {'data': {'id': o, 'label': simplify_uri(o)}}

        if s and o and p:
            edges.append({
                'data': {'source': s, 'target': o, 'label': simplify_uri(p)}
            })

    return list(nodes.values()) + edges

def run_dash():
    port = 8050 # 改成未被佔用的端口
    webbrowser.open_new(f"http://127.0.0.1:{port}/")
    app.run_server(port=port, debug=False, use_reloader=False)

threading.Thread(target=run_dash).start()

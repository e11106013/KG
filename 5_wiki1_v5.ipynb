# %%
import requests
import os
import json
import time
import shutil
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

# 初始化 Wikipedia 中文 API
api_wrapper = WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=300, lang="zh")
wiki_tool = WikipediaQueryRun(api_wrapper=api_wrapper)

# Wikidata 查詢
def wikidata_search(entity_name):
    url = 'https://www.wikidata.org/w/api.php'
    params = {
        'action': 'wbsearchentities',
        'search': entity_name,
        'language': 'zh',
        'format': 'json',
        'limit': 3
    }
    response = requests.get(url, params=params).json()
    for result in response.get('search', []):
        desc = result.get('description', '')
        if desc:
            return result['id'], desc
    return None, 'Not found'

# # Wikipedia fallback 查詢
# def wikipedia_fallback(keyword):
#     try:
#         page_result = wiki_tool.invoke({"query": keyword})
#         if "Page:" in page_result and "Summary:" in page_result:
#             page_title = page_result.split("Summary:")[0].replace("Page:", "").strip()
#             summary = page_result.split("Summary:")[1].strip()
#             if page_title == keyword:
#                 return page_title, summary
#     except Exception as e:
#         print(f"❌ Wikipedia 查詢失敗: {e}")
#     return None, 'Not found'

# DBpedia 查 URI
def get_dbpedia_uri_from_dbpedia(entity_name):
    sparql_url = "http://dbpedia.org/sparql"
    sparql_query = """
    SELECT ?subject WHERE {
        # ?subject rdfs:label "%s"@zh.
    }
    LIMIT 1
    """ % entity_name
    try:
        response = requests.get(sparql_url, params={"query": sparql_query, "format": "json"})
        results = response.json().get("results", {}).get("bindings", [])
        if results:
            return results[0]["subject"]["value"]
    except Exception as e:
        print(f"❌ DBpedia 查詢錯誤: {e}")
    return None

# 不需查詢的類別
SKIP_CATEGORIES = {"貨幣", "單位", "數量", "比例", "時間"}

# 整合查詢函式（使用實體名稱與類別）
def enrich_entity(entity_name, entity_type):
    # ⛔️ 如果是排除的類別就直接略過查詢
    if entity_type in SKIP_CATEGORIES:
        return None, f"Skipped ({entity_type})", None

    # 1️⃣ 先查 Wikidata
    qid, desc = wikidata_search(entity_name)
    if qid:
        dbpedia_uri = get_dbpedia_uri_from_dbpedia(entity_name)
        return qid, desc, dbpedia_uri

    # 2️⃣ fallback DBpedia URI
    dbpedia_uri = get_dbpedia_uri_from_dbpedia(entity_name)
    if dbpedia_uri:
        return None, "From DBpedia", dbpedia_uri

    # # 3️⃣ fallback Wikipedia 最後查
    # page, summary = wikipedia_fallback(entity_name)
    # if page:
    #     return None, summary, None

    return None, 'Not found', None

# 處理 JSON 中的關係
def process_relationships(relationships):
    for relationship in relationships:
        for rel in relationship.get("關係列表", []):
            subject = rel.get("主體", "")
            subject_type = rel.get("主體類別", "")
            obj = rel.get("客體", "")
            obj_type = rel.get("客體類別", "")
            relation = rel.get("關係", "")

            sub_qid, sub_desc, sub_dbpedia = enrich_entity(subject, subject_type)
            obj_qid, obj_desc, obj_dbpedia = enrich_entity(obj, obj_type)

            rel["主體 QID"] = sub_qid
            rel["主體 描述"] = sub_desc
            rel["主體 DBpedia"] = sub_dbpedia
            rel["客體 QID"] = obj_qid
            rel["客體 描述"] = obj_desc
            rel["客體 DBpedia"] = obj_dbpedia

            print(f"主體: {subject}（{subject_type}） → QID: {sub_qid} / 描述: {sub_desc} / DBpedia: {sub_dbpedia}")
            print(f"客體: {obj}（{obj_type}） → QID: {obj_qid} / 描述: {obj_desc} / DBpedia: {obj_dbpedia}")
            print(f"關係: {relation}")
            print("-" * 50)
            time.sleep(0.5)

# 批次處理檔案
def process_all_json(json_dir, out_dir, done_dir):
    for filename in os.listdir(json_dir):
        if filename.endswith(".json"):
            file_path = os.path.join(json_dir, filename)
            print(f"🚀 處理檔案: {filename}")
            with open(file_path, "r", encoding="utf-8") as f:
                data = json.load(f)

            if isinstance(data, dict):
                relationships = data.get("review", {}).get("relationships", [])
                process_relationships(relationships)
            elif isinstance(data, list):
                for item in data:
                    if isinstance(item, dict):
                        relationships = item.get("review", {}).get("relationships", [])
                        process_relationships(relationships)

            output_file = os.path.join(out_dir, filename)
            with open(output_file, "w", encoding="utf-8") as f:
                json.dump(data, f, ensure_ascii=False, indent=4)

            shutil.move(file_path, os.path.join(done_dir, filename))
            print(f"✅ 已移動到完成目錄: {filename}")

# %%
# 設定目錄路徑
json_dir = "./docs/output/4_human_review/v7"
done_dir = "./docs/output/4_human_review/v7/done/"
out_dir = "./docs/output/5_wiki/v7/"
#os.makedirs(out_dir, exist_ok=True)

# 執行處理目錄中的所有 JSON 檔案並保存到新目錄
process_all_json(json_dir, out_dir,done_dir)
# Out:
# 🚀 處理檔案: 直衝雲霄：花蓮機場走過一甲子歲月(179).json
# 主體: 沈怡（人物） → QID: Q8276171 / 描述: Chinese politician (1901-1980) / DBpedia: None
# 客體: 花蓮航空站落成啟用（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 參與
# --------------------------------------------------
# 主體: 郝樂遜（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 花蓮航空站落成啟用（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 參與
# --------------------------------------------------
# 主體: 擴建跑道及助航設備（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1,250萬元（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 成本
# --------------------------------------------------
# 主體: 日本投降（事件） → QID: Q6540361 / 描述: end of World War II, 2 September 1945 / DBpedia: http://dbpedia.org/resource/Surrender_of_Japan
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 地點
# --------------------------------------------------
# 主體: 花蓮航空站落成啟用（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 花蓮（地點） → QID: Q249868 / 描述: county in Taiwan / DBpedia: http://dbpedia.org/resource/Hualien
# 關係: 地點
# --------------------------------------------------
# 主體: 國民政府接管臺灣（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 地點
# --------------------------------------------------
# 主體: 發展東部觀光旅遊（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 花蓮（地點） → QID: Q249868 / 描述: county in Taiwan / DBpedia: http://dbpedia.org/resource/Hualien
# 關係: 地點
# --------------------------------------------------
# 主體: 花蓮港廳轄下蕃地飛行作業（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 花蓮港（地點） → QID: Q3847201 / 描述: international seaport in Hualien, Hualien, Taiwan / DBpedia: http://dbpedia.org/resource/Port_of_Hualien
# 關係: 地點
# --------------------------------------------------
# 主體: 開辦國際航線（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 地點
# --------------------------------------------------
# 主體: 新航廈正式營運（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 花蓮（地點） → QID: Q249868 / 描述: county in Taiwan / DBpedia: http://dbpedia.org/resource/Hualien
# 關係: 地點
# --------------------------------------------------
# 主體: 解嚴（事件） → QID: Q17869100 / 描述: Wikinews article / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 解嚴
# --------------------------------------------------
# 主體: 解嚴（事件） → QID: Q17869100 / 描述: Wikinews article / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 地點
# --------------------------------------------------
# 主體: 臺灣經濟好轉（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 經濟好轉
# --------------------------------------------------
# 主體: 臺灣經濟好轉（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 地點
# --------------------------------------------------
# 主體: 機場改善計畫（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 地點
# --------------------------------------------------
# 主體: 擴建花蓮機場候機室（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 花蓮（地點） → QID: Q249868 / 描述: county in Taiwan / DBpedia: http://dbpedia.org/resource/Hualien
# 關係: 地點
# --------------------------------------------------
# 主體: 擴建跑道及助航設備（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 花蓮（地點） → QID: Q249868 / 描述: county in Taiwan / DBpedia: http://dbpedia.org/resource/Hualien
# 關係: 地點
# --------------------------------------------------
# 主體: 日本投降（事件） → QID: Q6540361 / 描述: end of World War II, 2 September 1945 / DBpedia: http://dbpedia.org/resource/Surrender_of_Japan
# 客體: 民國34年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 花蓮航空站落成啟用（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國51年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 國民政府接管臺灣（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國34年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 發展東部觀光旅遊（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國48年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 花蓮港廳轄下蕃地飛行作業（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 大正年間（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 開辦國際航線（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國86年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 新航廈正式營運（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國93年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 解嚴（事件） → QID: Q17869100 / 描述: Wikinews article / DBpedia: None
# 客體: 民國76年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣經濟好轉（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 40年代（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 機場改善計畫（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 40年代（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 擴建花蓮機場候機室（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國58年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 擴建跑道及助航設備（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國50年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 日本（政府） → QID: Q17 / 描述: island country in East Asia / DBpedia: http://dbpedia.org/resource/Japan
# 客體: 日本投降（事件） → QID: Q6540361 / 描述: end of World War II, 2 September 1945 / DBpedia: http://dbpedia.org/resource/Surrender_of_Japan
# 關係: 投降
# --------------------------------------------------
# 主體: 國民政府（政府） → QID: Q2308761 / 描述: Kuomintang-ruled government of the Republic of China between 1925 and 1948 / DBpedia: http://dbpedia.org/resource/Nationalist_government
# 客體: 國民政府接管臺灣（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 接管
# --------------------------------------------------
# 主體: 臺灣總督府警務局航空班（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣總督府（組織） → QID: Q15908531 / 描述: government of Taiwan during the Japanese rule / DBpedia: http://dbpedia.org/resource/Government-General_of_Taiwan
# 關係: 成立
# --------------------------------------------------
# 主體: 交通部民用航空局（組織） → QID: Q701679 / 描述: government agency of the Republic of China, Taiwan / DBpedia: http://dbpedia.org/resource/Civil_Aeronautics_Administration_(Taiwan)
# 客體: 發展東部觀光旅遊（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 發展
# --------------------------------------------------
# 主體: 臺灣總督府警務局航空班（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 花蓮港廳轄下蕃地飛行作業（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 進行
# --------------------------------------------------
# 主體: 交通部民用航空局（組織） → QID: Q701679 / 描述: government agency of the Republic of China, Taiwan / DBpedia: http://dbpedia.org/resource/Civil_Aeronautics_Administration_(Taiwan)
# 客體: 開辦國際航線（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 開辦
# --------------------------------------------------
# 主體: 民航局（組織） → QID: Q1875618 / 描述: government agency charged with the regulation of aviation / DBpedia: None
# 客體: 新航廈正式營運（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 營運
# --------------------------------------------------
# 主體: 行政院美援運用基金會（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 機場改善計畫（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 進行
# --------------------------------------------------
# 主體: 民航局（組織） → QID: Q1875618 / 描述: government agency charged with the regulation of aviation / DBpedia: None
# 客體: 擴建花蓮機場候機室（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 擴建
# --------------------------------------------------
# 主體: 民航局（組織） → QID: Q1875618 / 描述: government agency charged with the regulation of aviation / DBpedia: None
# 客體: 擴建跑道及助航設備（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 擴建
# --------------------------------------------------
# 主體: 臺灣總督府警務局航空班（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 花蓮（地點） → QID: Q249868 / 描述: county in Taiwan / DBpedia: http://dbpedia.org/resource/Hualien
# 關係: 地點
# --------------------------------------------------
# 主體: 臺灣總督府警務局航空班（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 日治時期（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# ✅ 已移動到完成目錄: 直衝雲霄：花蓮機場走過一甲子歲月(179).json
# 🚀 處理檔案: 看不見的推手—美援與臺灣經濟發展(93).json
# 主體: 美援對我國經濟的影響（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 14.8億（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 金額
# --------------------------------------------------
# 主體: 援歐部份雜持（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 五十三億（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 金額
# --------------------------------------------------
# 主體: 援歐部份雜持（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 一億二千五百萬（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 金額
# --------------------------------------------------
# 主體: 援歐部份雜持（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 四億六千三百萬（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 金額
# --------------------------------------------------
# 主體: 簽訂中美救濟協定和援華法案（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 中美救濟協定（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 簽署
# --------------------------------------------------
# 主體: 簽訂中美救濟協定和援華法案（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 援華法案（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 簽署
# --------------------------------------------------
# 主體: 美國國會通過共同安全法案（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 共同安全法案（專有名詞） → QID: Q6944182 / 描述: American foreign aid law / DBpedia: None
# 關係: 通過
# --------------------------------------------------
# 主體: 美援外兩院迅獲折衷協禁（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 美援（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 通過
# --------------------------------------------------
# 主體: 美援對我國經濟的影響（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 美元（貨幣） → QID: None / 描述: Skipped (貨幣) / DBpedia: None
# 關係: 貨幣
# --------------------------------------------------
# 主體: 國際援助計畫（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 歐洲復興計畫（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 實施
# --------------------------------------------------
# 主體: 國際援助計畫（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 馬歇爾計畫（專有名詞） → QID: Q4576 / 描述: American initiative for foreign aid to Western Europe following World War II / DBpedia: None
# 關係: 實施
# --------------------------------------------------
# 主體: 推動經濟發展（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 四年經濟計畫（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 實施
# --------------------------------------------------
# 主體: 推動經濟發展（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 外匯及貿易管制計畫（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 實施
# --------------------------------------------------
# 主體: 推動經濟發展（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 十九點財經改革方案（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 實施
# --------------------------------------------------
# 主體: 推動經濟發展（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 加工出口區設置條例（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 實施
# --------------------------------------------------
# 主體: 第二次世界大戰（事件） → QID: Q362 / 描述: 1939–1945 global conflict / DBpedia: None
# 客體: 租借法案（專有名詞） → QID: Q207637 / 描述: United States foreign policy during World War II / DBpedia: http://dbpedia.org/resource/Lend-Lease
# 關係: 實施
# --------------------------------------------------
# 主體: 基礎工業完工（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 石門水庫（專有名詞） → QID: Q101230894 / 描述: reservoir in Taoyuan City, Taiwan / DBpedia: None
# 關係: 完工
# --------------------------------------------------
# 主體: 基礎工業完工（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 西螺大橋（專有名詞） → QID: Q11629486 / 描述: bridge in Taiwan / DBpedia: http://dbpedia.org/resource/Xiluo_Bridge
# 關係: 完工
# --------------------------------------------------
# 主體: 韓戰爆發（事件） → QID: Q17869300 / 描述: Wikinews article / DBpedia: None
# 客體: 韓戰（專有名詞） → QID: Q8663 / 描述: war between North and South Korea, 1950–1953 / DBpedia: None
# 關係: 爆發
# --------------------------------------------------
# 主體: 成立行政院外匯貿易審議委員會（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國47年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 政府遷臺（事件） → QID: Q16165653 / 描述: Republic of China's retreat from Mainland China to the Island of Taiwan / DBpedia: None
# 客體: 民國38年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 美國國會通過共同安全法案（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國40年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 美援對我國經濟的影響（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國40年至54年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 停止對我援助（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國38年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 第二次世界大戰（事件） → QID: Q362 / 描述: 1939–1945 global conflict / DBpedia: None
# 客體: 第二次世界大戰（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 設立行政院美援運用委員會（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國37年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 戰後重建（事件） → QID: Q3422086 / 描述: peaceful efforts after war, often including financial aid, made by governments to promote recovery and development of a war torn country or state / DBpedia: None
# 客體: 第二次世界大戰（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 歐洲（政府） → QID: Q185144 / 描述: Swedish rock band / DBpedia: None
# 客體: 國際援助計畫（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 接受者
# --------------------------------------------------
# 主體: 美國（政府） → QID: Q30 / 描述: country primarily located in North America / DBpedia: None
# 客體: 第二次世界大戰（事件） → QID: Q362 / 描述: 1939–1945 global conflict / DBpedia: None
# 關係: 提供者
# --------------------------------------------------
# 主體: 美國（政府） → QID: Q30 / 描述: country primarily located in North America / DBpedia: None
# 客體: 簽訂中美救濟協定和援華法案（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 提供者
# --------------------------------------------------
# 主體: 中華民國（政府） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 簽訂中美救濟協定和援華法案（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 接受者
# --------------------------------------------------
# 主體: 中國農村復興聯合委員會（組織） → QID: Q11626125 / 描述: government ministry of the Republic of China (Taiwan) / DBpedia: http://dbpedia.org/resource/Sino-American_Joint_Commission_on_Rural_Reconstruction
# 客體: 共同謀劃運用美國援助款項（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 參與
# --------------------------------------------------
# 主體: 行政院外匯貿易審議委員會（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 成立行政院外匯貿易審議委員會（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 成立
# --------------------------------------------------
# 主體: 行政院美援運用委員會（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 設立行政院美援運用委員會（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 成立
# --------------------------------------------------
# ✅ 已移動到完成目錄: 看不見的推手—美援與臺灣經濟發展(93).json
# 🚀 處理檔案: 礦山記憶：探索金瓜石百年歷史風華(191).json
# 主體: 劉銘傳（人物） → QID: Q707594 / 描述: Chinese general, first governor of Chinese province of Taiwan (1836-1896) / DBpedia: http://dbpedia.org/resource/Liu_Mingchuan
# 客體: 16世紀（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 劉銘傳（人物） → QID: Q707594 / 描述: Chinese general, first governor of Chinese province of Taiwan (1836-1896) / DBpedia: http://dbpedia.org/resource/Liu_Mingchuan
# 客體: 1889年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 西班牙人、荷蘭人（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 16世紀（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 工人（人物） → QID: Q12713481 / 描述: low-skilled or unskilled worker in manual-labour occupations and industrial work, usually for a wage / DBpedia: http://dbpedia.org/resource/Laborer
# 客體: 1889年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 田中長兵衛（人物） → QID: Q7682248 / 描述: Japanese businessman (1834–1901) / DBpedia: None
# 客體: 1896年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 後宮信太郎（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1914年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 劉銘傳（人物） → QID: Q707594 / 描述: Chinese general, first governor of Chinese province of Taiwan (1836-1896) / DBpedia: http://dbpedia.org/resource/Liu_Mingchuan
# 客體: 16世紀（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 劉銘傳（人物） → QID: Q707594 / 描述: Chinese general, first governor of Chinese province of Taiwan (1836-1896) / DBpedia: http://dbpedia.org/resource/Liu_Mingchuan
# 客體: 1889年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 西班牙人、荷蘭人（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 16世紀（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 工人（人物） → QID: Q12713481 / 描述: low-skilled or unskilled worker in manual-labour occupations and industrial work, usually for a wage / DBpedia: http://dbpedia.org/resource/Laborer
# 客體: 1889年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 田中長兵衛（人物） → QID: Q7682248 / 描述: Japanese businessman (1834–1901) / DBpedia: None
# 客體: 1896年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 後宮信太郎（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1914年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 田中長兵衛（人物） → QID: Q7682248 / 描述: Japanese businessman (1834–1901) / DBpedia: None
# 客體: 1896年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 後宮信太郎（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1914年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 田中長兵衛（人物） → QID: Q7682248 / 描述: Japanese businessman (1834–1901) / DBpedia: None
# 客體: 1896年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 後宮信太郎（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1914年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 金礦（專有名詞） → QID: Q1071389 / 描述: process of extracting gold from the ground / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 基隆河（地點） → QID: Q708976 / 描述: river in the Tamsui river basin of Taiwan / DBpedia: http://dbpedia.org/resource/Keelung_River
# 客體: 金礦（專有名詞） → QID: Q1071389 / 描述: process of extracting gold from the ground / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 北部（地點） → QID: Q3495161 / 描述: part of Dublin city that lies to the north of the River Liffey / DBpedia: None
# 客體: 金礦（專有名詞） → QID: Q1071389 / 描述: process of extracting gold from the ground / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 九份（地點） → QID: Q31093 / 描述: mountain area in Ruifang District near Keelung, Taiwan / DBpedia: http://dbpedia.org/resource/Jiufen
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 日本（地點） → QID: Q17 / 描述: island country in East Asia / DBpedia: http://dbpedia.org/resource/Japan
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 金獅獎（專有名詞） → QID: Q209459 / 描述: highest prize given to a film at the Venice Film Festival / DBpedia: http://dbpedia.org/resource/Golden_Lion
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 悲情城市（專有名詞） → QID: Q133461 / 描述: 1989 film by Hou Hsiao-Hsien / DBpedia: http://dbpedia.org/resource/A_City_of_Sadness
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 無言的山丘（專有名詞） → QID: Q11567506 / 描述: 1992 film by Wang Tong / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 多桑（專有名詞） → QID: Q19849922 / 描述: 1994 film by Wu Nien-jen / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 金礦（專有名詞） → QID: Q1071389 / 描述: process of extracting gold from the ground / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 基隆河（地點） → QID: Q708976 / 描述: river in the Tamsui river basin of Taiwan / DBpedia: http://dbpedia.org/resource/Keelung_River
# 客體: 金礦（專有名詞） → QID: Q1071389 / 描述: process of extracting gold from the ground / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 北部（地點） → QID: Q3495161 / 描述: part of Dublin city that lies to the north of the River Liffey / DBpedia: None
# 客體: 金礦（專有名詞） → QID: Q1071389 / 描述: process of extracting gold from the ground / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 金獅獎（專有名詞） → QID: Q209459 / 描述: highest prize given to a film at the Venice Film Festival / DBpedia: http://dbpedia.org/resource/Golden_Lion
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 悲情城市（專有名詞） → QID: Q133461 / 描述: 1989 film by Hou Hsiao-Hsien / DBpedia: http://dbpedia.org/resource/A_City_of_Sadness
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 無言的山丘（專有名詞） → QID: Q11567506 / 描述: 1992 film by Wang Tong / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 多桑（專有名詞） → QID: Q19849922 / 描述: 1994 film by Wu Nien-jen / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 九份（地點） → QID: Q31093 / 描述: mountain area in Ruifang District near Keelung, Taiwan / DBpedia: http://dbpedia.org/resource/Jiufen
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 日本（地點） → QID: Q17 / 描述: island country in East Asia / DBpedia: http://dbpedia.org/resource/Japan
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 九份（地點） → QID: Q31093 / 描述: mountain area in Ruifang District near Keelung, Taiwan / DBpedia: http://dbpedia.org/resource/Jiufen
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 日本（地點） → QID: Q17 / 描述: island country in East Asia / DBpedia: http://dbpedia.org/resource/Japan
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 九份（地點） → QID: Q31093 / 描述: mountain area in Ruifang District near Keelung, Taiwan / DBpedia: http://dbpedia.org/resource/Jiufen
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 日本（地點） → QID: Q17 / 描述: island country in East Asia / DBpedia: http://dbpedia.org/resource/Japan
# 客體: 臺灣鑛業規則（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 位置
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1945年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 1945年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 日本（地點） → QID: Q17 / 描述: island country in East Asia / DBpedia: http://dbpedia.org/resource/Japan
# 客體: 1945年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 2008年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 2008年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1955年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 1955年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1945年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 1945年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 日本（地點） → QID: Q17 / 描述: island country in East Asia / DBpedia: http://dbpedia.org/resource/Japan
# 客體: 1945年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1975年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 水湳洞（地點） → QID: Q11130226 / 描述: region in north-east coastal Taiwan / DBpedia: None
# 客體: 1975年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1987年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 1987年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1948年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 1948年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1948年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 1948年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1975年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 水湳洞（地點） → QID: Q11130226 / 描述: region in north-east coastal Taiwan / DBpedia: None
# 客體: 1975年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1987年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 1987年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 2008年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 2008年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1945年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 1945年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 日本（地點） → QID: Q17 / 描述: island country in East Asia / DBpedia: http://dbpedia.org/resource/Japan
# 客體: 1945年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1987年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 1987年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 2008年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 客體: 2008年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 1975年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 水湳洞（地點） → QID: Q11130226 / 描述: region in north-east coastal Taiwan / DBpedia: None
# 客體: 1975年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺金公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 關係: 時間
# --------------------------------------------------
# 主體: 臺金公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣省行政長官公署（組織） → QID: Q697926 / 描述: former railway operator and governmental agency in Taiwan / DBpedia: None
# 客體: 1941年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 行政院資源委員會（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1944年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣總督府（組織） → QID: Q15908531 / 描述: government of Taiwan during the Japanese rule / DBpedia: http://dbpedia.org/resource/Government-General_of_Taiwan
# 客體: 1896年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 日本鑛業株式會社（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1914年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣鐵路管理局（組織） → QID: Q697926 / 描述: former railway operator and governmental agency in Taiwan / DBpedia: http://dbpedia.org/resource/Taiwan_Railways_Administration
# 客體: 1965年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺糖公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1991年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 台灣金屬鑛業股份有限公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1955年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣省行政長官公署（組織） → QID: Q697926 / 描述: former railway operator and governmental agency in Taiwan / DBpedia: None
# 客體: 1941年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 行政院資源委員會（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1944年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣總督府（組織） → QID: Q15908531 / 描述: government of Taiwan during the Japanese rule / DBpedia: http://dbpedia.org/resource/Government-General_of_Taiwan
# 客體: 1896年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 日本鑛業株式會社（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1914年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺金公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1971年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺金公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1980年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣金銅鑛務局（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1948年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣金銅鑛務局（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1948年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺金公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1971年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣總督府（組織） → QID: Q15908531 / 描述: government of Taiwan during the Japanese rule / DBpedia: http://dbpedia.org/resource/Government-General_of_Taiwan
# 客體: 1896年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 日本鑛業株式會社（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1914年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺金公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1980年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣總督府（組織） → QID: Q15908531 / 描述: government of Taiwan during the Japanese rule / DBpedia: http://dbpedia.org/resource/Government-General_of_Taiwan
# 客體: 1896年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 日本鑛業株式會社（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1914年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣鐵路管理局（組織） → QID: Q697926 / 描述: former railway operator and governmental agency in Taiwan / DBpedia: http://dbpedia.org/resource/Taiwan_Railways_Administration
# 客體: 1965年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺糖公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1991年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣省行政長官公署（組織） → QID: Q697926 / 描述: former railway operator and governmental agency in Taiwan / DBpedia: None
# 客體: 1941年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 行政院資源委員會（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1944年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺金公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1980年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣鐵路管理局（組織） → QID: Q697926 / 描述: former railway operator and governmental agency in Taiwan / DBpedia: http://dbpedia.org/resource/Taiwan_Railways_Administration
# 客體: 1965年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺糖公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1991年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺金公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1971年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 3,000人（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 金瓜石（地點） → QID: Q5365867 / 描述: Historic mining town in northeastern Taiwan / DBpedia: http://dbpedia.org/resource/Jinguashi
# 客體: 3,000人（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 1973年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 客體: 一萬噸（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 1948年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 客體: 1,900人（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 1951年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 客體: 11,000人（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 1948年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 客體: 1,900人（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 1951年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 客體: 11,000人（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 1973年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 客體: 一萬噸（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 1973年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 客體: 一萬噸（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# ✅ 已移動到完成目錄: 礦山記憶：探索金瓜石百年歷史風華(191).json
# 🚀 處理檔案: 科技時代：清華大學電動車的研發(195).json
# 主體: 蔣經國（人物） → QID: Q313598 / 描述: 6th and 7th President of Republic of China / DBpedia: http://dbpedia.org/resource/Chiang_Ching-kuo
# 客體: 臺北市國父紀念館（地點） → QID: None / 描述: Not found / DBpedia: None
# 關係: 地點
# --------------------------------------------------
# 主體: 徐賢修（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 地點
# --------------------------------------------------
# 主體: 毛高文（人物） → QID: Q6753585 / 描述: Taiwanese politician and chemist / DBpedia: http://dbpedia.org/resource/Mao_Kao-wen
# 客體: 美國（地點） → QID: Q30 / 描述: country primarily located in North America / DBpedia: None
# 關係: 地點
# --------------------------------------------------
# 主體: 汪積昭（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 美國（地點） → QID: Q30 / 描述: country primarily located in North America / DBpedia: None
# 關係: 地點
# --------------------------------------------------
# 主體: 蔣經國（人物） → QID: Q313598 / 描述: 6th and 7th President of Republic of China / DBpedia: http://dbpedia.org/resource/Chiang_Ching-kuo
# 客體: 行政院（組織） → QID: Q715055 / 描述: executive body of the Republic of China / DBpedia: http://dbpedia.org/resource/Executive_Yuan
# 關係: 組織
# --------------------------------------------------
# 主體: 蔣經國（人物） → QID: Q313598 / 描述: 6th and 7th President of Republic of China / DBpedia: http://dbpedia.org/resource/Chiang_Ching-kuo
# 客體: 交通部電信總局（組織） → QID: Q717531 / 描述: Taiwanese telecommunications company / DBpedia: None
# 關係: 組織
# --------------------------------------------------
# 主體: 蔣經國（人物） → QID: Q313598 / 描述: 6th and 7th President of Republic of China / DBpedia: http://dbpedia.org/resource/Chiang_Ching-kuo
# 客體: 郵政總局（組織） → QID: Q7676310 / 描述: Post office in Zhongzhen, Taipei, Taiwan / DBpedia: None
# 關係: 組織
# --------------------------------------------------
# 主體: 徐賢修（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 國立清華大學（組織） → QID: Q43406 / 描述: national research university in Hsinchu City, Taiwan / DBpedia: http://dbpedia.org/resource/National_Tsing_Hua_University
# 關係: 組織
# --------------------------------------------------
# 主體: 毛高文（人物） → QID: Q6753585 / 描述: Taiwanese politician and chemist / DBpedia: http://dbpedia.org/resource/Mao_Kao-wen
# 客體: 通用汽車公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 關係: 組織
# --------------------------------------------------
# 主體: 汪積昭（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 唐曼寧運輸顧問公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 關係: 組織
# --------------------------------------------------
# 主體: 蔣經國（人物） → QID: Q313598 / 描述: 6th and 7th President of Republic of China / DBpedia: http://dbpedia.org/resource/Chiang_Ching-kuo
# 客體: 1977年10月8日（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 徐賢修（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1971年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 毛高文（人物） → QID: Q6753585 / 描述: Taiwanese politician and chemist / DBpedia: http://dbpedia.org/resource/Mao_Kao-wen
# 客體: 1971年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 交車典禮（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 2人（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# 主體: 交車典禮（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 11輛（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# 主體: 交車典禮（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 3輛（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# 主體: 交車典禮（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 6輛（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# 主體: 交車典禮（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 200公斤（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# 主體: 交車典禮（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 75公里（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# 主體: 交車典禮（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 16萬8,510元（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# 主體: 清華一號亮相（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 60公里（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# 主體: 清華一號亮相（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 100公里（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# 主體: 清華一號亮相（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1,555公斤（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# 主體: 郵電用電動車使用（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 15公里（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# 主體: 郵電用電動車使用（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 45公里（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 數量
# --------------------------------------------------
# ...
# 關係: 參與
# --------------------------------------------------
# 主體: 測量工作（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 公路局（組織） → QID: Q10883025 / 描述: government agency under the Ministry of Transportation and Communications of the Republic of China (Taiwan) / DBpedia: None
# 關係: 參與
# --------------------------------------------------
# 主體: 測量工作（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 行政院國軍退除役官兵就業輔導委員會（組織） → QID: Q5972697 / 描述: government commission in charge of veterans affairs in Taiwan / DBpedia: None
# 關係: 參與
# --------------------------------------------------
# 主體: 測量工作（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 公路局（組織） → QID: Q10883025 / 描述: government agency under the Ministry of Transportation and Communications of the Republic of China (Taiwan) / DBpedia: None
# 關係: 參與
# --------------------------------------------------
# 主體: 中橫公路（專有名詞） → QID: Q5060681 / 描述: highway system that connects the East and West coasts of Taiwan / DBpedia: http://dbpedia.org/resource/Central_Cross-Island_Highway
# 客體: 1949年5月9日（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 通車
# --------------------------------------------------
# 主體: 中橫公路（專有名詞） → QID: Q5060681 / 描述: highway system that connects the East and West coasts of Taiwan / DBpedia: http://dbpedia.org/resource/Central_Cross-Island_Highway
# 客體: 3年9個月又18天（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 建設時間
# --------------------------------------------------
# 主體: 中橫公路（專有名詞） → QID: Q5060681 / 描述: highway system that connects the East and West coasts of Taiwan / DBpedia: http://dbpedia.org/resource/Central_Cross-Island_Highway
# 客體: 192公里（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 長度
# --------------------------------------------------
# 主體: 東西橫貫公路（專有名詞） → QID: Q5060681 / 描述: highway system that connects the East and West coasts of Taiwan / DBpedia: None
# 客體: 111公里（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 長度
# --------------------------------------------------
# 主體: 中橫公路（專有名詞） → QID: Q5060681 / 描述: highway system that connects the East and West coasts of Taiwan / DBpedia: http://dbpedia.org/resource/Central_Cross-Island_Highway
# 客體: 四億三千餘萬元（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 建設成本
# --------------------------------------------------
# ✅ 已移動到完成目錄: 鬼斧神工的中橫公路(105).json
# 🚀 處理檔案: 黃金歲月：臺灣鳳梨罐頭行銷全球(175).json
# 主體: 岡村庄太郎（人物） → QID: None / 描述: Not found / DBpedia: None
# 客體: 岡村鳳梨工廠（組織） → QID: None / 描述: Not found / DBpedia: None
# 關係: 創辦
# --------------------------------------------------
# 主體: 外銷數量增加（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 200萬箱（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 外銷量
# --------------------------------------------------
# 主體: 外銷數量增加（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 300萬箱（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 外銷量
# --------------------------------------------------
# 主體: 外銷數量增加（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 400萬箱（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 外銷量
# --------------------------------------------------
# 主體: 設置鳳梨保證產量示範耕種區域（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 50公噸（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 產量
# --------------------------------------------------
# 主體: 設置鳳梨保證產量示範耕種區域（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 80公噸（數量） → QID: None / 描述: Skipped (數量) / DBpedia: None
# 關係: 產量
# --------------------------------------------------
# 主體: 太平洋戰爭爆發（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 太平洋戰爭（專有名詞） → QID: Q184425 / 描述: theater of World War II fought in the Pacific and Asia / DBpedia: None
# 關係: 爆發
# --------------------------------------------------
# 主體: 引進開英種鳳梨（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 開英種（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 引進
# --------------------------------------------------
# 主體: 引進開英種鳳梨（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: SmoothCayenne（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 引進
# --------------------------------------------------
# 主體: 引進鳳梨（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 鳳梨（專有名詞） → QID: Q1493 / 描述: tile bearing bromeliad / DBpedia: None
# 關係: 引進
# --------------------------------------------------
# 主體: 出口遭受挑戰（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 鳳梨罐頭（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 出口
# --------------------------------------------------
# 主體: 外銷數量增加（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 鳳梨罐頭（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 外銷
# --------------------------------------------------
# 主體: 成立台灣合同鳳梨株式會社（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 台灣合同鳳梨株式會社（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 成立
# --------------------------------------------------
# 主體: 成立台灣鳳梨股份有限公司（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 耕者有其田政策（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 實施
# --------------------------------------------------
# 主體: 成立岡村鳳梨工廠（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 鳳梨罐頭（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 生產
# --------------------------------------------------
# 主體: 成立臺東糖廠鳳梨工場（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺東糖廠鳳梨工場（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 成立
# --------------------------------------------------
# 主體: 成立臺東糖廠鳳梨工場（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 糖鳳牌（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 生產
# --------------------------------------------------
# 主體: 鳳梨祭神（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 鳳梨（專有名詞） → QID: Q1493 / 描述: tile bearing bromeliad / DBpedia: None
# 關係: 祭祀
# --------------------------------------------------
# 主體: 研發適合直接食用的品種（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 金鑽鳳梨（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 研發
# --------------------------------------------------
# 主體: 重新生產鳳梨罐頭（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 鳳梨罐頭（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 生產
# --------------------------------------------------
# 主體: 設置鳳梨保證產量示範耕種區域（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 鳳梨保證產量示範耕種區域（專有名詞） → QID: None / 描述: Not found / DBpedia: None
# 關係: 設置
# --------------------------------------------------
# 主體: 鳳梨祭神（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 鳳梨（專有名詞） → QID: Q1493 / 描述: tile bearing bromeliad / DBpedia: None
# 關係: 祭祀
# --------------------------------------------------
# 主體: 太平洋戰爭爆發（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 太平洋（地點） → QID: Q98 / 描述: ocean between Asia, Australia and the Americas / DBpedia: http://dbpedia.org/resource/Pacific_Ocean
# 關係: 戰爭地
# --------------------------------------------------
# 主體: 引進開英種鳳梨（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 夏威夷（地點） → QID: Q782 / 描述: state of the United States of America / DBpedia: None
# 關係: 引進地
# --------------------------------------------------
# 主體: 引進鳳梨（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 中國大陸（地點） → QID: Q19188 / 描述: geopolitical area under the jurisdiction of the People's Republic of China, excluding Special Administrative Regions / DBpedia: None
# 關係: 引進地
# --------------------------------------------------
# 主體: 引進鳳梨（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 引進地
# --------------------------------------------------
# 主體: 出口遭受挑戰（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 所在地
# --------------------------------------------------
# 主體: 外銷數量增加（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 所在地
# --------------------------------------------------
# 主體: 成立台灣合同鳳梨株式會社（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 所在地
# --------------------------------------------------
# 主體: 成立台灣鳳梨股份有限公司（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 所在地
# --------------------------------------------------
# 主體: 成立臺東糖廠鳳梨工場（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺東（地點） → QID: Q713381 / 描述: A county-administered city in Taitung County, Taiwan / DBpedia: None
# 關係: 所在地
# --------------------------------------------------
# 主體: 鳳梨祭神（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 舉辦
# --------------------------------------------------
# 主體: 拜拜（事件） → QID: Q2929140 / 描述: 1995 film by Karim Dridi / DBpedia: http://dbpedia.org/resource/Bye_Bye
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 舉辦
# --------------------------------------------------
# 主體: 研發適合直接食用的品種（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 所在地
# --------------------------------------------------
# 主體: 重新生產鳳梨罐頭（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 所在地
# --------------------------------------------------
# 主體: 設置鳳梨保證產量示範耕種區域（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺東（地點） → QID: Q713381 / 描述: A county-administered city in Taitung County, Taiwan / DBpedia: None
# 關係: 所在地
# --------------------------------------------------
# 主體: 鳳梨祭神（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 舉辦
# --------------------------------------------------
# 主體: 拜拜（事件） → QID: Q2929140 / 描述: 1995 film by Karim Dridi / DBpedia: http://dbpedia.org/resource/Bye_Bye
# 客體: 臺灣（地點） → QID: Q865 / 描述: country in East Asia / DBpedia: http://dbpedia.org/resource/Republic_of_China_(1912–1949)
# 關係: 舉辦
# --------------------------------------------------
# 主體: 太平洋戰爭爆發（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1941年12月（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 引進開英種鳳梨（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1920年代（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 引進鳳梨（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 清康熙年間（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 出口遭受挑戰（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1970年代（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 外銷數量增加（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1950年代（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 成立台灣合同鳳梨株式會社（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1930年代（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 成立台灣鳳梨股份有限公司（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1955年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 成立岡村鳳梨工廠（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 20世紀初（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 成立岡村鳳梨工廠（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 日治初期（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 成立臺東糖廠鳳梨工場（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1957年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 研發適合直接食用的品種（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1980年代（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 重新生產鳳梨罐頭（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 戰後（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 設置鳳梨保證產量示範耕種區域（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 1958年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 時間
# --------------------------------------------------
# 主體: 臺灣總督府（組織） → QID: Q15908531 / 描述: government of Taiwan during the Japanese rule / DBpedia: http://dbpedia.org/resource/Government-General_of_Taiwan
# 客體: 成立台灣合同鳳梨株式會社（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 創辦
# --------------------------------------------------
# 主體: 台灣糖業股份有限公司（組織） → QID: Q6126202 / 描述: state-owned company in Taiwan / DBpedia: None
# 客體: 成立臺東糖廠鳳梨工場（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 創辦
# --------------------------------------------------
# 主體: 臺灣省行政長官公署（組織） → QID: Q697926 / 描述: former railway operator and governmental agency in Taiwan / DBpedia: None
# 客體: 重新生產鳳梨罐頭（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 主管
# --------------------------------------------------
# 主體: 台灣農林股份有限公司（組織） → QID: Q123224152 / 描述: Corporation group in Taiwan / DBpedia: None
# 客體: 重新生產鳳梨罐頭（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 主管
# --------------------------------------------------
# 主體: 台糖（組織） → QID: Q6126202 / 描述: state-owned company in Taiwan / DBpedia: None
# 客體: 設置鳳梨保證產量示範耕種區域（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 主管
# --------------------------------------------------
# 主體: 台灣鳳梨股份有限公司（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 成立台灣鳳梨股份有限公司（事件） → QID: None / 描述: Not found / DBpedia: None
# 關係: 成立
# --------------------------------------------------
# 主體: 岡村鳳梨工廠（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 高雄（地點） → QID: Q181557 / 描述: city in southern Taiwan / DBpedia: None
# 關係: 所在地
# --------------------------------------------------
# 主體: 岡村鳳梨工廠（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 鳳山（地點） → QID: Q633500 / 描述: A district in Kaohsiung City, Taiwan / DBpedia: None
# 關係: 所在地
# --------------------------------------------------
# ✅ 已移動到完成目錄: 黃金歲月：臺灣鳳梨罐頭行銷全球(175).json
# 🚀 處理檔案: 黑與白的精彩對弈—圍棋(74).json
# 主體: 文化大革命（事件） → QID: Q8690 / 描述: 1966–1976 Maoist sociopolitical movement in China / DBpedia: http://dbpedia.org/resource/Cultural_Revolution
# 客體: 民國68年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 發生於
# --------------------------------------------------
# 主體: 圍棋運動發展（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國68年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 發生於
# --------------------------------------------------
# 主體: 文化大革命（事件） → QID: Q8690 / 描述: 1966–1976 Maoist sociopolitical movement in China / DBpedia: http://dbpedia.org/resource/Cultural_Revolution
# 客體: 民國68年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 發生於
# --------------------------------------------------
# 主體: 圍棋運動發展（事件） → QID: None / 描述: Not found / DBpedia: None
# 客體: 民國68年（時間） → QID: None / 描述: Skipped (時間) / DBpedia: None
# 關係: 發生於
# --------------------------------------------------
# 主體: 中華文化復興運動推行委員會,圍棋推行委員會,政府機關,學術單位,圍棋協會（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 中國大陸（地點） → QID: Q19188 / 描述: geopolitical area under the jurisdiction of the People's Republic of China, excluding Special Administrative Regions / DBpedia: None
# 關係: 政府
# --------------------------------------------------
# 主體: 中華文化復興運動推行委員會,圍棋推行委員會,政府機關,學術單位,圍棋協會（組織） → QID: None / 描述: Not found / DBpedia: None
# 客體: 中國大陸（地點） → QID: Q19188 / 描述: geopolitical area under the jurisdiction of the People's Republic of China, excluding Special Administrative Regions / DBpedia: None
# 關係: 政府
# --------------------------------------------------
# ✅ 已移動到完成目錄: 黑與白的精彩對弈—圍棋(74).json

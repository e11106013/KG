# %% [markdown]
# ### Prompt - 將文本進行NER處理

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain


# 定義 CoT NER Prompt
ner_prompt = PromptTemplate(
    input_variables=["text"],
    template="""
    這是一個命名實體識別（NER）任務，你需要將文本中的實體分類為以下類別：
    ### **命名實體分類方式：**  
    - 人物（Person）：包括個人姓名、稱號、官職、別名等。
    - 時間（Date/Time）：歷史年代、具體年份、月份、日期、時刻等。  
    - 組織（Organization）：政府機構、學術機構、軍事組織、社會團體、企業等。
    - 事件（Event）：戰爭、革命、條約、政策變遷、災難、運動等。
    - 專有名詞（Proper Noun）：包含特定歷史文件、法律條文、計畫名稱等。
    - 數量（Quantity）：具體數字、統計數據、人口數、傷亡數等。
    - 貨幣（Money）：歷史貨幣單位及金額。
    - 比例（Percentage/Ratio）：百分比、比率、分數等。
     
    直接輸出 **JSON **格式，每個句子或事件應該是陣列中的一個獨立 JSON 物件。請勿包含其他文字、步驟或 Markdown 格式標記（例如 ```json）。  
    
    ### **文本輸入範例：愛因斯坦是20世紀最重要的科學家之一，其創立了現代物理學的兩大支柱的相對論及量子力學，有「現代物理學之父」之譽。1933年10月回到美國後，愛因斯坦成為普林斯頓高等研究院的常駐教授。** 
    ### **以下是輸出格式範例：**  
    {{
        "人物": ["愛因斯坦"],
        "時間": ["20世紀"],
        "地點": [],
        "組織": [],
        "專有名詞": ["相對論","量子力學","現代物理學之父"]
        "數量": [],
        "貨幣": [],
        "比例": [],
        "事件": ["創立相對論與量子力學"]
    }},
    {{
        以此類推...
    }}
    ### **範例到此結束。**
    
    將輸入每一段輸入的文本，提取成命名實體：
    {text}
    """
)

# %% [markdown]
# ### Prompt - 提取 NER實體的關係

# %%
# 定義 CoT 關係識別 Prompt
relation_prompt = PromptTemplate(
    input_variables=["entities"],
    template="""
    請分析以下實體，推理它們之間的關係。
    請使用 **逐步推理（Chain-of-Thought, CoT）** 的方式：
    1. 觀察每個實體類別（人物、組織、事件等），並思考它們可能的關聯。
    2. 嘗試基於以下wikidata常見的屬性(Property)推理可能的關係：
        人物關係（Person） 相關屬性：
        - P31 (instance of)：實體所屬的類別，例如：「孫中山」- P31 - 「人類」
        ...略
        組織(Organization)關係相關屬性： 
        - P199 (organizational divisions)：業務部門，本組織的組織部門（不是獨立的法人實體）。
        ...略
        數字概念（Numbber Date/Time）相關屬性：
        - P4876 number of records ：記錄數量，記錄的數量。
        ...略      
        時間概念（Date/Time）相關屬性： 
        - P577 (publication date)：出版日期，作品首次出版或發行的時間。
        ...略       
        事件（Event）相關屬性：
        - P361 (part of)：事件的一部分，例如：「二戰」- P361 - 「太平洋戰爭」
        ...略            
        地理(location/geography)概念相關屬性：
        - P361 (part of)：地點的一部分，例如：「基隆」- P361 - 「台灣」
        ...略
        出版品(publication/book)相關屬性：
        - P1343 (described by source)：記載處，有記載此項的文獻等出處。
        ...略
        
    3. 嘗試根據這些關係屬性，建立關係結構，**主體-關係-客體**。例如：
        - 如果一個人物與事件相關，他可能是 **發起** 或 **參與** 了該事件。
        - 如果一個組織與地點相關，這個組織可能 **位於** 該地點。
        - 如果一個人物與時間相關，這個人物可能 **出生於** 或 **死亡於** 這個時間。

    4. ***請確保輸出結果是標準的 JSON 格式，不包含任何其他文字。***

    格式範例如下:
    輸入實體:
    {{
        "人物": ["愛因斯坦"],
        "時間": ["20世紀"],
        "地點": [],
        "組織": [],
        "專有名詞": ["相對論","量子力學","現代物理學之父"]
        "數量": [],
        "貨幣": [],
        "比例": [],
        "事件": ["創立相對論與量子力學"]
    }},
    {{
        以此類推...
    }}    
    
    輸出關係結構:
    {{
         {{"事件": ["創立相對論及量子力學"]}},{{["主體": "愛因斯坦|人物", "關係": "時間|P585", "客體": "20世紀|時間"],["主體": "愛因斯坦|人物", "關係": "作者|P50", "客體": "相對論|專有名詞"],["主體": "愛因斯坦|人物", "關係": "作者|P50", "客體": "量子力學|專有名詞"]}}
        ,{{"事件": ["移居美國，任職於普林斯頓"]}},{{["主體": "愛因斯坦|人物", "關係": "時間|P585", "客體": "1933年10月|時間"],["主體": "愛因斯坦|人物", "關係": "任職|P108", "客體": "普林斯頓高等研究院|組織"]}}
        以類此類推...
        
    }}
    ### **範例到此結束。**
    
    將輸入實體清單，分析推理後建立成關係結構：
    {entities}
    """
)

# %%
import json
import re

# 執行 NER 任務
def extract_entities(text):
    raw_result = ner_chain.run(text)  
    #raw_result = ner_chain.invoke(text)  
    try:
        return json.loads(clean_json_output(raw_result))
    except json.JSONDecodeError:
        return {"error": "NER 解析錯誤", "raw_result": raw_result}

# 執行關係識別任務
def extract_relationships(entities):
    raw_result = relation_chain.run(json.dumps(entities, ensure_ascii=False))
    #raw_result = relation_chain.invoke(json.dumps(entities, ensure_ascii=False))
    try:
        return json.loads(clean_json_output(raw_result))
    except json.JSONDecodeError:
        return {"error": "關係識別解析錯誤", "raw_result": raw_result}

# 清理 JSON 輸出，移除 Markdown 標記
def clean_json_output(raw_output):
    # 移除可能的 Markdown JSON 標記
    cleaned = re.sub(r"```json\s*([\s\S]*?)\s*```", r"\1", raw_output).strip()
    return cleaned

# 安全地解析 JSON 字串
def safe_json_loads(data):
    if isinstance(data, str):
        try:
            return json.loads(data)  # 嘗試解析 JSON 字串
        except json.JSONDecodeError:
            print("錯誤：無法解析 JSON 字串")
            return {}  # 解析失敗時返回空字典
    return data  # 如果本來就是字典，則直接返回

# 將文本進行 NER 和關係識別
def process_text(text):
    # 先執行 NER
    entities = extract_entities(text)
    
    # 如果 NER 解析出錯，直接返回
    if "error" in entities:
        return entities
    
    # 再執行關係識別
    relationships = extract_relationships(entities)
    
    return {
        "entities": entities,
        "relationships": relationships
    }

# %%
# import langchain
# # 設定 debug 模式為 False
# #langchain.debug = True
# langchain.debug = False

# print(langchain.__version__)

# %%
# 設定基本的 LLM 模型

from langchain_openai import ChatOpenAI
import os

# 設置 LLM 模型
os.environ["GROQ_API_KEY"] = 'gsk_'

llm = ChatOpenAI(
    openai_api_base="https://api.groq.com/openai/v1",
    openai_api_key=os.environ['GROQ_API_KEY'],
    model_name="llama-3.3-70b-versatile",
    #model_name="llama-3.2-3b-preview",        
    #model_name="llama-3.2-3b-preview",
    #model_name="mixtral-8x7b-32768",
    #model_name="llama-3.2-11b-vision-preview",
    #model_name="deepseek-r1-distill-qwen-32b",
    #model_name="deepseek-r1-distill-llama-70b",
    temperature=0.0,
  #  max_tokens=1000,
)

# %% [markdown]
# ### NER 測試

# %%
import os
import json
from pprint import pprint

## NER 測試文本
ner_chain = LLMChain(prompt=ner_prompt, llm=llm)

#test_text = "依據民國32年所發表的開羅宣言，日本應無條件投降並將台灣、澎湖群島歸還中國。因此，國民政府乃於民國33年5月在中央設計局之下設立台灣調查委員會，做為戰後接收台灣之準備。民國34年8月29日，國民政府特任陳儀為台灣省行政長官，負台灣接收及軍政全責；9月7日，政府又任命陳儀兼任台灣省警備總司令。"
#test_text = "光復之初，民眾表現出對國民政府熱烈的歡迎與支持。但由於二次大戰末期，臺灣屢遭美軍轟炸，公共設施遭受相當破壞，戰後生產原料取得不易，技術人才難求，短期內恢復戰前生產水準，自非易事。然而當時中央政府派遣來台灣的官員，集行政、司法、立法、軍事大權於一身的行政長官公署制，非但未能有效復原，臺政卻每況愈下，迭受抨擊，加上溝通不夠與觀念的差異，以及所採取的不良經濟、統治方式與風評不佳的官威軍政，種下釀成日後228事件的遠因。"
test_text = ["「霧社事件」發生在民國19年，由霧社地區德哥塔雅原住民賽德克的泰雅人揭竿起義，反抗日本帝國主義侵害行為之不幸事件，依據目睹該事件悲慘景象之巫金墩所述(詳下列檔案影像)，該事件係當時在霧社公校舉行例行運動大會時，由莫那魯道酋長率領部落勇士，全副武裝衝入運動場，殺死運動場上約一百六十餘個日本人，導致台灣總督府採取強力的軍事行動，使用國際所禁用的方式派飛機投擲化學毒氣，以慘無人道的手法殘害原住民。除事件領導人莫那魯道自縊外，該族族民亦幾遭滅族。",
    "巫金墩指出，霧社事件係起因於當時的日本完全忽視泰雅族的習慣，除屢次徵召原住民義務勞動苦役、欺壓、虐待外，日本警官亦凌辱部落婦女，加上「以蕃制蕃」措施，長期以來的種族衝突，讓原住民在無法忍受的怨恨累積下，點燃其反日情節，終致霧社事件的發生。",
    "當時的台灣總督府不但無法迅速處理因應，甚至採取不人道的手段鎮壓，因而遭到日本帝國議會強烈質疑，總督石塚英藏與總務長官人見次郎遭到撤換，嚴重影響軍國主義天皇思想的威信，總督府高壓式的「理蕃」政策也因此被迫做適度的調整修正；霧社事件當可說是日本統治台灣期間最後一次激烈的台灣反抗行動。",
    "電影是人類文化的新興載體，可直接記錄與再現人類生活歷史及自然界種種現象之原貌，透過電影手法將歷史檔案普及化的模式，正是導演籌拍史詩電影，將原住民抗日精神加以重現的另一種典範，令人期待之餘，我們已先從國家檔案一窺端倪囉。"
]
ner = ner_chain.invoke({"text": test_text})
#print(response)
#print(json.dumps(response, indent=4, ensure_ascii=False))
#print(json.dumps(response, indent=2, ensure_ascii=False))
pprint(ner, indent=4, width=80, compact=False)
# Out:
# {   'text': '{\n'
#             '    "人物": ["莫那魯道", "巫金墩", "石塚英藏", "人見次郎"],\n'
#             '    "時間": ["民國19年"],\n'
#             '    "組織": ["日本帝國", "台灣總督府"],\n'
#             '    "專有名詞": ["霧社事件", "泰雅人", "賽德克", "霧社公校"],\n'
#             '    "數量": ["一百六十餘個"],\n'
#             '    "貨幣": [],\n'
#             '    "比例": [],\n'
#             '    "事件": ["霧社事件", "運動大會", "軍事行動", "抗日行動"]\n'
#             '},\n'
#             '{\n'
#             '    "人物": ["巫金墩", "莫那魯道"],\n'
#             '    "時間": [],\n'
#             '    "組織": ["日本帝國", "台灣總督府"],\n'
#             '    "專有名詞": ["霧社事件", "泰雅族", "以蕃制蕃"],\n'
#             '    "數量": [],\n'
#             '    "貨幣": [],\n'
#             '    "比例": [],\n'
#             '    "事件": ["霧社事件", "種族衝突"]\n'
#             '},\n'
#             '{\n'
#             '    "人物": ["石塚英藏", "人見次郎"],\n'
#             '    "時間": [],\n'
#             '    "組織": ["日本帝國", "台灣總督府", "日本帝國議會"],\n'
#             '    "專有名詞": ["霧社事件", "理蕃政策"],\n'
#             '    "數量": [],\n'
#             '    "貨幣": [],\n'
#             '    "比例": [],\n'
#             '    "事件": ["霧社事件", "撤換"]\n'
#             '},\n'
#             '{\n'
#             '    "人物": [],\n'
#             '    "時間": [],\n'
#             '    "組織": [],\n'
#             '    "專有名詞": ["電影", "史詩電影"],\n'
#             '    "數量": [],\n'
#             '    "貨幣": [],\n'
#             '    "比例": [],\n'
#             '    "事件": ["霧社事件", "抗日行動"]\n'
#             '}'}

# %% [markdown]
# ### RE 測試

# %%
# 建立關係識別 LLMChain
relation_chain = LLMChain(prompt=relation_prompt, llm=llm)
# 再執行關係識別
relationships = extract_relationships(ner)

pprint(relationships, indent=4, width=80, compact=False)
# Out:
# [   {   '事件': ['霧社事件', '運動大會', '軍事行動', '抗日行動'],
#         '關係': [   {'主體': '莫那魯道|人物', '客體': '霧社事件|事件', '關係': '參與|P1344'},
#                   {'主體': '巫金墩|人物', '客體': '霧社事件|事件', '關係': '參與|P1344'},
#                   {'主體': '石塚英藏|人物', '客體': '霧社事件|事件', '關係': '參與|P1344'},
#                   {'主體': '人見次郎|人物', '客體': '霧社事件|事件', '關係': '參與|P1344'},
#                   {'主體': '霧社事件|事件', '客體': '民國19年|時間', '關係': '發生於|P585'},
#                   {'主體': '霧社事件|事件', '客體': '日本帝國|組織', '關係': '涉及|P361'},
#                   {'主體': '霧社事件|事件', '客體': '台灣總督府|組織', '關係': '涉及|P361'},
#                   {'主體': '霧社事件|事件', '客體': '泰雅人|專有名詞', '關係': '涉及|P361'},
#                   {'主體': '霧社事件|事件', '客體': '賽德克|專有名詞', '關係': '涉及|P361'},
#                   {'主體': '霧社事件|事件', '客體': '霧社公校|專有名詞', '關係': '涉及|P361'}]},
#     {   '事件': ['霧社事件', '種族衝突'],
#         '關係': [   {'主體': '巫金墩|人物', '客體': '霧社事件|事件', '關係': '參與|P1344'},
#                   {'主體': '莫那魯道|人物', '客體': '霧社事件|事件', '關係': '參與|P1344'},
#                   {'主體': '霧社事件|事件', '客體': '日本帝國|組織', '關係': '涉及|P361'},
#                   {'主體': '霧社事件|事件', '客體': '台灣總督府|組織', '關係': '涉及|P361'},
#                   {'主體': '霧社事件|事件', '客體': '泰雅族|專有名詞', '關係': '涉及|P361'},
#                   {'主體': '霧社事件|事件', '客體': '以蕃制蕃|專有名詞', '關係': '涉及|P361'}]},
#     {   '事件': ['霧社事件', '撤換'],
#         '關係': [   {'主體': '石塚英藏|人物', '客體': '霧社事件|事件', '關係': '參與|P1344'},
#                   {'主體': '人見次郎|人物', '客體': '霧社事件|事件', '關係': '參與|P1344'},
#                   {'主體': '霧社事件|事件', '客體': '日本帝國|組織', '關係': '涉及|P361'},
#                   {'主體': '霧社事件|事件', '客體': '台灣總督府|組織', '關係': '涉及|P361'},
#                   {'主體': '霧社事件|事件', '客體': '日本帝國議會|組織', '關係': '涉及|P361'},
#                   {'主體': '霧社事件|事件', '客體': '理蕃政策|專有名詞', '關係': '涉及|P361'}]},
#     {   '事件': ['霧社事件', '抗日行動'],
#         '關係': [   {'主體': '霧社事件|事件', '客體': '電影|專有名詞', '關係': '被描述於|P1343'},
#                   {'主體': '霧社事件|事件', '客體': '史詩電影|專有名詞', '關係': '被描述於|P1343'}]}]

# %% [markdown]
# ### 顯示已處理檔案內容

# %%
import os
import json
out_dir = "./docs/output/3_ner_re_p/llama_v7/"
json_dir = out_dir  # JSON檔案所在資料夾

# 取得所有 JSON 檔案
files = [f for f in os.listdir(json_dir) if f.endswith(".json")]

for file in files:
    full_path = os.path.join(json_dir, file)
    
    with open(full_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        
        print(f"\n===== 檔案名稱: {file} =====")
        print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# ===== 檔案名稱: 228事件(20).json =====
# {
#   "result": {
#     "entities": [
#       {
#         "人物": [],
#         "時間": [
#           "光復之初",
#           "二次大戰末期"
#         ],
#         "組織": [
#           "國民政府"
#         ],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "二次大戰",
#           "228事件"
#         ],
#         "地點": [
#           "臺灣"
#         ]
#       },
#       {
#         "人物": [
#           "葉德根",
#           "傅學通",
#           "林江邁",
#           "陳文溪"
#         ],
#         "時間": [
#           "民國36年2月27日"
#         ],
#         "組織": [
#           "臺灣省菸酒專賣局",
#           "警察大隊"
#         ],
#         "專有名詞": [
#           "天馬茶房"
#         ],
#         "數量": [
#           "6名",
#           "4名",
#           "5箱",
#           "40歲"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "查緝",
#           "走私"
#         ],
#         "地點": [
#           "淡水",
#           "臺北市",
#           "延平北路"
#         ]
#       },
#       {
#         "人物": [
#           "陳文溪"
#         ],
#         "時間": [
#           "2月28日"
#         ],
#         "組織": [
#           "警察總局",
#           "長官公署"
#         ],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "228事件"
#         ],
#         "地點": [
#           "臺灣"
#         ]
#       },
#       {
#         "人物": [
#           "李登輝"
#         ],
#         "時間": [
#           "民國84年"
#         ],
#         "組織": [
#           "政府",
#           "財團法人228事件紀念基金會"
#         ],
#         "專有名詞": [
#           "228紀念碑",
#           "228和平公園",
#           "228事件處理及補償條例"
#         ],
#         "數量": [
#           "84年"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "228事件"
#         ],
#         "地點": [
#           "臺北市"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "89年",
#           "90年",
#           "94年",
#           "97年"
#         ],
#         "組織": [
#           "政府",
#           "本局"
#         ],
#         "專有名詞": [
#           "228事件檔案展",
#           "檔案導引",
#           "228事件與青年學生",
#           "228事件與公營事業",
#           "228事件的鎮壓與救卹"
#         ],
#         "數量": [
#           "48個",
#           "64,241件"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "228事件"
#         ],
#         "地點": []
#       }
#     ],
#     "relationships": {
#       "error": "關係識別解析錯誤",
#       "raw_result": "```\n[\n  {\n    \"事件\": [\"二次大戰\", \"228事件\"],\n    \"關係\": [\n      {\"主體\": \"國民政府|組織\", \"關係\": \"P361\", \"客體\": \"臺灣|地點\"},\n      {\"主體\": \"二次大戰|事件\", \"關係\": \"P577\", \"客體\": \"光復之初|時間\"},\n      {\"主體\": \"二次大戰|事件\", \"關係\": \"P577\", \"客體\": \"二次大戰末期|時間\"},\n      {\"主體\": \"228事件|事件\", \"關係\": \"P361\", \"客體\": \"臺灣|地點\"}\n    ]\n  },\n  {\n    \"事件\": [\"查緝\", \"走私\"],\n    \"關係\": [\n      {\"主體\": \"葉德根|人物\", \"關係\": \"P50\", \"客體\": \"查緝|事件\"},\n      {\"主體\": \"傅學通|人物\", \"關係\": \"P50\", \"客體\": \"查緝|事件\"},\n      {\"主體\": \"林江邁|人物\", \"關係\": \"P50\", \"客體\": \"查緝|事件\"},\n      {\"主體\": \"陳文溪|人物\", \"關係\": \"P50\", \"客體\": \"查緝|事件\"},\n      {\"主體\": \"臺灣省菸酒專賣局|組織\", \"關係\": \"P361\", \"客體\": \"淡水|地點\"},\n      {\"主體\": \"警察大隊|組織\", \"關係\": \"P361\", \"客體\": \"臺北市|地點\"},\n      {\"主體\": \"天馬茶房|專有名詞\", \"關係\": \"P1343\", \"客體\": \"查緝|事件\"},\n      {\"主體\": \"6名|數量\", \"關係\": \"P4876\", \"客體\": \"查緝|事件\"},\n      {\"主體\": \"4名|數量\", \"關係\": \"P4876\", \"客體\": \"查緝|事件\"},\n      {\"主體\": \"5箱|數量\", \"關係\": \"P4876\", \"客體\": \"查緝|事件\"},\n      {\"主體\": \"40歲|數量\", \"關係\": \"P4876\", \"客體\": \"查緝|事件\"}\n    ]\n  },\n  {\n    \"事件\": [\"228事件\"],\n    \"關係\": [\n      {\"主體\": \"陳文溪|人物\", \"關係\": \"P50\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"警察總局|組織\", \"關係\": \"P361\", \"客體\": \"臺灣|地點\"},\n      {\"主體\": \"長官公署|組織\", \"關係\": \"P361\", \"客體\": \"臺灣|地點\"},\n      {\"主體\": \"2月28日|時間\", \"關係\": \"P577\", \"客體\": \"228事件|事件\"}\n    ]\n  },\n  {\n    \"事件\": [\"228事件\"],\n    \"關係\": [\n      {\"主體\": \"李登輝|人物\", \"關係\": \"P50\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"政府|組織\", \"關係\": \"P361\", \"客體\": \"臺北市|地點\"},\n      {\"主體\": \"財團法人228事件紀念基金會|組織\", \"關係\": \"P361\", \"客體\": \"臺北市|地點\"},\n      {\"主體\": \"228紀念碑|專有名詞\", \"關係\": \"P1343\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"228和平公園|專有名詞\", \"關係\": \"P1343\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"228事件處理及補償條例|專有名詞\", \"關係\": \"P1343\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"84年|數量\", \"關係\": \"P4876\", \"客體\": \"228事件|事件\"}\n    ]\n  },\n  {\n    \"事件\": [\"228事件\"],\n    \"關係\": [\n      {\"主體\": \"政府|組織\", \"關係\": \"P361\", \"客體\": \"臺灣|地點\"},\n      {\"主體\": \"本局|組織\", \"關係\": \"P361\", \"客體\": \"臺灣|地點\"},\n      {\"主體\": \"228事件檔案展|專有名詞\", \"關係\": \"P1343\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"檔案導引|專有名詞\", \"關係\": \"P1343\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"228事件與青年學生|專有名詞\", \"關係\": \"P1343\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"228事件與公營事業|專有名詞\", \"關係\": \"P1343\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"228事件的鎮壓與救卹|專有名詞\", \"關係\": \"P1343\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"48個|數量\", \"關係\": \"P4876\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"64,241件|數量\", \"關係\": \"P4876\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"89年|時間\", \"關係\": \"P577\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"90年|時間\", \"關係\": \"P577\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"94年|時間\", \"關係\": \"P577\", \"客體\": \"228事件|事件\"},\n      {\"主體\": \"97年|時間\", \"關係\": \"P577\", \"客體\": \"228事件|事件\"}\n    ]\n  }\n]\n```"
#     }
#   }
# }
#
# ===== 檔案名稱: 「友仔」是什麼？光復初期臺北地區非法組織調查報告告訴您(37).json =====
# {
#   "result": {
#     "error": "NER 解析錯誤",
#     "raw_result": "{\n    \"人物\": [],\n    \"時間\": [\"日治時期\", \"民國34年8月15日\"],\n    \"組織\": [\"警察\", \"保甲\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"警察所享有之廣大權力\", \"日本宣布投降\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"民國34年8月15日\"],\n    \"組織\": [\"警察\", \"自發性組織\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"日本宣布投降\", \"社會治安稍脫常軌\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"34年10月25日\"],\n    \"組織\": [\"政府\", \"警政\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"政府正式接管臺灣警政\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [],\n    \"組織\": [\"遊民\", \"幫派\"],\n    \"專有名詞\": [],\n    \"數量\": [\"萬餘人\"],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"市區治安危機\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"11月1日\"],\n    \"組織\": [\"義勇糾察隊\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"成立義勇糾察隊\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [],\n    \"組織\": [\"義勇糾察隊\", \"軍警\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"成員良莠不齊\", \"部分成員有越軌舉止\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [],\n    \"組織\": [\"義勇警察隊\", \"民警組織\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"將義勇糾察隊解散\", \"改編為義勇警察隊\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [],\n    \"組織\": [\"義勇警察隊\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"協助維持地方治安\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"35年\"],\n    \"組織\": [\"臺灣行政長官公署\", \"民政處\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"建立壯丁守望隊\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [],\n    \"組織\": [\"警察\", \"民警組織\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"維持社會治安\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"35年2月\"],\n    \"組織\": [],\n    \"專有名詞\": [],\n    \"數量\": [\"5,064人\", \"2,922人\"],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"統計無業遊民及流氓\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [],\n    \"組織\": [\"臺灣省警務處\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"調查非法組織及曾擔任皇民奉公會的人士\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"37年\"],\n    \"組織\": [\"臺灣省警務處\", \"臺北市警察局\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"調查萬華地區的流氓組織\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [],\n    \"組織\": [\"萬華車站之十二牲相\", \"龍山寺口之十九路軍\", \"祖師廟口之蜘蛛黨\", \"蕃薯市之一心派\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"流氓組織活動\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [],\n    \"組織\": [\"堀江部隊\"],\n    \"專有名詞\": [],\n    \"數量\": [\"百餘名\"],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"犯有敲詐勒索、賭博等不法行為\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [],\n    \"組織\": [],\n    \"專有名詞\": [\"艋舺\"],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"非法組織的活動對於大眾安全影響\"]\n}"
#   }
# }
#
# ===== 檔案名稱: 「回首向來蕭瑟處，歸去，也無風雨也無晴」—民國38年國軍遷臺紀事(30).json =====
# {
#   "result": {
#     "error": "NER 解析錯誤",
#     "raw_result": "{\n    \"人物\": [\"蔣總統中正\", \"李代總統宗仁\"],\n    \"時間\": [\"20世紀\", \"38年\", \"37年\", \"39年\", \"34年\", \"10月\"],\n    \"組織\": [\"國軍\", \"政府\", \"空軍\", \"陸軍\", \"海軍\", \"國防部\", \"行政院\"],\n    \"專有名詞\": [\"二戰\", \"國共戰局\", \"遼瀋戰役\", \"平津戰役\", \"徐蚌會戰\", \"臺灣防衛計畫\", \"臺灣保衛軍事實施方案\"],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"二次大戰\", \"國共戰爭\", \"遷徙\", \"保衛臺灣\"]\n},\n{\n    \"人物\": [\"蔣總統中正\", \"李代總統宗仁\"],\n    \"時間\": [\"38年\", \"37年\"],\n    \"組織\": [\"國軍\", \"空軍\", \"陸軍\", \"海軍\"],\n    \"專有名詞\": [\"臺灣防衛計畫\"],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"國軍移轉臺灣\", \"空軍移轉臺灣\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"36年\", \"37年\", \"38年\"],\n    \"組織\": [\"國軍\", \"陸軍\", \"海軍\"],\n    \"專有名詞\": [\"遼瀋戰役\", \"平津戰役\", \"徐蚌會戰\"],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"國軍來臺\", \"陸軍來臺\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"37年\", \"38年\", \"39年\"],\n    \"組織\": [\"海軍\"],\n    \"專有名詞\": [\"臺灣防衛計畫\"],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"海軍移轉臺灣\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"38年\"],\n    \"組織\": [\"陸軍\"],\n    \"專有名詞\": [\"臺灣防衛計畫\"],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"陸軍來臺\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"38年\"],\n    \"組織\": [\"陸軍\"],\n    \"專有名詞\": [\"臺灣防衛計畫\"],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"陸軍總司令部來臺\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"38年\"],\n    \"組織\": [\"空軍\", \"海軍\", \"陸軍\"],\n    \"專有名詞\": [\"臺灣防衛計畫\"],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"國軍移轉臺灣\", \"空軍移轉臺灣\", \"海軍移轉臺灣\"]\n},\n{\n    \"人物\": [],\n    \"時間\": [\"38年\"],\n    \"組織\": [\"國防部\"],\n    \"專有名詞\": [\"臺灣防衛計畫\"],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"國防部研擬作戰計畫\"]\n},\n{\n    \"人物\": [\"李代總統宗仁\"],\n    \"時間\": [\"10月\"],\n    \"組織\": [\"政府\", \"國軍\"],\n    \"專有名詞\": [\"臺灣保衛軍事實施方案\"],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"政府遷臺\", \"國軍保衛臺灣\"]\n},\n{\n    \"人物\": [\"蔣總裁中正\", \"閻行政院長錫山\"],\n    \"時間\": [\"12月\"],\n    \"組織\": [\"政府\", \"行政院\"],\n    \"專有名詞\": [],\n    \"數量\": [],\n    \"貨幣\": [],\n    \"比例\": [],\n    \"事件\": [\"政府遷臺\", \"行政院遷臺\"]\n}"
#   }
# }
#
# ===== 檔案名稱: 「威海衛」租借地的收回(42).json =====
# {
#   "result": {
#     "entities": [
#       {
#         "人物": [],
#         "時間": [
#           "鴉片戰爭"
#         ],
#         "組織": [
#           "清廷"
#         ],
#         "專有名詞": [
#           "不平等條約"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "簽下不平等條約"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [],
#         "組織": [],
#         "專有名詞": [
#           "租借地"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": []
#       },
#       {
#         "人物": [],
#         "時間": [],
#         "組織": [],
#         "專有名詞": [
#           "租借地"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": []
#       },
#       {
#         "人物": [],
#         "時間": [],
#         "組織": [
#           "中華民國"
#         ],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "收回租借地"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [],
#         "組織": [],
#         "專有名詞": [
#           "威海衛"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": []
#       },
#       {
#         "人物": [],
#         "時間": [
#           "19世紀末",
#           "光緒24年",
#           "1898年"
#         ],
#         "組織": [
#           "俄國",
#           "英國",
#           "清廷"
#         ],
#         "專有名詞": [
#           "旅順",
#           "大連",
#           "威海衛",
#           "訂租威海衛專條"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "租借旅順、大連及威海衛"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [],
#         "組織": [
#           "俄國",
#           "英國",
#           "清廷"
#         ],
#         "專有名詞": [
#           "威海衛"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "控制權落入外國"
#         ]
#       },
#       {
#         "人物": [
#           "段祺瑞"
#         ],
#         "時間": [
#           "民國3年",
#           "第一次世界大戰"
#         ],
#         "組織": [
#           "北洋政府",
#           "德國",
#           "奧匈帝國"
#         ],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "宣戰"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "民國7年",
#           "第一次世界大戰"
#         ],
#         "組織": [
#           "中國",
#           "德國",
#           "奧匈帝國"
#         ],
#         "專有名詞": [
#           "巴黎和會"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "提出廢除外國在華勢力範圍"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "民國10年"
#         ],
#         "組織": [
#           "中國"
#         ],
#         "專有名詞": [
#           "華盛頓會議"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "提出歸還各國在華租借地的要求"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "民國13年"
#         ],
#         "組織": [
#           "中英"
#         ],
#         "專有名詞": [
#           "交收威海衛專約"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "訂立交收威海衛專約"
#         ]
#       },
#       {
#         "人物": [
#           "曹錕"
#         ],
#         "時間": [
#           "民國19年"
#         ],
#         "組織": [
#           "中英"
#         ],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "重開談判"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "清光緒24年",
#           "1898年"
#         ],
#         "組織": [],
#         "專有名詞": [
#           "中英議租威海衛專條"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": []
#       }
#     ],
#     "relationships": [
#       {
#         "事件": [
#           "簽下不平等條約"
#         ],
#         "關係": [
#           {
#             "主體": "清廷|組織",
#             "關係": "簽署|P162",
#             "客體": "不平等條約|專有名詞"
#           },
#           {
#             "主體": "清廷|組織",
#             "關係": "時間|P577",
#             "客體": "鴉片戰爭|時間"
#           }
#         ]
#       },
#       {
#         "事件": [],
#         "關係": [
#           {
#             "主體": "租借地|專有名詞",
#             "關係": "是|P31",
#             "客體": "領土|專有名詞"
#           }
#         ]
#       },
#       {
#         "事件": [],
#         "關係": [
#           {
#             "主體": "租借地|專有名詞",
#             "關係": "是|P31",
#             "客體": "領土|專有名詞"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "收回租借地"
#         ],
#         "關係": [
#           {
#             "主體": "中華民國|組織",
#             "關係": "收回|P509",
#             "客體": "租借地|專有名詞"
#           }
#         ]
#       },
#       {
#         "事件": [],
#         "關係": [
#           {
#             "主體": "威海衛|專有名詞",
#             "關係": "是|P31",
#             "客體": "租借地|專有名詞"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "租借旅順、大連及威海衛"
#         ],
#         "關係": [
#           {
#             "主體": "俄國|組織",
#             "關係": "租借|P509",
#             "客體": "旅順|專有名詞"
#           },
#           {
#             "主體": "英國|組織",
#             "關係": "租借|P509",
#             "客體": "威海衛|專有名詞"
#           },
#           {
#             "主體": "清廷|組織",
#             "關係": "租借|P509",
#             "客體": "大連|專有名詞"
#           },
#           {
#             "主體": "俄國|組織",
#             "關係": "時間|P577",
#             "客體": "19世紀末|時間"
#           },
#           {
#             "主體": "英國|組織",
#             "關係": "時間|P577",
#             "客體": "光緒24年|時間"
#           },
#           {
#             "主體": "清廷|組織",
#             "關係": "時間|P577",
#             "客體": "1898年|時間"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "控制權落入外國"
#         ],
#         "關係": [
#           {
#             "主體": "俄國|組織",
#             "關係": "控制|P181",
#             "客體": "威海衛|專有名詞"
#           },
#           {
#             "主體": "英國|組織",
#             "關係": "控制|P181",
#             "客體": "威海衛|專有名詞"
#           },
#           {
#             "主體": "清廷|組織",
#             "關係": "失去控制|P181",
#             "客體": "威海衛|專有名詞"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "宣戰"
#         ],
#         "關係": [
#           {
#             "主體": "段祺瑞|人物",
#             "關係": "宣戰|P607",
#             "客體": "德國|組織"
#           },
#           {
#             "主體": "段祺瑞|人物",
#             "關係": "宣戰|P607",
#             "客體": "奧匈帝國|組織"
#           },
#           {
#             "主體": "北洋政府|組織",
#             "關係": "宣戰|P607",
#             "客體": "德國|組織"
#           },
#           {
#             "主體": "北洋政府|組織",
#             "關係": "宣戰|P607",
#             "客體": "奧匈帝國|組織"
#           },
#           {
#             "主體": "段祺瑞|人物",
#             "關係": "時間|P577",
#             "客體": "民國3年|時間"
#           },
#           {
#             "主體": "北洋政府|組織",
#             "關係": "時間|P577",
#             "客體": "第一次世界大戰|時間"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "提出廢除外國在華勢力範圍"
#         ],
#         "關係": [
#           {
#             "主體": "中國|組織",
#             "關係": "提出|P793",
#             "客體": "廢除外國在華勢力範圍|專有名詞"
#           },
#           {
#             "主體": "中國|組織",
#             "關係": "時間|P577",
#             "客體": "民國7年|時間"
#           },
#           {
#             "主體": "中國|組織",
#             "關係": "時間|P577",
#             "客體": "第一次世界大戰|時間"
#           },
#           {
#             "主體": "中國|組織",
#             "關係": "地點|P276",
#             "客體": "巴黎和會|專有名詞"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "提出歸還各國在華租借地的要求"
#         ],
#         "關係": [
#           {
#             "主體": "中國|組織",
#             "關係": "提出|P793",
#             "客體": "歸還各國在華租借地的要求|專有名詞"
#           },
#           {
#             "主體": "中國|組織",
#             "關係": "時間|P577",
#             "客體": "民國10年|時間"
#           },
#           {
#             "主體": "中國|組織",
#             "關係": "地點|P276",
#             "客體": "華盛頓會議|專有名詞"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "訂立交收威海衛專約"
#         ],
#         "關係": [
#           {
#             "主體": "中英|組織",
#             "關係": "訂立|P162",
#             "客體": "交收威海衛專約|專有名詞"
#           },
#           {
#             "主體": "中英|組織",
#             "關係": "時間|P577",
#             "客體": "民國13年|時間"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "重開談判"
#         ],
#         "關係": [
#           {
#             "主體": "曹錕|人物",
#             "關係": "重開談判|P793",
#             "客體": "中英|組織"
#           },
#           {
#             "主體": "曹錕|人物",
#             "關係": "時間|P577",
#             "客體": "民國19年|時間"
#           }
#         ]
#       },
#       {
#         "事件": [],
#         "關係": [
#           {
#             "主體": "中英議租威海衛專條|專有名詞",
#             "關係": "是|P31",
#             "客體": "條約|專有名詞"
#           }
#         ]
#       }
#     ]
#   }
# }
#
# ===== 檔案名稱: 「快速」發展的年代：麥克阿瑟公路通車一甲子(203).json =====
# {
#   "result": {
#     "entities": [
#       {
#         "人物": [],
#         "時間": [
#           "1951",
#           "1965"
#         ],
#         "組織": [],
#         "專有名詞": [
#           "西螺大橋",
#           "中橫公路",
#           "石門水庫"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "大規模建設時期"
#         ]
#       },
#       {
#         "人物": [
#           "麥克阿瑟",
#           "DouglasMacArthur"
#         ],
#         "時間": [],
#         "組織": [],
#         "專有名詞": [
#           "麥克阿瑟公路",
#           "北基二路",
#           "北基新路"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "麥克阿瑟將軍逝世"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "1961",
#           "1964"
#         ],
#         "組織": [
#           "政府"
#         ],
#         "專有名詞": [
#           "麥帥公路"
#         ],
#         "數量": [
#           "23.4",
#           "2.057",
#           "45",
#           "25"
#         ],
#         "貨幣": [
#           "新臺幣2億2,790萬元",
#           "1億2,695萬元",
#           "1億95萬元"
#         ],
#         "比例": [],
#         "事件": [
#           "公路建設"
#         ]
#       },
#       {
#         "人物": [
#           "黃杰",
#           "沈怡",
#           "高立夫"
#         ],
#         "時間": [
#           "1964"
#         ],
#         "組織": [
#           "臺灣省政府",
#           "交通部",
#           "美國駐華大使館"
#         ],
#         "專有名詞": [
#           "公路局",
#           "金馬號"
#         ],
#         "數量": [],
#         "貨幣": [
#           "10元",
#           "5元",
#           "1元"
#         ],
#         "比例": [],
#         "事件": [
#           "通車典禮"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "1965",
#           "1967",
#           "1969"
#         ],
#         "組織": [
#           "省政府"
#         ],
#         "專有名詞": [
#           "臺灣省麥克阿瑟直達公路管理辦法"
#         ],
#         "數量": [
#           "80",
#           "60",
#           "50"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "管理辦法"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "1978"
#         ],
#         "組織": [
#           "交通部"
#         ],
#         "專有名詞": [
#           "高速公路交通管制規則"
#         ],
#         "數量": [
#           "51"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "管理辦法廢止"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "1970"
#         ],
#         "組織": [],
#         "專有名詞": [
#           "中山高速公路"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "十大建設"
#         ]
#       }
#     ],
#     "relationships": {
#       "error": "關係識別解析錯誤",
#       "raw_result": "```\n[\n  {\n    \"事件\": [\"大規模建設時期\"],\n    \"關係\": [\n      {\"主體\": \"西螺大橋|專有名詞\", \"關係\": \"時間|P577\", \"客體\": \"1951|時間\"},\n      {\"主體\": \"中橫公路|專有名詞\", \"關係\": \"時間|P577\", \"客體\": \"1965|時間\"},\n      {\"主體\": \"石門水庫|專有名詞\", \"關係\": \"時間|P577\", \"客體\": \"1951|時間\"}\n    ]\n  },\n  {\n    \"事件\": [\"麥克阿瑟將軍逝世\"],\n    \"關係\": [\n      {\"主體\": \"麥克阿瑟|人物\", \"關係\": \"時間|P585\", \"客體\": \"1964|時間\"},\n      {\"主體\": \"麥克阿瑟公路|專有名詞\", \"關係\": \"時間|P577\", \"客體\": \"1964|時間\"}\n    ]\n  },\n  {\n    \"事件\": [\"公路建設\"],\n    \"關係\": [\n      {\"主體\": \"政府|組織\", \"關係\": \"時間|P577\", \"客體\": \"1961|時間\"},\n      {\"主體\": \"麥帥公路|專有名詞\", \"關係\": \"時間|P577\", \"客體\": \"1964|時間\"},\n      {\"主體\": \"公路建設|事件\", \"關係\": \"成本|P2135\", \"客體\": \"新臺幣2億2,790萬元|貨幣\"}\n    ]\n  },\n  {\n    \"事件\": [\"通車典禮\"],\n    \"關係\": [\n      {\"主體\": \"黃杰|人物\", \"關係\": \"時間|P585\", \"客體\": \"1964|時間\"},\n      {\"主體\": \"沈怡|人物\", \"關係\": \"時間|P585\", \"客體\": \"1964|時間\"},\n      {\"主體\": \"高立夫|人物\", \"關係\": \"時間|P585\", \"客體\": \"1964|時間\"},\n      {\"主體\": \"臺灣省政府|組織\", \"關係\": \"時間|P577\", \"客體\": \"1964|時間\"},\n      {\"主體\": \"交通部|組織\", \"關係\": \"時間|P577\", \"客體\": \"1964|時間\"},\n      {\"主體\": \"美國駐華大使館|組織\", \"關係\": \"時間|P577\", \"客體\": \"1964|時間\"}\n    ]\n  },\n  {\n    \"事件\": [\"管理辦法\"],\n    \"關係\": [\n      {\"主體\": \"省政府|組織\", \"關係\": \"時間|P577\", \"客體\": \"1965|時間\"},\n      {\"主體\": \"臺灣省麥克阿瑟直達公路管理辦法|專有名詞\", \"關係\": \"時間|P577\", \"客體\": \"1965|時間\"}\n    ]\n  },\n  {\n    \"事件\": [\"管理辦法廢止\"],\n    \"關係\": [\n      {\"主體\": \"交通部|組織\", \"關係\": \"時間|P577\", \"客體\": \"1978|時間\"},\n      {\"主體\": \"高速公路交通管制規則|專有名詞\", \"關係\": \"時間|P577\", \"客體\": \"1978|時間\"}\n    ]\n  },\n  {\n    \"事件\": [\"十大建設\"],\n    \"關係\": [\n      {\"主體\": \"中山高速公路|專有名詞\", \"關係\": \"時間|P577\", \"客體\": \"1970|時間\"}\n    ]\n  }\n]\n```"
#     }
#   }
# }
#
# ===== 檔案名稱: 「日暮鄉關何處是」─「留越國軍」的返台路(31).json =====
# {
#   "result": {
#     "entities": [
#       {
#         "人物": [
#           "黃杰",
#           "白崇禧"
#         ],
#         "時間": [
#           "38年",
#           "20世紀"
#         ],
#         "地點": [
#           "上海",
#           "基隆港區",
#           "廣西",
#           "越南",
#           "臺灣"
#         ],
#         "組織": [
#           "國軍",
#           "保安隊",
#           "政府"
#         ],
#         "專有名詞": [
#           "太平輪遇難旅客紀念碑",
#           "相對論",
#           "量子力學"
#         ],
#         "數量": [
#           "3萬餘人"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "國共戰事",
#           "船難事件",
#           "入越"
#         ]
#       },
#       {
#         "人物": [
#           "黃杰",
#           "白崇禧",
#           "蔣總裁中正"
#         ],
#         "時間": [
#           "38年6月",
#           "7月初",
#           "12月初"
#         ],
#         "地點": [
#           "廣西鎮南關",
#           "越南",
#           "諒山",
#           "香港"
#         ],
#         "組織": [
#           "國軍",
#           "保安隊",
#           "政府",
#           "外交部"
#         ],
#         "專有名詞": [
#           "桂、滇國軍入越之先例"
#         ],
#         "數量": [
#           "48員"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "保安隊遭攻擊",
#           "國軍入越"
#         ]
#       },
#       {
#         "人物": [
#           "黃杰",
#           "白崇禧",
#           "蔣總裁中正"
#         ],
#         "時間": [
#           "38年12月中旬"
#         ],
#         "地點": [
#           "粵桂邊區",
#           "廣西",
#           "越南"
#         ],
#         "組織": [
#           "國軍",
#           "政府"
#         ],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "華中國軍作戰失利"
#         ]
#       },
#       {
#         "人物": [
#           "黃杰",
#           "何竹本",
#           "康士登"
#         ],
#         "時間": [
#           "38年12月12日"
#         ],
#         "地點": [
#           "越南",
#           "諒山",
#           "寺馬"
#         ],
#         "組織": [
#           "國軍",
#           "法軍"
#         ],
#         "專有名詞": [
#           "協定"
#         ],
#         "數量": [
#           "五百人"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "國軍入越",
#           "協定簽署"
#         ]
#       },
#       {
#         "人物": [
#           "黃杰",
#           "蔣總裁中正",
#           "周恩來"
#         ],
#         "時間": [
#           "40年12月25日"
#         ],
#         "地點": [
#           "富國島",
#           "金蘭灣"
#         ],
#         "組織": [
#           "國軍",
#           "政府",
#           "法軍"
#         ],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "絕食抗議行動"
#         ]
#       },
#       {
#         "人物": [
#           "黃杰",
#           "蔣總裁中正",
#           "蔡斯"
#         ],
#         "時間": [
#           "41年元月"
#         ],
#         "地點": [
#           "越南",
#           "臺灣"
#         ],
#         "組織": [
#           "國軍",
#           "政府",
#           "美軍顧問團"
#         ],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "國軍回臺"
#         ]
#       },
#       {
#         "人物": [
#           "黃杰",
#           "蔣總裁中正"
#         ],
#         "時間": [
#           "42年5月16日",
#           "6月28日"
#         ],
#         "地點": [
#           "越南",
#           "臺灣"
#         ],
#         "組織": [
#           "國軍",
#           "政府",
#           "海軍"
#         ],
#         "專有名詞": [
#           "富台計劃"
#         ],
#         "數量": [
#           "3萬餘人"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "國軍返臺"
#         ]
#       },
#       {
#         "人物": [
#           "黃杰",
#           "蔣總裁中正",
#           "李彌"
#         ],
#         "時間": [
#           "42年"
#         ],
#         "地點": [
#           "越南",
#           "臺灣",
#           "緬甸"
#         ],
#         "組織": [
#           "國軍",
#           "政府"
#         ],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "國軍返臺",
#           "留緬國軍"
#         ]
#       }
#     ],
#     "relationships": [
#       {
#         "事件": [
#           "國共戰事",
#           "船難事件",
#           "入越"
#         ],
#         "關係": [
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "國共戰事|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "船難事件|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "入越|事件"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "參與|P1344",
#             "客體": "國共戰事|事件"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "參與|P1344",
#             "客體": "船難事件|事件"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "參與|P1344",
#             "客體": "入越|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "時間|P585",
#             "客體": "38年|時間"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "時間|P585",
#             "客體": "38年|時間"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "地點|P276",
#             "客體": "上海|地點"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "地點|P276",
#             "客體": "上海|地點"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "保安隊遭攻擊",
#           "國軍入越"
#         ],
#         "關係": [
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "保安隊遭攻擊|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍入越|事件"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "參與|P1344",
#             "客體": "保安隊遭攻擊|事件"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍入越|事件"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "參與|P1344",
#             "客體": "保安隊遭攻擊|事件"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍入越|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "時間|P585",
#             "客體": "38年6月|時間"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "時間|P585",
#             "客體": "38年6月|時間"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "時間|P585",
#             "客體": "38年6月|時間"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "地點|P276",
#             "客體": "廣西鎮南關|地點"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "地點|P276",
#             "客體": "廣西鎮南關|地點"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "地點|P276",
#             "客體": "廣西鎮南關|地點"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "華中國軍作戰失利"
#         ],
#         "關係": [
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "華中國軍作戰失利|事件"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "參與|P1344",
#             "客體": "華中國軍作戰失利|事件"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "參與|P1344",
#             "客體": "華中國軍作戰失利|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "時間|P585",
#             "客體": "38年12月中旬|時間"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "時間|P585",
#             "客體": "38年12月中旬|時間"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "時間|P585",
#             "客體": "38年12月中旬|時間"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "地點|P276",
#             "客體": "粵桂邊區|地點"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "地點|P276",
#             "客體": "粵桂邊區|地點"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "地點|P276",
#             "客體": "粵桂邊區|地點"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "白崇禧|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "國軍入越",
#           "協定簽署"
#         ],
#         "關係": [
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍入越|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "協定簽署|事件"
#           },
#           {
#             "主體": "何竹本|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍入越|事件"
#           },
#           {
#             "主體": "何竹本|人物",
#             "關係": "參與|P1344",
#             "客體": "協定簽署|事件"
#           },
#           {
#             "主體": "康士登|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍入越|事件"
#           },
#           {
#             "主體": "康士登|人物",
#             "關係": "參與|P1344",
#             "客體": "協定簽署|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "時間|P585",
#             "客體": "38年12月12日|時間"
#           },
#           {
#             "主體": "何竹本|人物",
#             "關係": "時間|P585",
#             "客體": "38年12月12日|時間"
#           },
#           {
#             "主體": "康士登|人物",
#             "關係": "時間|P585",
#             "客體": "38年12月12日|時間"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "地點|P276",
#             "客體": "越南|地點"
#           },
#           {
#             "主體": "何竹本|人物",
#             "關係": "地點|P276",
#             "客體": "越南|地點"
#           },
#           {
#             "主體": "康士登|人物",
#             "關係": "地點|P276",
#             "客體": "越南|地點"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "何竹本|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "康士登|人物",
#             "關係": "組織|P361",
#             "客體": "法軍|組織"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "絕食抗議行動"
#         ],
#         "關係": [
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "絕食抗議行動|事件"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "參與|P1344",
#             "客體": "絕食抗議行動|事件"
#           },
#           {
#             "主體": "周恩來|人物",
#             "關係": "參與|P1344",
#             "客體": "絕食抗議行動|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "時間|P585",
#             "客體": "40年12月25日|時間"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "時間|P585",
#             "客體": "40年12月25日|時間"
#           },
#           {
#             "主體": "周恩來|人物",
#             "關係": "時間|P585",
#             "客體": "40年12月25日|時間"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "地點|P276",
#             "客體": "富國島|地點"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "地點|P276",
#             "客體": "富國島|地點"
#           },
#           {
#             "主體": "周恩來|人物",
#             "關係": "地點|P276",
#             "客體": "富國島|地點"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "周恩來|人物",
#             "關係": "組織|P361",
#             "客體": "政府|組織"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "國軍回臺"
#         ],
#         "關係": [
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍回臺|事件"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍回臺|事件"
#           },
#           {
#             "主體": "蔡斯|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍回臺|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "時間|P585",
#             "客體": "41年元月|時間"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "時間|P585",
#             "客體": "41年元月|時間"
#           },
#           {
#             "主體": "蔡斯|人物",
#             "關係": "時間|P585",
#             "客體": "41年元月|時間"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "地點|P276",
#             "客體": "越南|地點"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "地點|P276",
#             "客體": "越南|地點"
#           },
#           {
#             "主體": "蔡斯|人物",
#             "關係": "地點|P276",
#             "客體": "越南|地點"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "蔡斯|人物",
#             "關係": "組織|P361",
#             "客體": "美軍顧問團|組織"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "國軍返臺"
#         ],
#         "關係": [
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍返臺|事件"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍返臺|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "時間|P585",
#             "客體": "42年5月16日|時間"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "時間|P585",
#             "客體": "42年5月16日|時間"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "地點|P276",
#             "客體": "越南|地點"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "地點|P276",
#             "客體": "越南|地點"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "國軍返臺",
#           "留緬國軍"
#         ],
#         "關係": [
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍返臺|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "參與|P1344",
#             "客體": "留緬國軍|事件"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍返臺|事件"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "參與|P1344",
#             "客體": "留緬國軍|事件"
#           },
#           {
#             "主體": "李彌|人物",
#             "關係": "參與|P1344",
#             "客體": "國軍返臺|事件"
#           },
#           {
#             "主體": "李彌|人物",
#             "關係": "參與|P1344",
#             "客體": "留緬國軍|事件"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "時間|P585",
#             "客體": "42年|時間"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "時間|P585",
#             "客體": "42年|時間"
#           },
#           {
#             "主體": "李彌|人物",
#             "關係": "時間|P585",
#             "客體": "42年|時間"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "地點|P276",
#             "客體": "越南|地點"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "地點|P276",
#             "客體": "越南|地點"
#           },
#           {
#             "主體": "李彌|人物",
#             "關係": "地點|P276",
#             "客體": "越南|地點"
#           },
#           {
#             "主體": "黃杰|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "蔣總裁中正|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           },
#           {
#             "主體": "李彌|人物",
#             "關係": "組織|P361",
#             "客體": "國軍|組織"
#           }
#         ]
#       }
#     ]
#   }
# }
#
# ===== 檔案名稱: 「賽德克．巴萊」重現的霧社事件(17).json =====
# {
#   "result": {
#     "entities": [
#       {
#         "人物": [
#           "莫那魯道",
#           "巫金墩",
#           "石塚英藏",
#           "人見次郎"
#         ],
#         "時間": [
#           "民國19年"
#         ],
#         "組織": [
#           "日本帝國",
#           "台灣總督府"
#         ],
#         "專有名詞": [
#           "霧社事件",
#           "泰雅人",
#           "賽德克",
#           "霧社公校"
#         ],
#         "數量": [
#           "一百六十餘個"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "霧社事件",
#           "運動大會",
#           "軍事行動"
#         ]
#       },
#       {
#         "人物": [
#           "巫金墩"
#         ],
#         "時間": [],
#         "組織": [
#           "日本帝國"
#         ],
#         "專有名詞": [
#           "霧社事件",
#           "泰雅族",
#           "以蕃制蕃"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "霧社事件",
#           "種族衝突"
#         ]
#       },
#       {
#         "人物": [
#           "石塚英藏",
#           "人見次郎"
#         ],
#         "時間": [],
#         "組織": [
#           "台灣總督府",
#           "日本帝國議會"
#         ],
#         "專有名詞": [
#           "霧社事件",
#           "理蕃政策"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "霧社事件",
#           "撤換",
#           "調整修正"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [],
#         "組織": [],
#         "專有名詞": [
#           "電影",
#           "史詩電影",
#           "國家檔案"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "霧社事件",
#           "抗日行動"
#         ]
#       }
#     ],
#     "relationships": [
#       {
#         "事件": [
#           "霧社事件",
#           "運動大會",
#           "軍事行動"
#         ],
#         "關係": [
#           {
#             "主體": "莫那魯道|人物",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "巫金墩|人物",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "石塚英藏|人物",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "人見次郎|人物",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "霧社事件|事件",
#             "關係": "發生於|P585",
#             "客體": "民國19年|時間"
#           },
#           {
#             "主體": "日本帝國|組織",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "台灣總督府|組織",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "霧社事件|事件",
#             "關係": "涉及|P361",
#             "客體": "泰雅人|專有名詞"
#           },
#           {
#             "主體": "霧社事件|事件",
#             "關係": "涉及|P361",
#             "客體": "賽德克|專有名詞"
#           },
#           {
#             "主體": "霧社事件|事件",
#             "關係": "發生於|P585",
#             "客體": "霧社公校|專有名詞"
#           },
#           {
#             "主體": "霧社事件|事件",
#             "關係": "造成|P1354",
#             "客體": "一百六十餘個|數量"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "霧社事件",
#           "種族衝突"
#         ],
#         "關係": [
#           {
#             "主體": "巫金墩|人物",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "日本帝國|組織",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "霧社事件|事件",
#             "關係": "涉及|P361",
#             "客體": "泰雅族|專有名詞"
#           },
#           {
#             "主體": "霧社事件|事件",
#             "關係": "涉及|P361",
#             "客體": "以蕃制蕃|專有名詞"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "霧社事件",
#           "撤換",
#           "調整修正"
#         ],
#         "關係": [
#           {
#             "主體": "石塚英藏|人物",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "人見次郎|人物",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "台灣總督府|組織",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "日本帝國議會|組織",
#             "關係": "參與|P1344",
#             "客體": "霧社事件|事件"
#           },
#           {
#             "主體": "霧社事件|事件",
#             "關係": "涉及|P361",
#             "客體": "理蕃政策|專有名詞"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "霧社事件",
#           "抗日行動"
#         ],
#         "關係": [
#           {
#             "主體": "霧社事件|事件",
#             "關係": "被記載於|P1343",
#             "客體": "電影|專有名詞"
#           },
#           {
#             "主體": "霧社事件|事件",
#             "關係": "被記載於|P1343",
#             "客體": "史詩電影|專有名詞"
#           },
#           {
#             "主體": "霧社事件|事件",
#             "關係": "被記載於|P1343",
#             "客體": "國家檔案|專有名詞"
#           }
#         ]
#       }
#     ]
#   }
# }
#
# ===== 檔案名稱: 「醫者仁也‧仁者人也」─光復初期臺灣醫學教育(29).json =====
# {
#   "result": {
#     "entities": [
#       {
#         "人物": [],
#         "時間": [
#           "日治時期"
#         ],
#         "組織": [
#           "臺灣大學醫學院"
#         ],
#         "專有名詞": [
#           "西方醫療觀念",
#           "醫師及護士等培育機構",
#           "醫療人員證照制度"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "日本領臺",
#           "設立醫師及護士等培育機構"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "日治時期",
#           "光復後"
#         ],
#         "組織": [
#           "臺灣省醫師公會",
#           "臺灣省行政長官公署"
#         ],
#         "專有名詞": [
#           "臺灣省衛生建設建議案",
#           "青少年體力管理法"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "醫學教育",
#           "護理教育"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "35學年度"
#         ],
#         "組織": [
#           "臺灣省立臺北高級醫事職業學校",
#           "臺大醫學院"
#         ],
#         "專有名詞": [
#           "護士科",
#           "助產科"
#         ],
#         "數量": [
#           "160名",
#           "40名"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "開辦臺灣省立臺北高級醫事職業學校"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "37年12月",
#           "38年"
#         ],
#         "組織": [
#           "臺灣省政府",
#           "教育部"
#         ],
#         "專有名詞": [
#           "臺灣衛生教育委員會"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "成立臺灣衛生教育委員會"
#         ]
#       },
#       {
#         "人物": [
#           "劉瑞恆",
#           "陳志潛",
#           "杜聰明"
#         ],
#         "時間": [
#           "38年11月"
#         ],
#         "組織": [
#           "教育部",
#           "臺灣省政府"
#         ],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "視察臺灣省各級醫學校及各衛生機關"
#         ]
#       },
#       {
#         "人物": [
#           "杜聰明"
#         ],
#         "時間": [],
#         "組織": [
#           "臺灣大學醫學院",
#           "國防醫學院"
#         ],
#         "專有名詞": [],
#         "數量": [
#           "3,000人",
#           "2,000人",
#           "1,064位學生"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "醫學教育"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "日治時期",
#           "光復後"
#         ],
#         "組織": [
#           "臺灣省政府",
#           "教育廳"
#         ],
#         "專有名詞": [
#           "留日學生問題座談會"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "留日學生返臺"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "37年6月30日",
#           "38年"
#         ],
#         "組織": [
#           "臺灣省政府",
#           "教育廳"
#         ],
#         "專有名詞": [
#           "中醫",
#           "法醫",
#           "牙醫",
#           "藥學"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "事件": [
#           "開辦中醫、牙醫、藥學及護理等科系"
#         ]
#       }
#     ],
#     "relationships": {
#       "error": "關係識別解析錯誤",
# ...
#           {
#             "主體": "中華商場鼎盛時期|事件",
#             "關係": "時間|P577",
#             "客體": "1960年代|時間"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "搭建霓虹燈箱招牌"
#         ],
#         "關係": [
#           {
#             "主體": "松下電器|組織",
#             "關係": "發起|P1344",
#             "客體": "搭建霓虹燈箱招牌|事件"
#           },
#           {
#             "主體": "搭建霓虹燈箱招牌|事件",
#             "關係": "地點|P276",
#             "客體": "中華商場|地點"
#           },
#           {
#             "主體": "搭建霓虹燈箱招牌|事件",
#             "關係": "時間|P577",
#             "客體": "1964年|時間"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "興建中華路武昌街行人天橋"
#         ],
#         "關係": [
#           {
#             "主體": "臺北市政府|組織",
#             "關係": "發起|P1344",
#             "客體": "興建中華路武昌街行人天橋|事件"
#           },
#           {
#             "主體": "興建中華路武昌街行人天橋|事件",
#             "關係": "地點|P276",
#             "客體": "中華商場|地點"
#           },
#           {
#             "主體": "興建中華路武昌街行人天橋|事件",
#             "關係": "時間|P577",
#             "客體": "1969年|時間"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "串聯天橋"
#         ],
#         "關係": [
#           {
#             "主體": "中華商場|地點",
#             "關係": "地點|P276",
#             "客體": "串聯天橋|事件"
#           },
#           {
#             "主體": "串聯天橋|事件",
#             "關係": "時間|P577",
#             "客體": "1971年|時間"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "國慶閱兵遊行"
#         ],
#         "關係": [
#           {
#             "主體": "中華商場|地點",
#             "關係": "地點|P276",
#             "客體": "國慶閱兵遊行|事件"
#           },
#           {
#             "主體": "國慶閱兵遊行|事件",
#             "關係": "時間|P577",
#             "客體": "10月|時間"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "美食店家"
#         ],
#         "關係": [
#           {
#             "主體": "中華商場|地點",
#             "關係": "地點|P276",
#             "客體": "美食店家|事件"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "中華商場不再引領時代潮流"
#         ],
#         "關係": [
#           {
#             "主體": "中華商場|地點",
#             "關係": "地點|P276",
#             "客體": "中華商場不再引領時代潮流|事件"
#           },
#           {
#             "主體": "中華商場不再引領時代潮流|事件",
#             "關係": "時間|P577",
#             "客體": "1980年代|時間"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "中華商場租約期滿"
#         ],
#         "關係": [
#           {
#             "主體": "黃大洲|人物",
#             "關係": "發起|P1344",
#             "客體": "中華商場租約期滿|事件"
#           },
#           {
#             "主體": "中華商場租約期滿|事件",
#             "關係": "時間|P577",
#             "客體": "1981年|時間"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "拆除中華商場"
#         ],
#         "關係": [
#           {
#             "主體": "黃大洲|人物",
#             "關係": "發起|P1344",
#             "客體": "拆除中華商場|事件"
#           },
#           {
#             "主體": "拆除中華商場|事件",
#             "關係": "時間|P577",
#             "客體": "1984年|時間"
#           }
#         ]
#       }
#     ]
#   }
# }
#
# ===== 檔案名稱: 中華航空：從軍事化管理到以客為尊經營(152).json =====
# {
#   "result": {
#     "entities": [
#       {
#         "人物": [
#           "陳納德"
#         ],
#         "時間": [
#           "38年",
#           "11月"
#         ],
#         "組織": [
#           "歐亞航空公司",
#           "中國航空公司",
#           "民航空運隊",
#           "中央航空公司"
#         ],
#         "事件": [
#           "兩航事件"
#         ],
#         "專有名詞": [
#           "CivilAirTransport",
#           "C.A.T"
#         ],
#         "數量": [
#           "12"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "地點": [
#           "大陸",
#           "香港",
#           "北平",
#           "臺北"
#         ]
#       },
#       {
#         "人物": [
#           "蔣經國",
#           "衣復恩"
#         ],
#         "時間": [
#           "44年",
#           "48年",
#           "12月",
#           "16日"
#         ],
#         "組織": [
#           "民航空運股份有限公司",
#           "中央情報局",
#           "空軍總部",
#           "美國軍事援華顧問團"
#         ],
#         "事件": [
#           "越戰"
#         ],
#         "專有名詞": [
#           "中華航空公司",
#           "華夏航空公司",
#           "中國航空公司"
#         ],
#         "數量": [
#           "50%",
#           "26",
#           "40萬"
#         ],
#         "貨幣": [
#           "新臺幣"
#         ],
#         "比例": [],
#         "地點": [
#           "美國",
#           "臺北",
#           "日月潭",
#           "香港"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "50年",
#           "51年"
#         ],
#         "組織": [
#           "中華航空公司",
#           "C.A.T",
#           "C.I.A"
#         ],
#         "事件": [
#           "滇緬游擊隊",
#           "越戰"
#         ],
#         "專有名詞": [
#           "北辰小組",
#           "南星小組"
#         ],
#         "數量": [
#           "40"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "地點": [
#           "臺北",
#           "香港",
#           "永珍",
#           "曼谷",
#           "西貢"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "51年",
#           "10月",
#           "55年",
#           "12月"
#         ],
#         "組織": [
#           "中華航空公司"
#         ],
#         "事件": [],
#         "專有名詞": [
#           "DC-3",
#           "DC-4",
#           "YS-11",
#           "波音727"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "地點": [
#           "臺北",
#           "花蓮",
#           "高雄",
#           "馬公",
#           "西貢"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "53年",
#           "57年",
#           "64年",
#           "7月"
#         ],
#         "組織": [
#           "中華航空公司",
#           "C.A.T"
#         ],
#         "事件": [],
#         "專有名詞": [
#           "波音707"
#         ],
#         "數量": [
#           "2,050萬",
#           "2"
#         ],
#         "貨幣": [
#           "美金"
#         ],
#         "比例": [],
#         "地點": [
#           "東京",
#           "大阪",
#           "香港",
#           "漢城",
#           "馬尼拉"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "60年"
#         ],
#         "組織": [
#           "中華航空公司"
#         ],
#         "事件": [],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "地點": [
#           "聯合國"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "64年",
#           "4月"
#         ],
#         "組織": [
#           "中華航空公司"
#         ],
#         "事件": [
#           "越戰"
#         ],
#         "專有名詞": [
#           "波音727",
#           "C47"
#         ],
#         "數量": [
#           "2百",
#           "3"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "地點": [
#           "西貢",
#           "臺北",
#           "松山機場"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "68年",
#           "1月",
#           "1日"
#         ],
#         "組織": [
#           "中華航空公司"
#         ],
#         "事件": [],
#         "專有名詞": [
#           "波音747"
#         ],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "地點": [
#           "臺灣"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "70年代"
#         ],
#         "組織": [
#           "中華航空公司"
#         ],
#         "事件": [],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "地點": []
#       },
#       {
#         "人物": [],
#         "時間": [
#           "76年"
#         ],
#         "組織": [
#           "中華航空公司",
#           "長榮航空公司",
#           "華信航空公司",
#           "馬公航空公司"
#         ],
#         "事件": [],
#         "專有名詞": [],
#         "數量": [],
#         "貨幣": [],
#         "比例": [],
#         "地點": [
#           "臺灣"
#         ]
#       },
#       {
#         "人物": [],
#         "時間": [
#           "77年",
#           "82年"
#         ],
#         "組織": [
#           "中華航空公司",
#           "財團法人中華航空事業發展基金會"
#         ],
#         "事件": [],
#         "專有名詞": [],
#         "數量": [
#           "27"
#         ],
#         "貨幣": [],
#         "比例": [],
#         "地點": [
#           "臺灣證卷交易所"
#         ]
#       }
#     ],
#     "relationships": [
#       {
#         "事件": [
#           "兩航事件"
#         ],
#         "關係": [
#           {
#             "主體": "陳納德|人物",
#             "關係": "參與|P1344",
#             "客體": "兩航事件|事件"
#           },
#           {
#             "主體": "陳納德|人物",
#             "關係": "創辦|P112",
#             "客體": "歐亞航空公司|組織"
#           },
#           {
#             "主體": "陳納德|人物",
#             "關係": "創辦|P112",
#             "客體": "中國航空公司|組織"
#           },
#           {
#             "主體": "陳納德|人物",
#             "關係": "創辦|P112",
#             "客體": "民航空運隊|組織"
#           },
#           {
#             "主體": "陳納德|人物",
#             "關係": "創辦|P112",
#             "客體": "中央航空公司|組織"
#           },
#           {
#             "主體": "陳納德|人物",
#             "關係": "時間|P585",
#             "客體": "38年|時間"
#           },
#           {
#             "主體": "陳納德|人物",
#             "關係": "時間|P585",
#             "客體": "11月|時間"
#           },
#           {
#             "主體": "歐亞航空公司|組織",
#             "關係": "簡稱|P1813",
#             "客體": "C.A.T|專有名詞"
#           },
#           {
#             "主體": "中國航空公司|組織",
#             "關係": "簡稱|P1813",
#             "客體": "C.A.T|專有名詞"
#           },
#           {
#             "主體": "民航空運隊|組織",
#             "關係": "簡稱|P1813",
#             "客體": "C.A.T|專有名詞"
#           },
#           {
#             "主體": "中央航空公司|組織",
#             "關係": "簡稱|P1813",
#             "客體": "C.A.T|專有名詞"
#           },
#           {
#             "主體": "陳納德|人物",
#             "關係": "地點|P276",
#             "客體": "大陸|地點"
#           },
#           {
#             "主體": "陳納德|人物",
#             "關係": "地點|P276",
#             "客體": "香港|地點"
#           },
#           {
#             "主體": "陳納德|人物",
#             "關係": "地點|P276",
#             "客體": "北平|地點"
#           },
#           {
#             "主體": "陳納德|人物",
#             "關係": "地點|P276",
#             "客體": "臺北|地點"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "越戰"
#         ],
#         "關係": [
#           {
#             "主體": "蔣經國|人物",
#             "關係": "參與|P1344",
#             "客體": "越戰|事件"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "時間|P585",
#             "客體": "44年|時間"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "時間|P585",
#             "客體": "48年|時間"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "時間|P585",
#             "客體": "12月|時間"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "時間|P585",
#             "客體": "16日|時間"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "組織|P108",
#             "客體": "民航空運股份有限公司|組織"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "組織|P108",
#             "客體": "中央情報局|組織"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "組織|P108",
#             "客體": "空軍總部|組織"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "組織|P108",
#             "客體": "美國軍事援華顧問團|組織"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "地點|P276",
#             "客體": "美國|地點"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "地點|P276",
#             "客體": "臺北|地點"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "地點|P276",
#             "客體": "日月潭|地點"
#           },
#           {
#             "主體": "蔣經國|人物",
#             "關係": "地點|P276",
#             "客體": "香港|地點"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "滇緬游擊隊"
#         ],
#         "關係": [
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "簡稱|P1813",
#             "客體": "C.A.T|專有名詞"
#           },
#           {
#             "主體": "C.A.T|組織",
#             "關係": "簡稱|P1813",
#             "客體": "C.A.T|專有名詞"
#           },
#           {
#             "主體": "C.I.A|組織",
#             "關係": "簡稱|P1813",
#             "客體": "C.I.A|專有名詞"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "臺北|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "香港|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "永珍|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "曼谷|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "西貢|地點"
#           }
#         ]
#       },
#       {
#         "事件": [],
#         "關係": [
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "機型|P238",
#             "客體": "DC-3|專有名詞"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "機型|P238",
#             "客體": "DC-4|專有名詞"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "機型|P238",
#             "客體": "YS-11|專有名詞"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "機型|P238",
#             "客體": "波音727|專有名詞"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "臺北|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "花蓮|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "高雄|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "馬公|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "西貢|地點"
#           }
#         ]
#       },
#       {
#         "事件": [],
#         "關係": [
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "機型|P238",
#             "客體": "波音707|專有名詞"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "資產|P230",
#             "客體": "2,050萬|數量"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "資產|P230",
#             "客體": "2|數量"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "貨幣|P38",
#             "客體": "美金|貨幣"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "東京|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "大阪|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "香港|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "漢城|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "馬尼拉|地點"
#           }
#         ]
#       },
#       {
#         "事件": [],
#         "關係": [
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "聯合國|地點"
#           }
#         ]
#       },
#       {
#         "事件": [
#           "越戰"
#         ],
#         "關係": [
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "機型|P238",
#             "客體": "波音727|專有名詞"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "機型|P238",
#             "客體": "C47|專有名詞"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "西貢|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "臺北|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "松山機場|地點"
#           }
#         ]
#       },
#       {
#         "事件": [],
#         "關係": [
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "機型|P238",
#             "客體": "波音747|專有名詞"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "臺灣|地點"
#           }
#         ]
#       },
#       {
#         "事件": [],
#         "關係": [
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "臺灣|地點"
#           }
#         ]
#       },
#       {
#         "事件": [],
#         "關係": [
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "臺灣|地點"
#           },
#           {
#             "主體": "長榮航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "臺灣|地點"
#           },
#           {
#             "主體": "華信航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "臺灣|地點"
#           },
#           {
#             "主體": "馬公航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "臺灣|地點"
#           }
#         ]
#       },
#       {
#         "事件": [],
#         "關係": [
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "臺灣|地點"
#           },
#           {
#             "主體": "財團法人中華航空事業發展基金會|組織",
#             "關係": "地點|P276",
#             "客體": "臺灣|地點"
#           },
#           {
#             "主體": "中華航空公司|組織",
#             "關係": "地點|P276",
#             "客體": "臺灣證卷交易所|地點"
#           }
#         ]
#       }
#     ]
#   }
# }

# %% [markdown]
# ### 處理目錄裡面檔案

# %%
import json
import os
import shutil


json_dir = "./docs/output/1_clean_json/llama/"
done_dir = "./docs/output/1_clean_json/llama/done/"
out_dir = "./docs/output/3_ner_re_p/llama_v7/"

# 確保 json_done 目錄存在
#os.makedirs(done_dir, exist_ok=True)
#os.makedirs(out_dir, exist_ok=True)


json_files = [f for f in os.listdir(json_dir) if f.endswith(".json")]

for filename in json_files:
    file_path = os.path.join(json_dir, filename)
    
    try:
        # 讀取 JSON 檔案
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)
        print(f"✅ 開始處理: {filename}")
        # 取得 articles 欄位並進行處理
        articles = data.get("articles", [])

        processed_articles = process_text(articles)
        
        # 將處理後的結果寫回 JSON
        output_data = {
            #輸出加入articles內容
            #"articles": articles,
            "result": processed_articles
        }
        
        out_path = os.path.join(out_dir, filename)
        
        with open(out_path, "w", encoding="utf-8") as f:
            json.dump(output_data, f, indent=2, ensure_ascii=False)
        
        print(f"✅ 已處理並存入: {out_path}")
        
        # 搬移已處理的 JSON 檔案到 json_done 目錄
        shutil.move(file_path, os.path.join(done_dir, filename))
        print(f"📂 已搬移 {filename} 到 {done_dir}")
        
    except json.JSONDecodeError:
        print(f"⚠️ JSON 解析錯誤: {filename}")
    except IOError as e:
        print(f"⚠️ 無法讀取檔案 {filename}，錯誤: {e}")
    print("-" * 50)
    
print("\n📂 全部 JSON 檔案處理完成！")
# Out:
# ✅ 開始處理: 九年國教：春風化雨五十載(134).json
# ✅ 已處理並存入: ./docs/output/3_ner_re_p/llama_v7/九年國教：春風化雨五十載(134).json
# 📂 已搬移 九年國教：春風化雨五十載(134).json 到 ./docs/output/1_clean_json/llama/done/
# --------------------------------------------------
# ✅ 開始處理: 亞東關係協會：臺日友好關係的樞紐(185).json
# ✅ 已處理並存入: ./docs/output/3_ner_re_p/llama_v7/亞東關係協會：臺日友好關係的樞紐(185).json
# 📂 已搬移 亞東關係協會：臺日友好關係的樞紐(185).json 到 ./docs/output/1_clean_json/llama/done/
# --------------------------------------------------
# ✅ 開始處理: 人民頭家—公民直選總統(23).json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 28
#      25 # 取得 articles 欄位並進行處理
#      26 articles = data.get("articles", [])
# ---> 28 processed_articles = process_text(articles)
#      30 # 將處理後的結果寫回 JSON
#      31 output_data = {
#      32     #輸出加入articles內容
#      33     #"articles": articles,
#      34     "result": processed_articles
#      35 }
#
# Cell In[19], line 48, in process_text(text)
#      45     return entities
#      47 # 再執行關係識別
# ---> 48 relationships = extract_relationships(entities)
#      50 return {
#      51     "entities": entities,
#      52     "relationships": relationships
#      53 }
#
# Cell In[19], line 15, in extract_relationships(entities)
#      14 def extract_relationships(entities):
# ---> 15     raw_result = relation_chain.run(json.dumps(entities, ensure_ascii=False))
#      16     #raw_result = relation_chain.invoke(json.dumps(entities, ensure_ascii=False))
#      17     try:
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain_core\_api\deprecation.py:181, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     179     warned = True
#     180     emit_warning()
# --> 181 return wrapped(*args, **kwargs)
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain\chains\base.py:606, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     604     if len(args) != 1:
#     605         raise ValueError("`run` supports only one positional argument.")
# --> 606     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     607         _output_key
#     608     ]
#     610 if kwargs and not args:
#     611     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     612         _output_key
#     613     ]
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain_core\_api\deprecation.py:181, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     179     warned = True
#     180     emit_warning()
# --> 181 return wrapped(*args, **kwargs)
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain\chains\base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain\chains\base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain\chains\base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain\chains\llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain\chains\llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:843, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     835 def generate_prompt(
#     836     self,
#     837     prompts: list[PromptValue],
#    (...)
#     840     **kwargs: Any,
#     841 ) -> LLMResult:
#     842     prompt_messages = [p.to_messages() for p in prompts]
# --> 843     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:683, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     680 for i, m in enumerate(messages):
#     681     try:
#     682         results.append(
# --> 683             self._generate_with_cache(
#     684                 m,
#     685                 stop=stop,
#     686                 run_manager=run_managers[i] if run_managers else None,
#     687                 **kwargs,
#     688             )
#     689         )
#     690     except BaseException as e:
#     691         if run_managers:
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:908, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     906 else:
#     907     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 908         result = self._generate(
#     909             messages, stop=stop, run_manager=run_manager, **kwargs
#     910         )
#     911     else:
#     912         result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\langchain_openai\chat_models\base.py:800, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     798     generation_info = {"headers": dict(raw_response.headers)}
#     799 else:
# --> 800     response = self.client.create(**payload)
#     801 return self._create_chat_result(response, generation_info)
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\openai\resources\chat\completions\completions.py:925, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     882 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     883 def create(
#     884     self,
#    (...)
#     922     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     923 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     924     validate_response_format(response_format)
# --> 925     return self._post(
#     926         "/chat/completions",
#     927         body=maybe_transform(
#     928             {
#     929                 "messages": messages,
#     930                 "model": model,
#     931                 "audio": audio,
#     932                 "frequency_penalty": frequency_penalty,
#     933                 "function_call": function_call,
#     934                 "functions": functions,
#     935                 "logit_bias": logit_bias,
#     936                 "logprobs": logprobs,
#     937                 "max_completion_tokens": max_completion_tokens,
#     938                 "max_tokens": max_tokens,
#     939                 "metadata": metadata,
#     940                 "modalities": modalities,
#     941                 "n": n,
#     942                 "parallel_tool_calls": parallel_tool_calls,
#     943                 "prediction": prediction,
#     944                 "presence_penalty": presence_penalty,
#     945                 "reasoning_effort": reasoning_effort,
#     946                 "response_format": response_format,
#     947                 "seed": seed,
#     948                 "service_tier": service_tier,
#     949                 "stop": stop,
#     950                 "store": store,
#     951                 "stream": stream,
#     952                 "stream_options": stream_options,
#     953                 "temperature": temperature,
#     954                 "tool_choice": tool_choice,
#     955                 "tools": tools,
#     956                 "top_logprobs": top_logprobs,
#     957                 "top_p": top_p,
#     958                 "user": user,
#     959                 "web_search_options": web_search_options,
#     960             },
#     961             completion_create_params.CompletionCreateParamsStreaming
#     962             if stream
#     963             else completion_create_params.CompletionCreateParamsNonStreaming,
#     964         ),
#     965         options=make_request_options(
#     966             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     967         ),
#     968         cast_to=ChatCompletion,
#     969         stream=stream or False,
#     970         stream_cls=Stream[ChatCompletionChunk],
#     971     )
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\openai\_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)
#    1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\openai\_base_client.py:969, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     967 response = None
#     968 try:
# --> 969     response = self._client.send(
#     970         request,
#     971         stream=stream or self._should_stream_response_body(request=request),
#     972         **kwargs,
#     973     )
#     974 except httpx.TimeoutException as err:
#     975     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\jwu048\Documents\Python\poetry\demo\.venv\lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1259, in SSLSocket.recv(self, buflen, flags)
#    1255     if flags != 0:
#    1256         raise ValueError(
#    1257             "non-zero flags not allowed in calls to recv() on %s" %
#    1258             self.__class__)
# -> 1259     return self.read(buflen)
#    1260 else:
#    1261     return super().recv(buflen, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130         return self._sslobj.read(len, buffer)
#    1131     else:
# -> 1132         return self._sslobj.read(len)
#    1133 except SSLError as x:
#    1134     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

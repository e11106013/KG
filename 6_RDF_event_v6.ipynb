# %%
import os
import json
import requests
from rdflib import Graph, URIRef, Literal, RDF, Namespace, BNode
from rdflib.namespace import XSD, RDFS, OWL

# 定義命名空間
EX = Namespace("http://example.org/schema#")
WD = Namespace("http://www.wikidata.org/entity/")
WDT = Namespace("http://www.wikidata.org/prop/direct/")
DBR = Namespace("http://dbpedia.org/resource/")

LITERAL_CLASSES = {"數量", "比例", "單位", "貨幣", "時間"}

# 載入 JSON 檔案
def load_json(filename):
    with open(filename, 'r', encoding='utf-8') as file:
        return json.load(file)

# 從 Wikidata 獲取標籤和描述
def get_wikidata_info(qid):
    url = f"https://www.wikidata.org/wiki/Special:EntityData/{qid}.json"
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            entity = data['entities'].get(qid, {})
            labels = entity.get('labels', {})
            descriptions = entity.get('descriptions', {})
            label = labels.get('zh-tw', {}).get('value') or labels.get('zh', {}).get('value')
            description = descriptions.get('zh-tw', {}).get('value') or descriptions.get('zh', {}).get('value')
            return label, description
    except Exception as e:
        print(f"Error fetching Wikidata info for {qid}: {e}")
    return None, None

# 從 DBpedia 獲取標籤和描述
def get_dbpedia_info(uri):
    sparql = f"""
    SELECT ?label ?comment WHERE {{
        <{uri}> rdfs:label ?label .
        OPTIONAL {{ <{uri}> rdfs:comment ?comment . }}
        FILTER (lang(?label) = 'zh' || lang(?label) = 'zh-tw')
    }}
    """
    endpoint = "https://dbpedia.org/sparql"
    try:
        response = requests.get(endpoint, params={'query': sparql, 'format': 'json'})
        if response.status_code == 200:
            results = response.json().get('results', {}).get('bindings', [])
            if results:
                label = results[0].get('label', {}).get('value')
                comment = results[0].get('comment', {}).get('value')
                return label, comment
    except Exception as e:
        print(f"Error fetching DBpedia info for {uri}: {e}")
    return None, None

# 添加實體資訊到 RDF 圖中
def add_entity_info_to_graph(g, entity_uri, entity_id):
    label, description = get_wikidata_info(entity_id)
    if label:
        g.add((entity_uri, RDFS.label, Literal(label, lang='zh-TW')))
    if description:
        g.add((entity_uri, RDFS.comment, Literal(description, lang='zh-TW')))
    if not label or not description:
        dbpedia_uri = f"http://dbpedia.org/resource/{entity_id}"
        label, description = get_dbpedia_info(dbpedia_uri)
        if label:
            g.add((entity_uri, RDFS.label, Literal(label, lang='zh-TW')))
        if description:
            g.add((entity_uri, RDFS.comment, Literal(description, lang='zh-TW')))

# 建立 Literal 的 Blank Node
def create_literal_blank_node(g, label, entity_type):
    bnode = BNode()
    try:
        if "成" in label:
            numeric_value = float(label.replace("成", "")) / 10
            g.add((bnode, RDF.value, Literal(numeric_value, datatype=XSD.float)))
        elif label.replace(".", "", 1).isdigit():
            g.add((bnode, RDF.value, Literal(float(label), datatype=XSD.float)))
        else:
            g.add((bnode, RDF.value, Literal(label, lang='zh-TW')))
    except:
        g.add((bnode, RDF.value, Literal(label, lang='zh-TW')))
    g.add((bnode, RDF.type, EX[entity_type]))
    g.add((bnode, RDFS.label, Literal(label, lang='zh-TW')))
    return bnode

# 轉換 JSON 內容為 Turtle 格式
def convert_json_to_turtle(data, filename, output_dir):
    g = Graph()
    g.bind("ex", EX)
    g.bind("wd", WD)
    g.bind("wdt", WDT)
    g.bind("rdfs", RDFS)
    g.bind("dbr", DBR)

    for entry in data['review']['relationships']:
        for event in entry['事件']:
            event_uri = URIRef(f"http://example.org/doc/{filename}#event_{event}")
            g.add((event_uri, RDF.type, EX.Event))
            g.add((event_uri, EX.describedIn, URIRef(f"http://example.org/doc/{filename}.json")))
            g.add((event_uri, RDFS.label, Literal(event, lang='zh-TW')))
            g.add((event_uri, RDFS.comment, Literal(f"事件：{event}", lang='zh-TW')))

            for relationship in entry['關係列表']:
                subj_label = relationship.get('主體')
                subj_qid = relationship.get('主體 QID')
                subj_dbpedia = relationship.get('主體 DBpedia')
                subj_type = relationship.get('主體類別')

                obj_label = relationship.get('客體')
                obj_qid = relationship.get('客體 QID')
                obj_dbpedia = relationship.get('客體 DBpedia')
                obj_type = relationship.get('客體類別')

                predicate = relationship.get('p-items')
                predicate_uri = WDT[predicate]

                if subj_type in LITERAL_CLASSES:
                    subj_node = create_literal_blank_node(g, subj_label, subj_type)
                elif subj_qid:
                    subj_node = WD[subj_qid]
                    add_entity_info_to_graph(g, subj_node, subj_qid)
                    if subj_dbpedia:
                        g.add((subj_node, OWL.sameAs, URIRef(subj_dbpedia)))
                else:
                    subj_node = Literal(subj_label, lang='zh-TW')

                if obj_type in LITERAL_CLASSES:
                    obj_node = create_literal_blank_node(g, obj_label, obj_type)
                elif obj_qid:
                    obj_node = WD[obj_qid]
                    add_entity_info_to_graph(g, obj_node, obj_qid)
                    if obj_dbpedia:
                        g.add((obj_node, OWL.sameAs, URIRef(obj_dbpedia)))
                else:
                    obj_node = Literal(obj_label, lang='zh-TW')

                triple_node = BNode()
                g.add((triple_node, RDF.type, EX.Triple))
                g.add((triple_node, EX.subject, subj_node))
                g.add((triple_node, EX.predicate, predicate_uri))
                g.add((triple_node, EX.object, obj_node))

                g.add((event_uri, EX.hasTriple, triple_node))

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    ttl_filename = os.path.join(output_dir, f"{filename}.ttl")
    g.serialize(destination=ttl_filename, format="turtle", encoding="utf-8")
    print(f"RDF Turtle file saved as {ttl_filename}")

# 處理整個資料夾的 JSON 檔案
def convert_json_folder_to_turtle(input_folder, output_folder):
    for filename in os.listdir(input_folder):
        if filename.endswith(".json"):
            json_filepath = os.path.join(input_folder, filename)
            data = load_json(json_filepath)
            convert_json_to_turtle(data, filename[:-5], output_folder)

# %%
# 設定輸入和輸出的資料夾路徑
input_folder = "./docs/output/5_wiki/v7"  # 你的 JSON 檔案資料夾
output_folder = "./docs/output/6_rdf/event"  # 轉換後的 Turtle 檔案輸出資料夾

# 執行轉換
convert_json_folder_to_turtle(input_folder, output_folder)
# Out:
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\「友仔」是什麼？光復初期臺北地區非法組織調查報告告訴您(37).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\「回首向來蕭瑟處，歸去，也無風雨也無晴」—民國38年國軍遷臺紀事(30).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\「威海衛」租借地的收回(42).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\「快速」發展的年代：麥克阿瑟公路通車一甲子(203).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\「日暮鄉關何處是」─「留越國軍」的返台路(31).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\「賽德克．巴萊」重現的霧社事件(17).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426
ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\彰化地標：八卦山大佛與風景區(174).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\從想食到饗時—尋味臺灣八十年(172).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\從開發到保育：走過臺灣的建設時代(196).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\快樂時光：承載記憶的兒童樂園(130).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\您今天搭幾路？光復初期的基隆市公車(50).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\情報戰：金門戰役的決勝要件(149).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\愛仁輪事件爭議始末(117).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\戒嚴時期金門漁會與漁業的發展(186).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\戰時相戀、和平分離─海角七號的故事背景(25).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\打撈沉貼：光復初期臺灣的軍事接收要務(106).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\打造超級油輪「柏瑪奮進號」(125).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\扭轉「錢」坤—國幣演變的故事(84).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\投降到受降—撼動歷史的26天(38).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\抗戰「船」奇：決戰千里外的廣源輪案(121).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\抗戰時期的傷兵救護與管理(99).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\拓墾最前線臺三線上的明珠—北埔(122).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\探索臺灣鹽業發展四百年(199).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\揭密．國家檔案(173).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\撲瘧我最棒─得來不易的「台灣地區瘧疾根除證書」(3).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\文化活化了產業—從檔案看國營事業的轉型(65).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\旅行的記憶：歷史景點的美好故事(63).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\旋轉舞台：消失的電視國劇(49).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\晴空決戰中的外籍空軍志願隊(26).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\更迭變化的人口課題，永遠的挑戰─推行臺灣地區家庭計畫(4).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\本週中心德目：服從師長(45).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\杜絕烏腳病：臺灣公衛史上的大挑戰(202).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\東沙島主權維護：從海人草開發談起(87).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\桃園國際機場與周邊交通的發展(140).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\歡慶光復臺灣省博覽會(100).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\民國38年的太平輪事件(96).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\氣候戰爭：古寧頭戰役致勝關鍵之一(110).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\水庫紀元：曾文水庫的竣工與開放(192).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\水源永續：多功能石門水庫的興建(204).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\永誌邦誼：臺灣糖業技術的對外援助(157).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\沙漠奇蹟、綠洲農業—海外農耕隊(77).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\海洋臺灣：走尋港口的歷史(59).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\湖光山色：從工業走向觀光的澄清湖(155).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\溫泉之旅：北投產業發展速讀(115).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\灣生尋根-在臺日僑遣送(101).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\火車快飛—臺灣鐵路建設向前行(82).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\為國爭光：臺北市少棒隊勇奪世界冠軍(182).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\烽火歲月中的「臺灣革命同盟會」(103).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\烽火歲月與和平鐘聲：決戰於千里之外的宣傳單(52).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\獎券在手、希望無窮：期待中獎的喜悅(68).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\球來就打，永不放棄的臺南巨人少棒隊(169).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\甜蜜再進化—從產糖到製菓(161).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\由直轉橫：新臺幣鈔券的發行與演變(180).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\白金鹽憶：戰後臺灣鹽業的多元發展(184).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\百事可樂加冰塊：敲開市場大門的一封信(177).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\百年記憶：憲法制訂歷程(43).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\百年記憶：承載記憶的鐵路(44).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\直衝雲霄：花蓮機場走過一甲子歲月(179).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\看不見的推手—美援與臺灣經濟發展(93).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\礦山記憶：探索金瓜石百年歷史風華(191).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\科技時代：清華大學電動車的研發(195).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\空飄氣球諜對諜(15).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\空飄汽球：對中共的心戰攻勢(131).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\穿梭南北：自強號啟動臺灣運輸新紀元(126).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\穿越時空的阿里山森林鐵路！(88).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\筵席稅(14).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\紀念至聖先師的傳統禮俗—祭孔大典(75).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\細菌戰疫：國際合作與鼠疫防治(153).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\經營與蛻變：從輪船招商局到陽明海運(181).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\縮地千里始足下(56).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426\繁榮經濟的高雄加工出口區(112).ttl
# RDF Turtle file saved as ./docs/output/9_rdf/event_0426